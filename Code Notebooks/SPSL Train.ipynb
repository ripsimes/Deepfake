# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install -q "numpy<2" --force-reinstall

# %%
import numpy, torch, torchvision
# print("numpy:", numpy.__version__)
# print("torch:", torch.__version__)
# print("torchvision:", torchvision.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# CUDA: True

# %%
import os, glob, json, random

TRAIN_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/training_data"
VAL_DIR   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/validation_data"
TEST_DIR  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/publictest_data"

VAL_REF   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/validation_reference/reference.txt"
TEST_REF  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/publictest_reference/reference.txt"

STAGING = "/content/DiffusionForensics_Recons"
os.makedirs(STAGING, exist_ok=True)

IMG_EXTS = (".png", ".jpg", ".jpeg", ".webp", ".bmp", ".tif", ".tiff")

# ═══════════════════════════════════════════════════
# TRAINING — training_data_final
# ═══════════════════════════════════════════════════
train_items = []
for ext in IMG_EXTS:
    for p in glob.glob(os.path.join(TRAIN_DIR, f"*{ext}")):
        name = os.path.basename(p).lower()
        if "_real" in name:
            train_items.append({"path": p, "label": 0})
        elif "_fake" in name:
            train_items.append({"path": p, "label": 1})

random.seed(42)
random.shuffle(train_items)

n_real = sum(1 for x in train_items if x["label"] == 0)
n_fake = sum(1 for x in train_items if x["label"] == 1)
print(f"TRAIN: {len(train_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# VALIDATION — validation_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(VAL_REF) as f:
    val_labels = [int(line.strip()) for line in f if line.strip()]

val_images = sorted(glob.glob(os.path.join(VAL_DIR, "*.*")))
val_images = [p for p in val_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(val_images) == len(val_labels), \
    f"Mismatch: {len(val_images)} images vs {len(val_labels)} labels"

val_items = [{"path": p, "label": l} for p, l in zip(val_images, val_labels)]

n_real = sum(1 for x in val_items if x["label"] == 0)
n_fake = sum(1 for x in val_items if x["label"] == 1)
print(f"VAL:   {len(val_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# TEST — publictest_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(TEST_REF) as f:
    test_labels = [int(line.strip()) for line in f if line.strip()]

test_images = sorted(glob.glob(os.path.join(TEST_DIR, "*.*")))
test_images = [p for p in test_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(test_images) == len(test_labels), \
    f"Mismatch: {len(test_images)} images vs {len(test_labels)} labels"

test_items = [{"path": p, "label": l} for p, l in zip(test_images, test_labels)]

n_real = sum(1 for x in test_items if x["label"] == 0)
n_fake = sum(1 for x in test_items if x["label"] == 1)
print(f"TEST:  {len(test_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# SAVE JSONs
# ═══════════════════════════════════════════════════
for name, data in [("train", train_items), ("val", val_items), ("test", test_items)]:
    out = os.path.join(STAGING, f"{name}.json")
    with open(out, "w") as f:
        json.dump(data, f)
    print(f"\n✓ {name}.json → {len(data)} items → {out}")
# Out:
# TRAIN: 1000 images  (real=500, fake=500)
# VAL:   100 images  (real=50, fake=50)
# TEST:  1000 images  (real=500, fake=500)
#
# ✓ train.json → 1000 items → /content/DiffusionForensics_Recons/train.json
#
# ✓ val.json → 100 items → /content/DiffusionForensics_Recons/val.json
#
# ✓ test.json → 1000 items → /content/DiffusionForensics_Recons/test.json

# %%
# %%capture
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench
# !pip install jedi
# !python -m pip install -U pip setuptools wheel
# !pip install -r requirements.txt
# !pip install -e .

# %%
# %%capture
# %cd "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub"
# !head -n -1 requirements.txt > requirements_no_flash.txt
# !pip install -r requirements_no_flash.txt

# %%
# import shutil
# from pathlib import Path

# CKPT_DIR = Path("/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train")

# if CKPT_DIR.exists():
#     shutil.rmtree(CKPT_DIR)
#     print("🧹 Old checkpoints deleted")

# CKPT_DIR.mkdir(parents=True, exist_ok=True)
# print("✅ Fresh checkpoint directory created:", CKPT_DIR)
# Out:
# 🧹 Old checkpoints deleted
# ✅ Fresh checkpoint directory created: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train

# %%
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub

# !PYTHONPATH=/content/drive/MyDrive/Capstone_Hripsime/Frameworks:$PWD \
MASTER_ADDR=127.0.0.1 MASTER_PORT=29601 \
python -m ForensicHub.training_scripts.train \
--config "ForensicHub/statics/crossdataset_image/spsl_train.yaml"
# Out:
# /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/timm/optim/optim_factory.py:7: FutureWarning: Importing from timm.optim.optim_factory is deprecated, please import via timm.optim
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.optim", FutureWarning)
# 2026-04-16 16:15:41.717599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776356141.752417   14294 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776356141.763882   14294 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776356141.794106   14294 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776356141.794133   14294 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776356141.794137   14294 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776356141.794145   14294 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-16 16:15:41.801562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/IMDLBenCo/training_scripts/trainer/trainer.py:25: UserWarning: HOPE YOU TO READ: Starting from IMDLBenCo version v0.1.31, we have discovered a misdefinition regarding the --if_not_amp parameter in the argument parser. For more details, please refer to: https://github.com/scu-zjz/IMDLBenCo/issues/89. As a result, if you use the train.py script generated by an earlier version of 'benco init' before v0.1.30, along with the latest version of trainer.py, it may lead to AMP (Automatic Mixed Precision) being incorrectly enabled or disabled. We recommend updating to the latest version(after v0.1.31, include) of IMDLBenCo and re-initializing the project using 'benco init' to ensure that the --if_not_amp parameter is correctly defined.  Or for already initialized projects, please manually modify the action of the --if_not_amp parameter in train.py to 'store_true' to ensure correct logic.  We apologize for any inconvenience this may have caused.!!!!!!
#   warnings.warn(
# Not using distributed mode
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [16:16:22.792098] [patch] initialized torch.distributed process group (single-process, gloo)
# [16:16:22.794071] job dir: /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub/ForensicHub/training_scripts
# [16:16:22.794208] =====args:=====
# [16:16:22.794353] Namespace(gpus=0.0,
# flag='train',
# log_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train',
# if_predict_label=True,
# if_predict_mask=False,
# num_classes=2,
# batch_size=32,
# test_batch_size=16,
# epochs=20,
# accum_iter=1,
# record_epoch=0,
# no_model_eval=False,
# test_period=1,
# log_per_epoch_count=20,
# find_unused_parameters=False,
# use_amp=False,
# weight_decay=0.05,
# lr=0.0001,
# blr=0.001,
# min_lr=1e-05,
# warmup_epochs=1,
# device='cuda',
# seed=42,
# resume='',
# start_epoch=0,
# num_workers=2,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# output_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train',
# if_not_amp=True,
# distributed=False)
# [16:16:23.933798] [build_from_registry] Creating model 'AIGCTransform' with args: {'norm_type': 'image_net'}
# [16:16:23.934473] Train transform:  Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:16:23.934816] Test transform:  Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:16:23.934939] Post transform:  Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:16:23.935099] Post function check: spsl_post_func
# [16:16:23.935172] None
# [16:16:23.935401] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 256, 'path': '/content/DiffusionForensics_Recons/train.json', 'post_funcs': None, 'common_transform': Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [16:16:23.936854] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 256, 'path': '/content/DiffusionForensics_Recons/val.json', 'post_funcs': None, 'common_transform': Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [16:16:23.937155] Train dataset: DiffusionForensics_train.
# [16:16:23.937234] 1000
# [16:16:23.937348] [AIGCLabelDataset] at /content/DiffusionForensics_Recons/train.json, with length of 1,000
# [16:16:23.937416] Test dataset: ['DiffusionForensics_val'].
# [16:16:23.937500] [100]
# [16:17:20.119286] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [16:17:20.119425] spatial_count=0 keep_stride_count=0
# [16:17:57.313319] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [16:17:57.313469] spatial_count=0 keep_stride_count=0
# [16:17:57.380965] [build_from_registry] Creating model 'Spsl' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/spsl.yaml'}
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/xception-43020ad28.pth" to /root/.cache/torch/hub/checkpoints/xception-43020ad28.pth
# [16:18:00.765737] [build_from_registry] Creating model 'ImageF1' with args: {'threshold': 0.5}
# [16:18:00.765947] [build_from_registry] Creating model 'ImageAUC' with args: {}
# [16:18:00.766055] Evaluators: [<IMDLBenCo.evaluation.F1.ImageF1 object at 0x7e6ee5653da0>, <IMDLBenCo.evaluation.AUC.ImageAUC object at 0x7e6ee46aeff0>]
# [16:18:01.049298] Model = Spsl(
#   (backbone): Xception(
#     (conv1): Conv2d(4, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act2): ReLU(inplace=True)
#     (block1): Block(
#       (skip): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): SeparableConv2d(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block2): Block(
#       (skip): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block3): Block(
#       (skip): Conv2d(256, 728, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block4): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block5): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block6): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block7): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block8): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block9): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block10): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block11): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block12): Block(
#       (skip): Conv2d(728, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (conv3): SeparableConv2d(
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#       (pointwise): Conv2d(1024, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn3): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act3): ReLU(inplace=True)
#     (conv4): SeparableConv2d(
#       (conv1): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#       (pointwise): Conv2d(1536, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act4): ReLU(inplace=True)
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=2048, out_features=2, bias=True)
#   )
#   (loss_func): CrossEntropyLoss()
# )
# [16:18:01.057149] base lr: 8.00e-04
# [16:18:01.057376] actual lr: 1.00e-04
# [16:18:01.057631] accumulate grad iterations: 1
# [16:18:01.057723] effective batch size: 32
# [16:18:01.057812] master port: 29601
# [16:18:01.062588] AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.05
# )
# [16:18:01.062955] Start training for 20 epochs
# [16:18:01.065006] Auto Mixed Precision (AMP) is disabled.
# [16:18:01.066099] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:18:22.032516] Epoch: [0]  [ 0/31]  eta: 0:10:49  lr: 0.000000  combined_loss: [local: 0.6917 | reduced: 0.6917]  time: 20.9602  data: 17.6225  max mem: 5561
# [16:20:59.117836] Epoch: [0]  [20/31]  eta: 0:01:33  lr: 0.000065  combined_loss: [local: 0.6893 | reduced: 0.6937]  time: 7.8542  data: 7.0987  max mem: 5721
# [16:22:20.283901] Epoch: [0]  [30/31]  eta: 0:00:08  lr: 0.000097  combined_loss: [local: 0.6896 | reduced: 0.6915]  time: 8.0894  data: 7.3133  max mem: 5721
# [16:22:20.320492] Epoch: [0] Total time: 0:04:19 (8.3630 s / it)
# [16:22:21.176003] Averaged stats: lr: 0.000097  combined_loss: [local: 0.6896 | reduced: 0.6915]
# [16:22:22.505195] !!!Start Test: DiffusionForensics_val 6
# [16:22:31.136905] Test: [0]  [0/6]  eta: 0:00:51    time: 8.6286  data: 8.4754  max mem: 5721
# [16:22:47.855206] Test: [0]  [5/6]  eta: 0:00:04    time: 4.2243  data: 4.1344  max mem: 5721
# [16:22:47.896428] Test: [0] Total time: 0:00:25 (4.2315 s / it)
# [16:22:47.950172] ---syncronized---
# [16:22:47.950309] image-level F1 reduced_count 1
# [16:22:47.950406] image-level F1 reduced_sum 0.3116883337497711
# [16:22:47.950531] image-level AUC reduced_count 1
# [16:22:47.950624] image-level AUC reduced_sum 0.411202778983934
# [16:22:47.950731] ---syncronized done ---
# [16:22:48.307430] Averaged stats: image-level F1: [local: 0.3117 | reduced: 0.3117]  image-level AUC: [local: 0.4112 | reduced: 0.4112]
# [16:22:48.441221] Best image-level F1 image-level AUC = 0.36144555636685255
# [16:22:50.126467] Auto Mixed Precision (AMP) is disabled.
# [16:22:50.127691] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:22:52.793621] Epoch: [1]  [ 0/31]  eta: 0:01:22  lr: 0.000100  combined_loss: [local: 0.6666 | reduced: 0.6666]  time: 2.6646  data: 0.4857  max mem: 5721
# [16:23:11.633850] Epoch: [1]  [20/31]  eta: 0:00:11  lr: 0.000100  combined_loss: [local: 0.6653 | reduced: 0.6632]  time: 0.9419  data: 0.0297  max mem: 5721
# [16:23:19.948100] Epoch: [1]  [30/31]  eta: 0:00:00  lr: 0.000099  combined_loss: [local: 0.6483 | reduced: 0.6550]  time: 0.9295  data: 0.0297  max mem: 5721
# [16:23:20.005147] Epoch: [1] Total time: 0:00:29 (0.9638 s / it)
# [16:23:20.949164] Averaged stats: lr: 0.000099  combined_loss: [local: 0.6483 | reduced: 0.6550]
# [16:23:20.972312] !!!Start Test: DiffusionForensics_val 6
# [16:23:21.820637] Test: [1]  [0/6]  eta: 0:00:04    time: 0.8315  data: 0.6464  max mem: 5721
# [16:23:24.231055] Test: [1]  [5/6]  eta: 0:00:00    time: 0.5399  data: 0.4233  max mem: 5721
# [16:23:24.270540] Test: [1] Total time: 0:00:03 (0.5483 s / it)
# [16:23:24.285595] ---syncronized---
# [16:23:24.285703] image-level F1 reduced_count 1
# [16:23:24.285805] image-level F1 reduced_sum 0.4318181872367859
# [16:23:24.285906] image-level AUC reduced_count 1
# [16:23:24.286008] image-level AUC reduced_sum 0.55078125
# [16:23:24.286110] ---syncronized done ---
# [16:23:24.619130] Averaged stats: image-level F1: [local: 0.4318 | reduced: 0.4318]  image-level AUC: [local: 0.5508 | reduced: 0.5508]
# [16:23:24.762714] Best image-level F1 image-level AUC = 0.49129971861839294
# [16:23:25.794201] Auto Mixed Precision (AMP) is disabled.
# [16:23:25.794883] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:23:28.189738] Epoch: [2]  [ 0/31]  eta: 0:01:14  lr: 0.000099  combined_loss: [local: 0.5902 | reduced: 0.5902]  time: 2.3936  data: 0.9403  max mem: 5721
# [16:23:47.502224] Epoch: [2]  [20/31]  eta: 0:00:11  lr: 0.000098  combined_loss: [local: 0.5802 | reduced: 0.5688]  time: 0.9655  data: 0.0004  max mem: 5721
# [16:23:56.546573] Epoch: [2]  [30/31]  eta: 0:00:00  lr: 0.000098  combined_loss: [local: 0.5506 | reduced: 0.5739]  time: 0.9088  data: 0.0004  max mem: 5721
# [16:23:56.605426] Epoch: [2] Total time: 0:00:30 (0.9939 s / it)
# [16:23:57.452676] Averaged stats: lr: 0.000098  combined_loss: [local: 0.5506 | reduced: 0.5739]
# [16:23:57.940172] !!!Start Test: DiffusionForensics_val 6
# [16:23:58.287661] Test: [2]  [0/6]  eta: 0:00:02    time: 0.3426  data: 0.2786  max mem: 5721
# [16:23:58.813179] Test: [2]  [5/6]  eta: 0:00:00    time: 0.1445  data: 0.0713  max mem: 5721
# [16:23:58.853295] Test: [2] Total time: 0:00:00 (0.1518 s / it)
# [16:23:58.868777] ---syncronized---
# [16:23:58.868909] image-level F1 reduced_count 1
# [16:23:58.869004] image-level F1 reduced_sum 0.44999998807907104
# [16:23:58.869094] image-level AUC reduced_count 1
# [16:23:58.869183] image-level AUC reduced_sum 0.6048632218844985
# [16:23:58.869281] ---syncronized done ---
# [16:23:59.243329] Averaged stats: image-level F1: [local: 0.4500 | reduced: 0.4500]  image-level AUC: [local: 0.6049 | reduced: 0.6049]
# [16:23:59.397871] Best image-level F1 image-level AUC = 0.5274316049817848
# [16:24:00.378192] Auto Mixed Precision (AMP) is disabled.
# [16:24:00.379101] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:24:03.008900] Epoch: [3]  [ 0/31]  eta: 0:01:21  lr: 0.000098  combined_loss: [local: 0.4175 | reduced: 0.4175]  time: 2.6287  data: 0.8317  max mem: 5721
# [16:24:22.558582] Epoch: [3]  [20/31]  eta: 0:00:11  lr: 0.000096  combined_loss: [local: 0.4550 | reduced: 0.4583]  time: 0.9774  data: 0.0006  max mem: 5721
# [16:24:31.099746] Epoch: [3]  [30/31]  eta: 0:00:00  lr: 0.000095  combined_loss: [local: 0.4445 | reduced: 0.4566]  time: 0.9098  data: 0.0004  max mem: 5721
# [16:24:31.168076] Epoch: [3] Total time: 0:00:30 (0.9932 s / it)
# [16:24:32.073814] Averaged stats: lr: 0.000095  combined_loss: [local: 0.4445 | reduced: 0.4566]
# [16:24:32.082609] !!!Start Test: DiffusionForensics_val 6
# [16:24:33.100447] Test: [3]  [0/6]  eta: 0:00:06    time: 1.0087  data: 0.7034  max mem: 5721
# [16:24:34.105271] Test: [3]  [5/6]  eta: 0:00:00    time: 0.3354  data: 0.1218  max mem: 5721
# [16:24:34.232028] Test: [3] Total time: 0:00:02 (0.3578 s / it)
# [16:24:34.264030] ---syncronized---
# [16:24:34.264151] image-level F1 reduced_count 1
# [16:24:34.264253] image-level F1 reduced_sum 0.4878048598766327
# [16:24:34.264361] image-level AUC reduced_count 1
# [16:24:34.264463] image-level AUC reduced_sum 0.60546875
# [16:24:34.264636] ---syncronized done ---
# [16:24:34.621948] Averaged stats: image-level F1: [local: 0.4878 | reduced: 0.4878]  image-level AUC: [local: 0.6055 | reduced: 0.6055]
# [16:24:34.750241] Best image-level F1 image-level AUC = 0.5466368049383163
# [16:24:35.796392] Auto Mixed Precision (AMP) is disabled.
# [16:24:35.796944] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:24:38.046206] Epoch: [4]  [ 0/31]  eta: 0:01:09  lr: 0.000095  combined_loss: [local: 0.4670 | reduced: 0.4670]  time: 2.2481  data: 0.7613  max mem: 5721
# [16:24:57.584901] Epoch: [4]  [20/31]  eta: 0:00:11  lr: 0.000092  combined_loss: [local: 0.3796 | reduced: 0.3871]  time: 0.9769  data: 0.0003  max mem: 5721
# [16:25:06.735579] Epoch: [4]  [30/31]  eta: 0:00:00  lr: 0.000091  combined_loss: [local: 0.3730 | reduced: 0.3803]  time: 0.9218  data: 0.0004  max mem: 5721
# [16:25:06.780401] Epoch: [4] Total time: 0:00:30 (0.9995 s / it)
# [16:25:07.592370] Averaged stats: lr: 0.000091  combined_loss: [local: 0.3730 | reduced: 0.3803]
# [16:25:08.149435] !!!Start Test: DiffusionForensics_val 6
# [16:25:08.500985] Test: [4]  [0/6]  eta: 0:00:02    time: 0.3481  data: 0.2923  max mem: 5721
# [16:25:09.033438] Test: [4]  [5/6]  eta: 0:00:00    time: 0.1466  data: 0.0712  max mem: 5721
# [16:25:09.075972] Test: [4] Total time: 0:00:00 (0.1541 s / it)
# [16:25:09.090585] ---syncronized---
# [16:25:09.090709] image-level F1 reduced_count 1
# [16:25:09.090814] image-level F1 reduced_sum 0.5194805264472961
# [16:25:09.090916] image-level AUC reduced_count 1
# [16:25:09.091015] image-level AUC reduced_sum 0.6213634389926183
# [16:25:09.091123] ---syncronized done ---
# [16:25:09.456010] Averaged stats: image-level F1: [local: 0.5195 | reduced: 0.5195]  image-level AUC: [local: 0.6214 | reduced: 0.6214]
# [16:25:09.594459] Best image-level F1 image-level AUC = 0.5704219827199573
# [16:25:10.560324] Auto Mixed Precision (AMP) is disabled.
# [16:25:10.560813] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:25:12.660111] Epoch: [5]  [ 0/31]  eta: 0:01:05  lr: 0.000091  combined_loss: [local: 0.3273 | reduced: 0.3273]  time: 2.0981  data: 0.6624  max mem: 5721
# [16:25:32.488915] Epoch: [5]  [20/31]  eta: 0:00:11  lr: 0.000087  combined_loss: [local: 0.2835 | reduced: 0.2926]  time: 0.9914  data: 0.0005  max mem: 5721
# [16:25:41.133392] Epoch: [5]  [30/31]  eta: 0:00:00  lr: 0.000086  combined_loss: [local: 0.2835 | reduced: 0.2900]  time: 0.9153  data: 0.0003  max mem: 5721
# [16:25:41.178312] Epoch: [5] Total time: 0:00:30 (0.9877 s / it)
# [16:25:42.037795] Averaged stats: lr: 0.000086  combined_loss: [local: 0.2835 | reduced: 0.2900]
# [16:25:42.046613] !!!Start Test: DiffusionForensics_val 6
# [16:25:42.872513] Test: [5]  [0/6]  eta: 0:00:04    time: 0.8120  data: 0.5911  max mem: 5721
# [16:25:43.746975] Test: [5]  [5/6]  eta: 0:00:00    time: 0.2797  data: 0.1010  max mem: 5721
# [16:25:43.869881] Test: [5] Total time: 0:00:01 (0.3035 s / it)
# [16:25:43.909283] ---syncronized---
# [16:25:43.909435] image-level F1 reduced_count 1
# [16:25:43.909594] image-level F1 reduced_sum 0.4444444477558136
# [16:25:43.915562] image-level AUC reduced_count 1
# [16:25:43.915699] image-level AUC reduced_sum 0.6326530612244898
# [16:25:43.915822] ---syncronized done ---
# [16:25:44.881247] Averaged stats: image-level F1: [local: 0.4444 | reduced: 0.4444]  image-level AUC: [local: 0.6327 | reduced: 0.6327]
# [16:25:44.887875] Average image-level F1 image-level AUC = 0.5385487544901517
# [16:25:45.510629] Auto Mixed Precision (AMP) is disabled.
# [16:25:45.511122] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:25:47.565145] Epoch: [6]  [ 0/31]  eta: 0:01:03  lr: 0.000085  combined_loss: [local: 0.1204 | reduced: 0.1204]  time: 2.0529  data: 0.6368  max mem: 5721
# [16:26:06.871689] Epoch: [6]  [20/31]  eta: 0:00:11  lr: 0.000082  combined_loss: [local: 0.2479 | reduced: 0.2386]  time: 0.9653  data: 0.0003  max mem: 5721
# [16:26:15.818861] Epoch: [6]  [30/31]  eta: 0:00:00  lr: 0.000080  combined_loss: [local: 0.2242 | reduced: 0.2431]  time: 0.9401  data: 0.0003  max mem: 5721
# [16:26:15.865095] Epoch: [6] Total time: 0:00:30 (0.9792 s / it)
# [16:26:16.744401] Averaged stats: lr: 0.000080  combined_loss: [local: 0.2242 | reduced: 0.2431]
# [16:26:17.187313] !!!Start Test: DiffusionForensics_val 6
# [16:26:17.550280] Test: [6]  [0/6]  eta: 0:00:02    time: 0.3590  data: 0.2878  max mem: 5721
# [16:26:18.089669] Test: [6]  [5/6]  eta: 0:00:00    time: 0.1496  data: 0.0662  max mem: 5721
# [16:26:18.131860] Test: [6] Total time: 0:00:00 (0.1571 s / it)
# [16:26:18.147873] ---syncronized---
# [16:26:18.148009] image-level F1 reduced_count 1
# [16:26:18.148177] image-level F1 reduced_sum 0.4931507408618927
# [16:26:18.148299] image-level AUC reduced_count 1
# [16:26:18.148445] image-level AUC reduced_sum 0.6643508467216674
# [16:26:18.148620] ---syncronized done ---
# [16:26:18.475224] Averaged stats: image-level F1: [local: 0.4932 | reduced: 0.4932]  image-level AUC: [local: 0.6644 | reduced: 0.6644]
# [16:26:18.513134] Best image-level F1 image-level AUC = 0.5787507937917801
# [16:26:19.611337] Auto Mixed Precision (AMP) is disabled.
# [16:26:19.611825] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:26:22.039634] Epoch: [7]  [ 0/31]  eta: 0:01:15  lr: 0.000080  combined_loss: [local: 0.1125 | reduced: 0.1125]  time: 2.4266  data: 0.9568  max mem: 5721
# [16:26:42.137804] Epoch: [7]  [20/31]  eta: 0:00:11  lr: 0.000075  combined_loss: [local: 0.1661 | reduced: 0.1816]  time: 1.0048  data: 0.0005  max mem: 5721
# [16:26:50.986716] Epoch: [7]  [30/31]  eta: 0:00:01  lr: 0.000073  combined_loss: [local: 0.1778 | reduced: 0.1806]  time: 0.9293  data: 0.0002  max mem: 5721
# [16:26:51.049319] Epoch: [7] Total time: 0:00:31 (1.0141 s / it)
# [16:26:51.875000] Averaged stats: lr: 0.000073  combined_loss: [local: 0.1778 | reduced: 0.1806]
# [16:26:52.418949] !!!Start Test: DiffusionForensics_val 6
# [16:26:52.755951] Test: [7]  [0/6]  eta: 0:00:01    time: 0.3325  data: 0.2646  max mem: 5721
# [16:26:53.318655] Test: [7]  [5/6]  eta: 0:00:00    time: 0.1490  data: 0.0659  max mem: 5721
# [16:26:53.395078] Test: [7] Total time: 0:00:00 (0.1624 s / it)
# [16:26:53.402542] ---syncronized---
# [16:26:53.402717] image-level F1 reduced_count 1
# [16:26:53.402867] image-level F1 reduced_sum 0.375
# [16:26:53.402993] image-level AUC reduced_count 1
# [16:26:53.403113] image-level AUC reduced_sum 0.654513888888889
# [16:26:53.403235] ---syncronized done ---
# [16:26:53.909564] Averaged stats: image-level F1: [local: 0.3750 | reduced: 0.3750]  image-level AUC: [local: 0.6545 | reduced: 0.6545]
# [16:26:53.910357] Average image-level F1 image-level AUC = 0.5147569444444444
# [16:26:54.676123] Auto Mixed Precision (AMP) is disabled.
# [16:26:54.676632] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:26:57.230713] Epoch: [8]  [ 0/31]  eta: 0:01:19  lr: 0.000073  combined_loss: [local: 0.1671 | reduced: 0.1671]  time: 2.5522  data: 0.7855  max mem: 5721
# [16:27:16.568120] Epoch: [8]  [20/31]  eta: 0:00:11  lr: 0.000069  combined_loss: [local: 0.1600 | reduced: 0.1602]  time: 0.9668  data: 0.0003  max mem: 5721
# [16:27:25.378370] Epoch: [8]  [30/31]  eta: 0:00:00  lr: 0.000066  combined_loss: [local: 0.1664 | reduced: 0.1633]  time: 0.9363  data: 0.0003  max mem: 5721
# [16:27:25.439057] Epoch: [8] Total time: 0:00:30 (0.9923 s / it)
# [16:27:26.324704] Averaged stats: lr: 0.000066  combined_loss: [local: 0.1664 | reduced: 0.1633]
# [16:27:26.870077] !!!Start Test: DiffusionForensics_val 6
# [16:27:27.202051] Test: [8]  [0/6]  eta: 0:00:01    time: 0.3293  data: 0.2791  max mem: 5721
# [16:27:27.751226] Test: [8]  [5/6]  eta: 0:00:00    time: 0.1462  data: 0.0704  max mem: 5721
# [16:27:27.794071] Test: [8] Total time: 0:00:00 (0.1537 s / it)
# [16:27:27.810885] ---syncronized---
# [16:27:27.811017] image-level F1 reduced_count 1
# [16:27:27.811128] image-level F1 reduced_sum 0.4000000059604645
# [16:27:27.811238] image-level AUC reduced_count 1
# [16:27:27.811352] image-level AUC reduced_sum 0.640625
# [16:27:27.811470] ---syncronized done ---
# [16:27:28.156545] Averaged stats: image-level F1: [local: 0.4000 | reduced: 0.4000]  image-level AUC: [local: 0.6406 | reduced: 0.6406]
# [16:27:28.300021] Average image-level F1 image-level AUC = 0.5203125029802322
# [16:27:28.522200] Auto Mixed Precision (AMP) is disabled.
# [16:27:28.522637] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:27:30.585963] Epoch: [9]  [ 0/31]  eta: 0:01:03  lr: 0.000066  combined_loss: [local: 0.2120 | reduced: 0.2120]  time: 2.0621  data: 0.5185  max mem: 5721
# [16:27:49.735681] Epoch: [9]  [20/31]  eta: 0:00:11  lr: 0.000061  combined_loss: [local: 0.1110 | reduced: 0.1475]  time: 0.9574  data: 0.0004  max mem: 5721
# [16:27:58.969573] Epoch: [9]  [30/31]  eta: 0:00:00  lr: 0.000059  combined_loss: [local: 0.1275 | reduced: 0.1439]  time: 0.9299  data: 0.0004  max mem: 5721
# [16:27:59.016114] Epoch: [9] Total time: 0:00:30 (0.9837 s / it)
# [16:27:59.931445] Averaged stats: lr: 0.000059  combined_loss: [local: 0.1275 | reduced: 0.1439]
# [16:28:00.159248] !!!Start Test: DiffusionForensics_val 6
# [16:28:00.814123] Test: [9]  [0/6]  eta: 0:00:03    time: 0.6512  data: 0.4281  max mem: 5721
# [16:28:01.321194] Test: [9]  [5/6]  eta: 0:00:00    time: 0.1915  data: 0.0716  max mem: 5721
# [16:28:01.363950] Test: [9] Total time: 0:00:01 (0.2003 s / it)
# [16:28:01.380482] ---syncronized---
# [16:28:01.380630] image-level F1 reduced_count 1
# [16:28:01.380736] image-level F1 reduced_sum 0.4225352108478546
# [16:28:01.380842] image-level AUC reduced_count 1
# [16:28:01.380942] image-level AUC reduced_sum 0.6241319444444444
# [16:28:01.381043] ---syncronized done ---
# [16:28:01.729337] Averaged stats: image-level F1: [local: 0.4225 | reduced: 0.4225]  image-level AUC: [local: 0.6241 | reduced: 0.6241]
# [16:28:01.877851] Average image-level F1 image-level AUC = 0.5233335776461495
# [16:28:02.028218] Auto Mixed Precision (AMP) is disabled.
# [16:28:02.028661] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:28:03.974581] Epoch: [10]  [ 0/31]  eta: 0:01:00  lr: 0.000059  combined_loss: [local: 0.0991 | reduced: 0.0991]  time: 1.9448  data: 0.5243  max mem: 5721
# [16:28:23.954654] Epoch: [10]  [20/31]  eta: 0:00:11  lr: 0.000054  combined_loss: [local: 0.0967 | reduced: 0.1146]  time: 0.9989  data: 0.0003  max mem: 5721
# [16:28:32.712124] Epoch: [10]  [30/31]  eta: 0:00:00  lr: 0.000052  combined_loss: [local: 0.1058 | reduced: 0.1174]  time: 0.9356  data: 0.0003  max mem: 5721
# [16:28:32.777618] Epoch: [10] Total time: 0:00:30 (0.9919 s / it)
# [16:28:33.813679] Averaged stats: lr: 0.000052  combined_loss: [local: 0.1058 | reduced: 0.1174]
# [16:28:33.815493] !!!Start Test: DiffusionForensics_val 6
# [16:28:34.653148] Test: [10]  [0/6]  eta: 0:00:04    time: 0.8231  data: 0.5528  max mem: 5721
# [16:28:35.602611] Test: [10]  [5/6]  eta: 0:00:00    time: 0.2939  data: 0.0965  max mem: 5721
# [16:28:35.745501] Test: [10] Total time: 0:00:01 (0.3201 s / it)
# [16:28:36.198213] ---syncronized---
# [16:28:36.198387] image-level F1 reduced_count 1
# [16:28:36.198533] image-level F1 reduced_sum 0.45945945382118225
# [16:28:36.198660] image-level AUC reduced_count 1
# [16:28:36.198775] image-level AUC reduced_sum 0.6636284722222222
# [16:28:36.198891] ---syncronized done ---
# [16:28:36.712625] Averaged stats: image-level F1: [local: 0.4595 | reduced: 0.4595]  image-level AUC: [local: 0.6636 | reduced: 0.6636]
# [16:28:36.713592] Average image-level F1 image-level AUC = 0.5615439630217023
# [16:28:37.193138] Auto Mixed Precision (AMP) is disabled.
# [16:28:37.193970] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:28:39.182931] Epoch: [11]  [ 0/31]  eta: 0:01:01  lr: 0.000051  combined_loss: [local: 0.0836 | reduced: 0.0836]  time: 1.9878  data: 0.4998  max mem: 5721
# [16:28:58.448323] Epoch: [11]  [20/31]  eta: 0:00:11  lr: 0.000047  combined_loss: [local: 0.0592 | reduced: 0.0839]  time: 0.9632  data: 0.0004  max mem: 5721
# [16:29:07.765642] Epoch: [11]  [30/31]  eta: 0:00:00  lr: 0.000044  combined_loss: [local: 0.0969 | reduced: 0.0967]  time: 0.9548  data: 0.0004  max mem: 5721
# [16:29:07.813173] Epoch: [11] Total time: 0:00:30 (0.9877 s / it)
# [16:29:08.590784] Averaged stats: lr: 0.000044  combined_loss: [local: 0.0969 | reduced: 0.0967]
# [16:29:09.204369] !!!Start Test: DiffusionForensics_val 6
# [16:29:09.549613] Test: [11]  [0/6]  eta: 0:00:02    time: 0.3424  data: 0.2748  max mem: 5721
# [16:29:10.123701] Test: [11]  [5/6]  eta: 0:00:00    time: 0.1526  data: 0.0553  max mem: 5721
# [16:29:10.167830] Test: [11] Total time: 0:00:00 (0.1603 s / it)
# [16:29:10.185533] ---syncronized---
# [16:29:10.185658] image-level F1 reduced_count 1
# [16:29:10.185772] image-level F1 reduced_sum 0.48000001907348633
# [16:29:10.185887] image-level AUC reduced_count 1
# [16:29:10.185996] image-level AUC reduced_sum 0.6396005210594877
# [16:29:10.186107] ---syncronized done ---
# [16:29:10.570862] Averaged stats: image-level F1: [local: 0.4800 | reduced: 0.4800]  image-level AUC: [local: 0.6396 | reduced: 0.6396]
# [16:29:10.699133] Average image-level F1 image-level AUC = 0.559800270066487
# [16:29:10.930464] Auto Mixed Precision (AMP) is disabled.
# [16:29:10.930895] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:29:12.877772] Epoch: [12]  [ 0/31]  eta: 0:01:00  lr: 0.000044  combined_loss: [local: 0.0761 | reduced: 0.0761]  time: 1.9457  data: 0.5170  max mem: 5721
# [16:29:32.310866] Epoch: [12]  [20/31]  eta: 0:00:11  lr: 0.000039  combined_loss: [local: 0.0806 | reduced: 0.0937]  time: 0.9716  data: 0.0003  max mem: 5721
# [16:29:41.448320] Epoch: [12]  [30/31]  eta: 0:00:00  lr: 0.000037  combined_loss: [local: 0.0742 | reduced: 0.0911]  time: 0.9400  data: 0.0003  max mem: 5721
# [16:29:41.494558] Epoch: [12] Total time: 0:00:30 (0.9859 s / it)
# [16:29:42.353426] Averaged stats: lr: 0.000037  combined_loss: [local: 0.0742 | reduced: 0.0911]
# [16:29:42.800194] !!!Start Test: DiffusionForensics_val 6
# [16:29:43.251336] Test: [12]  [0/6]  eta: 0:00:02    time: 0.4465  data: 0.3895  max mem: 5721
# [16:29:43.782711] Test: [12]  [5/6]  eta: 0:00:00    time: 0.1628  data: 0.0853  max mem: 5721
# [16:29:43.830033] Test: [12] Total time: 0:00:01 (0.1712 s / it)
# [16:29:43.845861] ---syncronized---
# [16:29:43.846002] image-level F1 reduced_count 1
# [16:29:43.846131] image-level F1 reduced_sum 0.4117646813392639
# [16:29:43.846259] image-level AUC reduced_count 1
# [16:29:43.846393] image-level AUC reduced_sum 0.6052974381241858
# [16:29:43.846554] ---syncronized done ---
# [16:29:44.302608] Averaged stats: image-level F1: [local: 0.4118 | reduced: 0.4118]  image-level AUC: [local: 0.6053 | reduced: 0.6053]
# [16:29:44.303381] Average image-level F1 image-level AUC = 0.5085310597317249
# [16:29:45.013326] Auto Mixed Precision (AMP) is disabled.
# [16:29:45.015364] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:29:47.830183] Epoch: [13]  [ 0/31]  eta: 0:01:27  lr: 0.000037  combined_loss: [local: 0.0418 | reduced: 0.0418]  time: 2.8134  data: 0.7254  max mem: 5721
# [16:30:07.328218] Epoch: [13]  [20/31]  eta: 0:00:11  lr: 0.000033  combined_loss: [local: 0.0659 | reduced: 0.0808]  time: 0.9748  data: 0.0003  max mem: 5721
# [16:30:16.155568] Epoch: [13]  [30/31]  eta: 0:00:01  lr: 0.000031  combined_loss: [local: 0.0538 | reduced: 0.0810]  time: 0.9393  data: 0.0003  max mem: 5721
# [16:30:16.210543] Epoch: [13] Total time: 0:00:31 (1.0063 s / it)
# [16:30:17.166354] Averaged stats: lr: 0.000031  combined_loss: [local: 0.0538 | reduced: 0.0810]
# [16:30:17.765220] !!!Start Test: DiffusionForensics_val 6
# [16:30:18.118099] Test: [13]  [0/6]  eta: 0:00:02    time: 0.3498  data: 0.2763  max mem: 5721
# [16:30:18.677840] Test: [13]  [5/6]  eta: 0:00:00    time: 0.1514  data: 0.0511  max mem: 5721
# [16:30:18.721961] Test: [13] Total time: 0:00:00 (0.1591 s / it)
# [16:30:18.736579] ---syncronized---
# [16:30:18.736712] image-level F1 reduced_count 1
# [16:30:18.736813] image-level F1 reduced_sum 0.4179104268550873
# [16:30:18.736914] image-level AUC reduced_count 1
# [16:30:18.737011] image-level AUC reduced_sum 0.6313504125054277
# [16:30:18.737116] ---syncronized done ---
# [16:30:19.095711] Averaged stats: image-level F1: [local: 0.4179 | reduced: 0.4179]  image-level AUC: [local: 0.6314 | reduced: 0.6314]
# [16:30:19.239210] Average image-level F1 image-level AUC = 0.5246304196802575
# [16:30:19.483187] Auto Mixed Precision (AMP) is disabled.
# [16:30:19.483670] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:30:21.461006] Epoch: [14]  [ 0/31]  eta: 0:01:01  lr: 0.000030  combined_loss: [local: 0.0735 | reduced: 0.0735]  time: 1.9762  data: 0.5195  max mem: 5721
# [16:30:40.747655] Epoch: [14]  [20/31]  eta: 0:00:11  lr: 0.000027  combined_loss: [local: 0.0559 | reduced: 0.0654]  time: 0.9643  data: 0.0003  max mem: 5721
# [16:30:50.030798] Epoch: [14]  [30/31]  eta: 0:00:00  lr: 0.000025  combined_loss: [local: 0.0559 | reduced: 0.0641]  time: 0.9370  data: 0.0004  max mem: 5721
# [16:30:50.074876] Epoch: [14] Total time: 0:00:30 (0.9868 s / it)
# [16:30:51.012388] Averaged stats: lr: 0.000025  combined_loss: [local: 0.0559 | reduced: 0.0641]
# [16:30:51.483045] !!!Start Test: DiffusionForensics_val 6
# [16:30:51.824432] Test: [14]  [0/6]  eta: 0:00:02    time: 0.3387  data: 0.2923  max mem: 5721
# [16:30:52.400864] Test: [14]  [5/6]  eta: 0:00:00    time: 0.1524  data: 0.0752  max mem: 5721
# [16:30:52.444487] Test: [14] Total time: 0:00:00 (0.1600 s / it)
# [16:30:52.460060] ---syncronized---
# [16:30:52.460173] image-level F1 reduced_count 1
# [16:30:52.460286] image-level F1 reduced_sum 0.45714282989501953
# [16:30:52.460392] image-level AUC reduced_count 1
# [16:30:52.460506] image-level AUC reduced_sum 0.6475694444444444
# [16:30:52.460610] ---syncronized done ---
# [16:30:52.813305] Averaged stats: image-level F1: [local: 0.4571 | reduced: 0.4571]  image-level AUC: [local: 0.6476 | reduced: 0.6476]
# [16:30:52.941826] Average image-level F1 image-level AUC = 0.552356137169732
# [16:30:53.125230] Auto Mixed Precision (AMP) is disabled.
# [16:30:53.125715] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:30:55.045947] Epoch: [15]  [ 0/31]  eta: 0:00:59  lr: 0.000025  combined_loss: [local: 0.0821 | reduced: 0.0821]  time: 1.9187  data: 0.5043  max mem: 5721
# [16:31:14.750711] Epoch: [15]  [20/31]  eta: 0:00:11  lr: 0.000021  combined_loss: [local: 0.0646 | reduced: 0.0688]  time: 0.9852  data: 0.0005  max mem: 5721
# [16:31:23.608621] Epoch: [15]  [30/31]  eta: 0:00:00  lr: 0.000020  combined_loss: [local: 0.0695 | reduced: 0.0728]  time: 0.9321  data: 0.0003  max mem: 5721
# [16:31:23.660625] Epoch: [15] Total time: 0:00:30 (0.9850 s / it)
# [16:31:24.561909] Averaged stats: lr: 0.000020  combined_loss: [local: 0.0695 | reduced: 0.0728]
# [16:31:24.570843] !!!Start Test: DiffusionForensics_val 6
# [16:31:25.491310] Test: [15]  [0/6]  eta: 0:00:05    time: 0.9165  data: 0.6687  max mem: 5721
# [16:31:26.784381] Test: [15]  [5/6]  eta: 0:00:00    time: 0.3668  data: 0.1214  max mem: 5721
# [16:31:26.908175] Test: [15] Total time: 0:00:02 (0.3891 s / it)
# [16:31:26.946052] ---syncronized---
# [16:31:26.946215] image-level F1 reduced_count 1
# [16:31:26.946366] image-level F1 reduced_sum 0.3692307770252228
# [16:31:26.946537] image-level AUC reduced_count 1
# [16:31:26.946679] image-level AUC reduced_sum 0.6579861111111112
# [16:31:26.946845] ---syncronized done ---
# [16:31:27.458406] Averaged stats: image-level F1: [local: 0.3692 | reduced: 0.3692]  image-level AUC: [local: 0.6580 | reduced: 0.6580]
# [16:31:27.459202] Average image-level F1 image-level AUC = 0.513608444068167
# [16:31:28.083062] Auto Mixed Precision (AMP) is disabled.
# [16:31:28.083575] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:31:30.069314] Epoch: [16]  [ 0/31]  eta: 0:01:01  lr: 0.000019  combined_loss: [local: 0.0932 | reduced: 0.0932]  time: 1.9841  data: 0.5135  max mem: 5721
# [16:31:49.396939] Epoch: [16]  [20/31]  eta: 0:00:11  lr: 0.000017  combined_loss: [local: 0.0454 | reduced: 0.0685]  time: 0.9663  data: 0.0004  max mem: 5721
# [16:31:58.581511] Epoch: [16]  [30/31]  eta: 0:00:00  lr: 0.000016  combined_loss: [local: 0.0572 | reduced: 0.0732]  time: 0.9471  data: 0.0003  max mem: 5721
# [16:31:58.628490] Epoch: [16] Total time: 0:00:30 (0.9853 s / it)
# [16:31:59.542348] Averaged stats: lr: 0.000016  combined_loss: [local: 0.0572 | reduced: 0.0732]
# [16:31:59.972760] !!!Start Test: DiffusionForensics_val 6
# [16:32:00.309379] Test: [16]  [0/6]  eta: 0:00:02    time: 0.3335  data: 0.2771  max mem: 5721
# [16:32:00.874591] Test: [16]  [5/6]  eta: 0:00:00    time: 0.1494  data: 0.0708  max mem: 5721
# [16:32:00.917794] Test: [16] Total time: 0:00:00 (0.1572 s / it)
# [16:32:00.934126] ---syncronized---
# [16:32:00.934240] image-level F1 reduced_count 1
# [16:32:00.934339] image-level F1 reduced_sum 0.4571428596973419
# [16:32:00.934441] image-level AUC reduced_count 1
# [16:32:00.934580] image-level AUC reduced_sum 0.6404689535388624
# [16:32:00.934685] ---syncronized done ---
# [16:32:01.308691] Averaged stats: image-level F1: [local: 0.4571 | reduced: 0.4571]  image-level AUC: [local: 0.6405 | reduced: 0.6405]
# [16:32:01.447194] Average image-level F1 image-level AUC = 0.5488059066181021
# [16:32:01.693550] Auto Mixed Precision (AMP) is disabled.
# [16:32:01.693955] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:32:03.600196] Epoch: [17]  [ 0/31]  eta: 0:00:59  lr: 0.000015  combined_loss: [local: 0.0688 | reduced: 0.0688]  time: 1.9050  data: 0.5168  max mem: 5721
# [16:32:23.382542] Epoch: [17]  [20/31]  eta: 0:00:11  lr: 0.000013  combined_loss: [local: 0.0550 | reduced: 0.0847]  time: 0.9891  data: 0.0003  max mem: 5721
# [16:32:32.357302] Epoch: [17]  [30/31]  eta: 0:00:00  lr: 0.000013  combined_loss: [local: 0.0550 | reduced: 0.0768]  time: 0.9361  data: 0.0004  max mem: 5721
# [16:32:32.401530] Epoch: [17] Total time: 0:00:30 (0.9906 s / it)
# [16:32:33.208543] Averaged stats: lr: 0.000013  combined_loss: [local: 0.0550 | reduced: 0.0768]
# [16:32:33.430947] !!!Start Test: DiffusionForensics_val 6
# [16:32:34.180908] Test: [17]  [0/6]  eta: 0:00:04    time: 0.7460  data: 0.5780  max mem: 5721
# [16:32:34.747291] Test: [17]  [5/6]  eta: 0:00:00    time: 0.2185  data: 0.0965  max mem: 5721
# [16:32:34.808911] Test: [17] Total time: 0:00:01 (0.2292 s / it)
# [16:32:34.818343] ---syncronized---
# [16:32:34.818520] image-level F1 reduced_count 1
# [16:32:34.818629] image-level F1 reduced_sum 0.4864864647388458
# [16:32:34.818737] image-level AUC reduced_count 1
# [16:32:34.818841] image-level AUC reduced_sum 0.6508901432913591
# [16:32:34.818963] ---syncronized done ---
# [16:32:35.235428] Averaged stats: image-level F1: [local: 0.4865 | reduced: 0.4865]  image-level AUC: [local: 0.6509 | reduced: 0.6509]
# [16:32:35.236188] Average image-level F1 image-level AUC = 0.5686883040151025
# [16:32:36.002016] Auto Mixed Precision (AMP) is disabled.
# [16:32:36.003520] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:32:38.562344] Epoch: [18]  [ 0/31]  eta: 0:01:19  lr: 0.000012  combined_loss: [local: 0.1355 | reduced: 0.1355]  time: 2.5574  data: 0.7770  max mem: 5721
# [16:32:57.953644] Epoch: [18]  [20/31]  eta: 0:00:11  lr: 0.000011  combined_loss: [local: 0.0468 | reduced: 0.0660]  time: 0.9694  data: 0.0003  max mem: 5721
# [16:33:06.831971] Epoch: [18]  [30/31]  eta: 0:00:00  lr: 0.000011  combined_loss: [local: 0.0420 | reduced: 0.0592]  time: 0.9364  data: 0.0003  max mem: 5721
# [16:33:06.896948] Epoch: [18] Total time: 0:00:30 (0.9966 s / it)
# [16:33:07.805121] Averaged stats: lr: 0.000011  combined_loss: [local: 0.0420 | reduced: 0.0592]
# [16:33:08.360146] !!!Start Test: DiffusionForensics_val 6
# [16:33:08.670421] Test: [18]  [0/6]  eta: 0:00:01    time: 0.3074  data: 0.2531  max mem: 5721
# [16:33:09.230318] Test: [18]  [5/6]  eta: 0:00:00    time: 0.1444  data: 0.0634  max mem: 5721
# [16:33:09.276922] Test: [18] Total time: 0:00:00 (0.1525 s / it)
# [16:33:09.290189] ---syncronized---
# [16:33:09.290315] image-level F1 reduced_count 1
# [16:33:09.290416] image-level F1 reduced_sum 0.47887319326400757
# [16:33:09.290548] image-level AUC reduced_count 1
# [16:33:09.290643] image-level AUC reduced_sum 0.6480034722222221
# [16:33:09.290742] ---syncronized done ---
# [16:33:09.676947] Averaged stats: image-level F1: [local: 0.4789 | reduced: 0.4789]  image-level AUC: [local: 0.6480 | reduced: 0.6480]
# [16:33:09.815315] Average image-level F1 image-level AUC = 0.5634383327431148
# [16:33:09.982625] Auto Mixed Precision (AMP) is disabled.
# [16:33:09.983019] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train
# [16:33:11.917617] Epoch: [19]  [ 0/31]  eta: 0:00:59  lr: 0.000011  combined_loss: [local: 0.0197 | reduced: 0.0197]  time: 1.9335  data: 0.4887  max mem: 5721
# [16:33:31.324805] Epoch: [19]  [20/31]  eta: 0:00:11  lr: 0.000010  combined_loss: [local: 0.0322 | reduced: 0.0517]  time: 0.9703  data: 0.0003  max mem: 5721
# [16:33:40.685699] Epoch: [19]  [30/31]  eta: 0:00:00  lr: 0.000010  combined_loss: [local: 0.0523 | reduced: 0.0591]  time: 0.9408  data: 0.0003  max mem: 5721
# [16:33:40.729613] Epoch: [19] Total time: 0:00:30 (0.9918 s / it)
# [16:33:41.553648] Averaged stats: lr: 0.000010  combined_loss: [local: 0.0523 | reduced: 0.0591]
# [16:33:42.820005] !!!Start Test: DiffusionForensics_val 6
# [16:33:43.176565] Test: [19]  [0/6]  eta: 0:00:02    time: 0.3533  data: 0.2823  max mem: 5721
# [16:33:43.817105] Test: [19]  [5/6]  eta: 0:00:00    time: 0.1655  data: 0.0708  max mem: 5721
# [16:33:43.860447] Test: [19] Total time: 0:00:01 (0.1731 s / it)
# [16:33:43.876549] ---syncronized---
# [16:33:43.876667] image-level F1 reduced_count 1
# [16:33:43.876780] image-level F1 reduced_sum 0.4864864647388458
# [16:33:43.876895] image-level AUC reduced_count 1
# [16:33:43.877004] image-level AUC reduced_sum 0.6413373860182372
# [16:33:43.877115] ---syncronized done ---
# [16:33:44.179984] Averaged stats: image-level F1: [local: 0.4865 | reduced: 0.4865]  image-level AUC: [local: 0.6413 | reduced: 0.6413]
# [16:33:44.217124] Average image-level F1 image-level AUC = 0.5639119253785415
# [16:33:44.543187] Training time 0:15:43

# %%
# %matplotlib inline
import os, json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from IPython.display import Image, display

LOG_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train/log.txt"


def parse_forensichub_json_log(path):
    all_entries = []

    with open(path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            try:
                entry = json.loads(line)
            except json.JSONDecodeError:
                continue

            if "epoch" in entry:
                all_entries.append(entry)

    if not all_entries:
        raise RuntimeError(f"No JSON epoch entries found in {path}")

    # Use only the last run if the log contains restarted runs
    runs = []
    current_run = []
    prev_epoch = -1

    for entry in all_entries:
        ep = int(entry.get("epoch", 0))

        if ep <= prev_epoch and current_run:
            runs.append(current_run)
            current_run = []

        current_run.append(entry)
        prev_epoch = ep

    if current_run:
        runs.append(current_run)

    entries = runs[-1]

    # Match Effort style: display epochs as 1-based
    epochs = [int(e["epoch"]) + 1 for e in entries]

    train_losses = [
        float(e.get("train_overall", e.get("train_combined_loss", np.nan)))
        for e in entries
    ]

    real_losses = [
        float(e.get("train_real_loss", np.nan))
        for e in entries
    ]

    fake_losses = [
        float(e.get("train_fake_loss", np.nan))
        for e in entries
    ]

    lrs = [
        float(e.get("train_lr", np.nan))
        for e in entries
    ]

    test_aucs = [
        float(e.get("test_image-level AUC", np.nan))
        for e in entries
    ]

    test_f1s = [
        float(e.get("test_image-level F1", np.nan))
        for e in entries
    ]

    return epochs, train_losses, real_losses, fake_losses, lrs, test_aucs, test_f1s, len(runs)


def plot_training(path):
    epochs, losses, real_losses, fake_losses, lrs, aucs, f1s, n_runs = parse_forensichub_json_log(path)

    aucs_np = np.array(aucs, dtype=float)
    f1s_np = np.array(f1s, dtype=float)

    best_auc_idx = int(np.nanargmax(aucs_np))

    best_auc_epoch = epochs[best_auc_idx]
    best_auc = aucs[best_auc_idx]
    f1_at_best_auc = f1s[best_auc_idx]

    print(f"Best AUC: {best_auc:.4f} at epoch {best_auc_epoch}")
    print(f"F1 at best AUC epoch: {f1_at_best_auc:.4f} at epoch {best_auc_epoch}")

    fig, axes = plt.subplots(1, 4, figsize=(22, 4.8))
    fig.patch.set_facecolor("#FAFAFA")

    for ax in axes:
        ax.set_facecolor("#F4F4F4")
        ax.spines[["top", "right"]].set_visible(False)
        ax.spines[["left", "bottom"]].set_color("#CCCCCC")
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # 1. Training losses
    ax = axes[0]
    ax.plot(epochs, losses, marker="o", linewidth=2, markersize=5, label="Overall loss")

    if not np.all(np.isnan(real_losses)):
        ax.plot(epochs, real_losses, marker="s", linewidth=1.8, markersize=4, label="Real loss")

    if not np.all(np.isnan(fake_losses)):
        ax.plot(epochs, fake_losses, marker="^", linewidth=1.8, markersize=4, label="Fake loss")

    ax.set_title("Training losses", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9, framealpha=0.5)

    # 2. Validation AUC
    ax = axes[1]
    ax.plot(epochs, aucs, marker="D", linewidth=2, markersize=5, label="Val AUC")
    ax.fill_between(epochs, 0.5, aucs, alpha=0.15)
    ax.scatter(best_auc_epoch, best_auc, s=90, zorder=5, label="Best AUC")
    ax.annotate(
        f"Best AUC: {best_auc:.4f}",
        xy=(best_auc_epoch, best_auc),
        xytext=(best_auc_epoch - max(epochs) * 0.12, best_auc + 0.08),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0.4, 1.05)
    ax.set_title("Validation AUC", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=9, framealpha=0.5)

    # 3. Validation F1 at best-AUC epoch
    ax = axes[2]
    ax.plot(epochs, f1s, marker="s", linewidth=2, markersize=5, label="Val F1")
    ax.scatter(best_auc_epoch, f1_at_best_auc, s=90, zorder=5, label="F1 at best-AUC epoch")
    ax.annotate(
        f"F1 @ best AUC: {f1_at_best_auc:.4f}",
        xy=(best_auc_epoch, f1_at_best_auc),
        xytext=(best_auc_epoch + max(epochs) * 0.12, f1_at_best_auc + 0.10),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0, 1.05)
    ax.set_title("Validation F1", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("F1")
    ax.legend(fontsize=9, framealpha=0.5)

    # 4. Learning rate
    ax = axes[3]
    ax.plot(epochs, lrs, marker="o", linewidth=2, markersize=5, label="Learning rate")
    ax.set_title("Learning rate schedule", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("LR")
    ax.ticklabel_format(style="sci", axis="y", scilimits=(0, 0))
    ax.legend(fontsize=9, framealpha=0.5)

    plt.suptitle(
        f"ForensicHub · SPSL on DiffusionForensics ({len(epochs)} epochs)",
        fontsize=14,
        y=1.03,
    )
    plt.tight_layout()

    out_path = "forensichub_spsl_training_curves.jpg"
    plt.savefig(out_path, dpi=100, bbox_inches="tight", facecolor=fig.get_facecolor())
    plt.close(fig)

    display(Image(out_path))


plot_training(LOG_PATH)
# Out:
# Best AUC: 0.6644 at epoch 7
# F1 at best AUC epoch: 0.4932 at epoch 7

# %%
# import sys, os

# base = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"
# print("DeepfakeBench exists:", os.path.exists(os.path.join(base, "DeepfakeBench")))
# print("ForensicHub exists:", os.path.exists(os.path.join(base, "ForensicHub")))

# sys.path.insert(0, base)
# sys.path.insert(0, os.path.join(base, "ForensicHub"))

# import DeepfakeBench
# print("DeepfakeBench import OK:", DeepfakeBench.__file__)

# %%
# Validation inference

import os
import json
import torch
from PIL import Image
from torchvision import transforms
import sys

BASE = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"

sys.path.insert(0, BASE)
sys.path.insert(0, os.path.join(BASE, "ForensicHub"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench"))
sys.path.insert(0, os.path.join(BASE, "IMDLBenCo"))

import ForensicHub.tasks.deepfake
from ForensicHub.registry import MODELS, build_from_registry

# ── Paths / constants ─────────────────────────────────────────────────────────
CHECKPOINT_DIR = f"{BASE}/ForensicHub/log/crossdataset_image_new/crossdataset_spsl_train"
VAL_JSON = "/content/DiffusionForensics_Recons/val.json"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
THRESHOLD = 0.5

# ── Step 1: find best epoch automatically from the log ────────────────────────
LOG_PATH = os.path.join(CHECKPOINT_DIR, "log.txt")

all_entries = []
with open(LOG_PATH) as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            entry = json.loads(line)
        except json.JSONDecodeError:
            continue

        if "epoch" in entry:
            all_entries.append(entry)

runs = []
current_run = []
prev_epoch = -1

for entry in all_entries:
    ep = int(entry.get("epoch", 0))

    if ep <= prev_epoch and current_run:
        runs.append(current_run)
        current_run = []

    current_run.append(entry)
    prev_epoch = ep

if current_run:
    runs.append(current_run)

if not runs:
    raise RuntimeError(f"No valid log runs found in {LOG_PATH}")

last_run = runs[-1]

# Choose best checkpoint by validation AUC
valid_auc_entries = [
    e for e in last_run
    if "test_image-level AUC" in e and e["test_image-level AUC"] is not None
]

if not valid_auc_entries:
    raise RuntimeError(f"No validation AUC entries found in last run of {LOG_PATH}")

best_entry = max(valid_auc_entries, key=lambda e: float(e["test_image-level AUC"]))

best_epoch = int(best_entry["epoch"])
best_auc = float(best_entry["test_image-level AUC"])
best_f1 = float(best_entry.get("test_image-level F1", float("nan")))

print(f"Best epoch from log by AUC: {best_epoch}")
print(f"Best val AUC: {best_auc:.6f}")
print(f"Val F1 at best-AUC epoch: {best_f1:.6f}")

# ── Step 2: select checkpoint ─────────────────────────────────────────────────
best_ckpt = os.path.join(CHECKPOINT_DIR, f"checkpoint-{best_epoch}.pth")

if not os.path.exists(best_ckpt):
    available = sorted(
        [
            f for f in os.listdir(CHECKPOINT_DIR)
            if f.startswith("checkpoint-") and f.endswith(".pth")
        ],
        key=lambda f: int(f.replace("checkpoint-", "").replace(".pth", ""))
    )

    if not available:
        raise FileNotFoundError(f"No checkpoint files found in {CHECKPOINT_DIR}")

    candidates = [
        f for f in available
        if int(f.replace("checkpoint-", "").replace(".pth", "")) <= best_epoch
    ]

    best_ckpt = os.path.join(
        CHECKPOINT_DIR,
        candidates[-1] if candidates else available[-1]
    )

print("Using checkpoint:")
print(best_ckpt)

# ── Step 3: build exact SPSL model from ForensicHub registry ──────────────────
model_args = {
    "name": "Spsl",
    "init_config": {
        "yaml_config_path": f"{BASE}/DeepfakeBench/DeepfakeBench/training/config/config/detector/spsl.yaml"
    }
}

model = build_from_registry(MODELS, model_args)

checkpoint = torch.load(best_ckpt, map_location=DEVICE, weights_only=False)
state_dict = checkpoint["model"] if "model" in checkpoint else checkpoint

missing, unexpected = model.load_state_dict(state_dict, strict=False)

print(f"Missing keys: {len(missing)}")
print(f"Unexpected keys: {len(unexpected)}")

if len(missing) > 0:
    print("First missing keys:", missing[:10])

if len(unexpected) > 0:
    print("First unexpected keys:", unexpected[:10])

model.to(DEVICE)
model.eval()

# ── Step 4: validation transform ──────────────────────────────────────────────
# SPSL / Xception-style preprocessing:
# image_size: usually 256
# norm_type: ImageNet

IMAGE_SIZE = 256

val_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
])

# ── Step 5: load validation items and run inference ───────────────────────────
with open(VAL_JSON) as f:
    val_items = json.load(f)

results = []
skipped = []

with torch.no_grad():
    for item in val_items:
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=DEVICE),
            }

            out_dict = model(**input_dict)

            prob = float(out_dict["pred_label"].view(-1)[0].item())
            pred = 1 if prob >= THRESHOLD else 0

            results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": prob,
                "correct": bool(pred == label),
                "checkpoint_epoch": best_epoch,
                "checkpoint_val_auc": best_auc,
                "checkpoint_val_f1": best_f1,
            })

        except Exception as e:
            skipped.append({
                "path": path,
                "error": str(e),
            })

if len(results) == 0:
    raise RuntimeError("No validation images were processed successfully.")

print(f"Processed: {len(results)}")
print(f"Skipped: {len(skipped)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# Best epoch from log by AUC: 6
# Best val AUC: 0.664351
# Val F1 at best-AUC epoch: 0.493151
# Using checkpoint:
# /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/spsl_train/checkpoint-6.pth
# [build_from_registry] Creating model 'Spsl' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/spsl.yaml'}
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/xception-43020ad28.pth" to /root/.cache/torch/hub/checkpoints/xception-43020ad28.pth
# Missing keys: 0
# Unexpected keys: 0
# Processed: 100
# Skipped: 0

# %%
# ── Inference on TRAINING set, SPSL model already loaded ──

import json
import torch
from PIL import Image
import numpy as np
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score

TRAIN_JSON = "/content/DiffusionForensics_Recons/train.json"
IMAGE_SIZE = 256   # SPSL preprocessing size

with open(TRAIN_JSON) as f:
    train_items = json.load(f)

print(f"Running inference on {len(train_items)} training images...")

train_results = []
train_skipped = []

with torch.no_grad():
    for i, item in enumerate(train_items):
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=DEVICE),
            }

            out_dict = model(**input_dict)

            prob = float(out_dict["pred_label"].view(-1)[0].item())
            pred = 1 if prob >= THRESHOLD else 0

            train_results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": prob,
                "correct": bool(pred == label),
            })

        except Exception as e:
            train_skipped.append({
                "path": path,
                "error": str(e),
            })

        if (i + 1) % 500 == 0:
            print(
                f"  {i+1}/{len(train_items)} processed | "
                f"ok={len(train_results)} | skipped={len(train_skipped)}"
            )

if len(train_results) == 0:
    raise RuntimeError("No training images were processed successfully.")

train_labels = np.array([r["true_label"] for r in train_results])
train_scores = np.array([r["confidence"] for r in train_results])
train_preds = np.array([r["pred"] for r in train_results])

train_acc = accuracy_score(train_labels, train_preds)
train_f1 = f1_score(train_labels, train_preds)
train_auc = roc_auc_score(train_labels, train_scores)

print("\n=== Train set results ===")
print(f"Processed: {len(train_results)}")
print(f"Skipped:   {len(train_skipped)}")
print(f"Train accuracy: {train_acc * 100:.2f}%")
print(f"Train F1:       {train_f1:.4f}")
print(f"Train AUC:      {train_auc:.4f}")

if len(train_skipped) > 0:
    print("\nFirst skipped examples:")
    for s in train_skipped[:5]:
        print(s)
# Out:
# Running inference on 1000 training images...
#   500/1000 processed | ok=500 | skipped=0
#   1000/1000 processed | ok=1000 | skipped=0
#
# === Train set results ===
# Processed: 1000
# Skipped:   0
# Train accuracy: 96.10%
# Train F1:       0.9603
# Train AUC:      0.9947

# %%
# ROC Curve: Validation only, SPSL

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score
from IPython.display import Image, display

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

# ── Validation ROC ──
y_true = np.array([r["true_label"] for r in results])
raw_score = np.array([r["confidence"] for r in results])

# Check whether score behaves like fake probability or real probability
auc_direct = roc_auc_score(y_true, raw_score)
auc_inverted = roc_auc_score(y_true, 1.0 - raw_score)

if auc_inverted > auc_direct:
    print("Score appears reversed. Using 1 - confidence as fake probability.")
    y_score = 1.0 - raw_score
    score_mode = "1 - confidence"
else:
    print("Score appears to be fake probability. Using confidence directly.")
    y_score = raw_score
    score_mode = "confidence"

fpr, tpr, thresh = roc_curve(y_true, y_score)
auc_val = auc(fpr, tpr)

# ── Plot ──
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor("#FAFAFA")

ax.set_facecolor("#F4F4F4")
ax.spines[["top", "right"]].set_visible(False)
ax.spines[["left", "bottom"]].set_color("#CCCCCC")
ax.set_aspect("equal")

ax.plot(fpr, tpr, color="#7B4FB5", linewidth=2.5, label="ROC curve")
ax.fill_between(fpr, tpr, alpha=0.25, color="#9B7FD4")

ax.text(
    0.55, 0.35,
    f"AUC = {auc_val:.2f}",
    fontsize=20,
    fontweight="bold",
    color="#5A3A8A",
    ha="center",
    va="center"
)

# Random baseline
ax.plot(
    [0, 1], [0, 1],
    color="#888",
    linestyle="--",
    linewidth=1,
    label="Random (0.50)"
)

# Best threshold using Youden index
opt_idx = np.argmax(tpr - fpr)

ax.scatter(
    fpr[opt_idx],
    tpr[opt_idx],
    color="#7B4FB5",
    s=100,
    zorder=5,
    edgecolors="white",
    linewidths=2
)

ax.annotate(
    f"Best: {thresh[opt_idx]:.3f}\nTPR={tpr[opt_idx]:.2f}, FPR={fpr[opt_idx]:.2f}",
    xy=(fpr[opt_idx], tpr[opt_idx]),
    xytext=(min(fpr[opt_idx] + 0.15, 0.75), max(tpr[opt_idx] - 0.12, 0.05)),
    fontsize=9,
    color="#5A3A8A",
    arrowprops=dict(arrowstyle="->", color="#7B4FB5", lw=1.5)
)

ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_xlabel("FPR", fontsize=12)
ax.set_ylabel("TPR", fontsize=12)
ax.set_title("ROC — Validation Set (SPSL)", fontsize=14, pad=12)

ax.legend(fontsize=10, loc="lower right", framealpha=0.5)

plt.tight_layout()
plt.savefig(
    "roc_val_spsl.jpg",
    dpi=80,
    bbox_inches="tight",
    facecolor=fig.get_facecolor()
)
plt.close(fig)

display(Image("roc_val_spsl.jpg"))

print(f"\nScore mode used: {score_mode}")
print(f"Validation AUC: {auc_val:.4f}")
print(f"AUC direct:     {auc_direct:.4f}")
print(f"AUC inverted:   {auc_inverted:.4f}")
print(f"Best threshold: {thresh[opt_idx]:.4f}")
# Out:
# Score appears to be fake probability. Using confidence directly.
# Score mode used: confidence
# Validation AUC: 0.6516
# AUC direct:     0.6516
# AUC inverted:   0.3484
# Best threshold: 0.2605

# %%
# ── Confusion Matrix: Validation only, SPSL — best-AUC checkpoint results ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score, accuracy_score, precision_score, recall_score
from IPython.display import Image, display

MODEL_NAME = "SPSL"

def compute_metrics(res):
    y_true = np.array([int(r["true_label"]) for r in res])
    y_pred = np.array([int(r["pred"]) for r in res])

    # Some cells use "confidence", others use "score"
    if "confidence" in res[0]:
        y_score = np.array([float(r["confidence"]) for r in res])
    elif "score" in res[0]:
        y_score = np.array([float(r["score"]) for r in res])
    else:
        raise KeyError("results must contain either 'confidence' or 'score'.")

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    TN, FP, FN, TP = cm.ravel()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    auc_direct = roc_auc_score(y_true, y_score)
    auc_inverted = roc_auc_score(y_true, 1.0 - y_score)

    # Use the direction that gives correct fake-probability ranking
    if auc_inverted > auc_direct:
        auc_val = auc_inverted
        score_mode = "1 - score"
    else:
        auc_val = auc_direct
        score_mode = "score"

    return TN, FP, FN, TP, accuracy, precision, recall, f1, auc_val, score_mode

def draw_cm(ax, TN, FP, FN, TP, title):
    cell_labels = [["TN", "FP"], ["FN", "TP"]]
    cell_values = [[TN, FP], [FN, TP]]
    cell_colors = [["#d4edda", "#f8d7da"],
                   ["#f8d7da", "#d4edda"]]

    for i in range(2):
        for j in range(2):
            ax.add_patch(
                plt.Rectangle(
                    (j, 1 - i), 1, 1,
                    facecolor=cell_colors[i][j],
                    edgecolor="black",
                    linewidth=1.5
                )
            )
            ax.text(
                j + 0.5,
                1 - i + 0.5,
                f"{cell_labels[i][j]}\n{cell_values[i][j]}",
                ha="center",
                va="center",
                fontsize=18,
                fontweight="bold",
                color="black"
            )

    ax.set_xlim(0, 2)
    ax.set_ylim(0, 2)
    ax.set_xticks([0.5, 1.5])
    ax.set_yticks([1.5, 0.5])

    ax.set_xticklabels(["Predicted REAL", "Predicted FAKE"], fontsize=10)
    ax.set_yticklabels(["REAL (0)", "FAKE (1)"], fontsize=10)

    ax.set_xlabel("Predicted label", fontsize=11, labelpad=8)
    ax.set_ylabel("True label", fontsize=11, labelpad=8)

    ax.tick_params(length=0)
    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_title(title, fontsize=10, pad=14)

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

TN, FP, FN, TP, acc, prec, rec, f1, auc_val, score_mode = compute_metrics(results)

# Optional: pull checkpoint metadata if your results include it
ckpt_epoch = results[0].get("checkpoint_epoch", None)
ckpt_val_auc = results[0].get("checkpoint_val_auc", None)
ckpt_val_f1 = results[0].get("checkpoint_val_f1", None)

print(f"{'═' * 60}")
print(f"  Validation Metrics — {MODEL_NAME}")
print(f"{'═' * 60}")

if ckpt_epoch is not None:
    print(f"  Selected checkpoint epoch: {ckpt_epoch}")
if ckpt_val_auc is not None:
    print(f"  AUC Best Epoch:     {float(ckpt_val_auc):.4f}")
if ckpt_val_f1 is not None:
    print(f"  F1 Best-AUC epoch:  {float(ckpt_val_f1):.4f}")
print(f"  Accuracy:           {acc:.4f}")
print(f"{'─' * 60}")
print(f"  TP (correct fake):         {TP}")
print(f"  TN (correct real):         {TN}")
print(f"  FP (false alarm):          {FP}")
print(f"  FN (missed fake):          {FN}")
print(f"{'═' * 60}")

fig, ax = plt.subplots(figsize=(6, 5))
fig.patch.set_facecolor("white")

draw_cm(
    ax,
    TN, FP, FN, TP,
    f"Val · AUC {auc_val:.3f} · Acc {acc * 100:.1f}% · F1 {f1 * 100:.1f}%"
)

plt.suptitle(f"Confusion Matrix — Validation ({MODEL_NAME})", fontsize=14, y=1.02)
plt.tight_layout()

out_path = "confusion_matrix_val_spsl.jpg"
plt.savefig(out_path, dpi=80, bbox_inches="tight", facecolor=fig.get_facecolor())
plt.close(fig)

display(Image(out_path))
# Out:
# ════════════════════════════════════════════════════════════
#   Validation Metrics — SPSL
# ════════════════════════════════════════════════════════════
#   Selected checkpoint epoch: 6
#   AUC Best Epoch:     0.6644
#   F1 Best-AUC epoch:  0.4932
#   Accuracy:           0.6000
# ────────────────────────────────────────────────────────────
#   TP (correct fake):         19
#   TN (correct real):         41
#   FP (false alarm):          9
#   FN (missed fake):          31
# ════════════════════════════════════════════════════════════

# %%
# Badly / Well Detected dataset — VALIDATION

# %matplotlib inline

import os
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image, display

# ── Rebuild all summary information from `results` ────────────────────────────
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

total = len(results)
n_correct = sum(r["correct"] for r in results)
accuracy = 100 * n_correct / total

probs = [r["confidence"] for r in results]

well  = [r for r in results if r["correct"]]
badly = [r for r in results if not r["correct"]]

well_sorted  = sorted(well,  key=lambda x: abs(x["confidence"] - 0.5), reverse=True)
badly_sorted = sorted(badly, key=lambda x: abs(x["confidence"] - 0.5), reverse=True)

well_sample  = well_sorted[:100]
badly_sample = badly_sorted[:100]

n_real = sum(r["true_label"] == 0 for r in results)
n_fake = sum(r["true_label"] == 1 for r in results)

tp = sum((r["true_label"] == 1 and r["pred"] == 1) for r in results)
tn = sum((r["true_label"] == 0 and r["pred"] == 0) for r in results)
fp = sum((r["true_label"] == 0 and r["pred"] == 1) for r in results)
fn = sum((r["true_label"] == 1 and r["pred"] == 0) for r in results)

real_acc = 100 * tn / max(1, n_real)
fake_acc = 100 * tp / max(1, n_fake)
precision_fake = tp / max(1, tp + fp)
recall_fake = tp / max(1, tp + fn)
f1_fake = 2 * precision_fake * recall_fake / max(1e-12, precision_fake + recall_fake)

# ── Print validation info ─────────────────────────────────────────────────────
print(f"Validation inference: {total} images\n")
print(f"Done: {n_correct}/{total} correct ({accuracy:.1f}% accuracy)")
print(f"Min prob: {min(probs):.4f}  Max: {max(probs):.4f}  Mean: {sum(probs)/len(probs):.4f}")
print(f"Well detected:  {len(well)}")
print(f"Badly detected: {len(badly)}")
print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")



# ── Per-source breakdown from validation mixed filenames ──────────────────────
def get_source(path):
    name = os.path.basename(path).lower()
    parts = name.split("_")
    return parts[1] if len(parts) >= 3 else "unknown"



if len(skipped) > 0:
    print(f"\nSkipped images: {len(skipped)}")
    for s in skipped[:10]:
        print(f"  {os.path.basename(s['path'])}: {s['error']}")

# ── Helpers ───────────────────────────────────────────────────────────────────
def label_str(l):
    return "REAL" if l == 0 else "FAKE"

def load_thumb(path, size=128):
    img = PILImage.open(path).convert("RGB")
    w, h = img.size
    side = min(w, h)
    img = img.crop(((w - side) // 2, (h - side) // 2,
                    (w + side) // 2, (h + side) // 2))
    return img.resize((size, size), PILImage.LANCZOS)

def make_grid(samples, title, filename, max_rows=10, cols=10):
    n = len(samples)
    if n == 0:
        print(f"No samples to plot for {filename}")
        return

    rows = min(max_rows, (n + cols - 1) // cols)
    show = min(n, rows * cols)

    fig, axes = plt.subplots(rows, cols, figsize=(22, rows * 2.7))
    fig.patch.set_facecolor('#1a1a1a')
    fig.suptitle(title, fontsize=15, color='white', y=0.995, fontweight='medium')

    if rows == 1:
        axes = [axes]
    flat_axes = [a for row in axes for a in row]

    for idx, ax in enumerate(flat_axes):
        if idx >= show:
            ax.axis('off')
            continue

        r = samples[idx]
        try:
            ax.imshow(load_thumb(r["path"]))
        except Exception:
            ax.set_facecolor('#333')
            ax.text(0.5, 0.5, 'error', ha='center', va='center',
                    color='white', fontsize=7, transform=ax.transAxes)

        true_color = '#2ecc71' if r["true_label"] == 0 else '#e74c3c'
        for spine in ax.spines.values():
            spine.set_edgecolor(true_color)
            spine.set_linewidth(3)

        ax.set_xticks([])
        ax.set_yticks([])

        src = get_source(r["path"])
        fname = os.path.basename(r["path"])
        ax.set_title(
            f"\nTrue: {label_str(r['true_label'])} → Pred: {label_str(r['pred'])}\n"
            f"conf: {r['confidence']:.3f}",
            fontsize=7, color='white', pad=4
        )

    for ax in flat_axes[show:]:
        ax.axis('off')

    real_p = mpatches.Patch(color='#2ecc71', label='True label: REAL')
    fake_p = mpatches.Patch(color='#e74c3c', label='True label: FAKE')
    fig.legend(handles=[real_p, fake_p], loc='lower center', ncol=2,
               fontsize=10, framealpha=0.3, facecolor='#333',
               labelcolor='white', bbox_to_anchor=(0.5, 0.01))

    plt.subplots_adjust(hspace=0.60, wspace=0.08, top=0.93, bottom=0.05)
    plt.savefig(filename, dpi=80, bbox_inches='tight',
                facecolor=fig.get_facecolor())
    plt.close(fig)
    display(Image(filename))

# ── Plots ─────────────────────────────────────────────────────────────────────
make_grid(
    well_sample,
    title=f'{len(well_sample)} most confidently CORRECT predictions (Validation)\n'
          'Border = true label',
    filename='well_detected_val.jpg'
)

make_grid(
    badly_sample,
    title=f'{len(badly_sample)} most confidently WRONG predictions (Validation)\n'
          'Border = true label',
    filename='badly_detected_val.jpg'
)
# Out:
# Validation inference: 100 images
#
# Done: 60/100 correct (60.0% accuracy)
# Min prob: 0.0083  Max: 0.9985  Mean: 0.3206
# Well detected:  60
# Badly detected: 40
# TP=19, TN=41, FP=9, FN=31

# %%
# Badly / Well Detected dataset — VALIDATION

# %matplotlib inline

import os
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image, display

# ── Rebuild all summary information from `results` ────────────────────────────
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

total = len(results)
n_correct = sum(r["correct"] for r in results)
accuracy = 100 * n_correct / total

probs = [r["confidence"] for r in results]

well  = [r for r in results if r["correct"]]
badly = [r for r in results if not r["correct"]]

# 1) sort by confidence distance from 0.5
well_sorted  = sorted(well,  key=lambda x: abs(x["confidence"] - 0.5), reverse=True)
badly_sorted = sorted(badly, key=lambda x: abs(x["confidence"] - 0.5), reverse=True)

# 2) take top 100 first
well_top = well_sorted[:100]
badly_top = badly_sorted[:100]

# 3) then group REAL first, FAKE second, preserving order within each group
def group_real_fake(samples):
    real_group = [r for r in samples if r["true_label"] == 0]
    fake_group = [r for r in samples if r["true_label"] == 1]
    return real_group + fake_group

well_sample  = group_real_fake(well_top)
badly_sample = group_real_fake(badly_top)

n_real = sum(r["true_label"] == 0 for r in results)
n_fake = sum(r["true_label"] == 1 for r in results)

tp = sum((r["true_label"] == 1 and r["pred"] == 1) for r in results)
tn = sum((r["true_label"] == 0 and r["pred"] == 0) for r in results)
fp = sum((r["true_label"] == 0 and r["pred"] == 1) for r in results)
fn = sum((r["true_label"] == 1 and r["pred"] == 0) for r in results)

real_acc = 100 * tn / max(1, n_real)
fake_acc = 100 * tp / max(1, n_fake)
precision_fake = tp / max(1, tp + fp)
recall_fake = tp / max(1, tp + fn)
f1_fake = 2 * precision_fake * recall_fake / max(1e-12, precision_fake + recall_fake)

# ── Print validation info ─────────────────────────────────────────────────────
print(f"Validation inference: {total} images\n")
print(f"Done: {n_correct}/{total} correct ({accuracy:.1f}% accuracy)")
print(f"Min prob: {min(probs):.4f}  Max: {max(probs):.4f}  Mean: {sum(probs)/len(probs):.4f}")
print(f"Well detected:  {len(well)}")
print(f"Badly detected: {len(badly)}")
print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")

# ── Per-source breakdown from validation mixed filenames ──────────────────────
def get_source(path):
    name = os.path.basename(path).lower()
    parts = name.split("_")
    return parts[1] if len(parts) >= 3 else "unknown"

if len(skipped) > 0:
    print(f"\nSkipped images: {len(skipped)}")
    for s in skipped[:10]:
        print(f"  {os.path.basename(s['path'])}: {s['error']}")

# ── Helpers ───────────────────────────────────────────────────────────────────
def label_str(l):
    return "REAL" if l == 0 else "FAKE"

def load_thumb(path, size=128):
    img = PILImage.open(path).convert("RGB")
    w, h = img.size
    side = min(w, h)
    img = img.crop(((w - side) // 2, (h - side) // 2,
                    (w + side) // 2, (h + side) // 2))
    return img.resize((size, size), PILImage.LANCZOS)

def make_grid(samples, title, filename, max_rows=10, cols=10):
    n = len(samples)
    if n == 0:
        print(f"No samples to plot for {filename}")
        return

    rows = min(max_rows, (n + cols - 1) // cols)
    show = min(n, rows * cols)

    fig, axes = plt.subplots(rows, cols, figsize=(22, rows * 2.7))
    fig.patch.set_facecolor('#1a1a1a')
    fig.suptitle(title, fontsize=15, color='white', y=0.995, fontweight='medium')

    if rows == 1:
        axes = [axes]
    flat_axes = [a for row in axes for a in row]

    for idx, ax in enumerate(flat_axes):
        if idx >= show:
            ax.axis('off')
            continue

        r = samples[idx]
        try:
            ax.imshow(load_thumb(r["path"]))
        except Exception:
            ax.set_facecolor('#333')
            ax.text(0.5, 0.5, 'error', ha='center', va='center',
                    color='white', fontsize=7, transform=ax.transAxes)

        true_color = '#2ecc71' if r["true_label"] == 0 else '#e74c3c'
        for spine in ax.spines.values():
            spine.set_edgecolor(true_color)
            spine.set_linewidth(3)

        ax.set_xticks([])
        ax.set_yticks([])

        ax.set_title(
            f"\nTrue: {label_str(r['true_label'])} → Pred: {label_str(r['pred'])}\n"
            f"conf: {r['confidence']:.3f}",
            fontsize=7, color='white', pad=4
        )

    for ax in flat_axes[show:]:
        ax.axis('off')

    real_p = mpatches.Patch(color='#2ecc71', label='True label: REAL')
    fake_p = mpatches.Patch(color='#e74c3c', label='True label: FAKE')
    fig.legend(handles=[real_p, fake_p], loc='lower center', ncol=2,
               fontsize=10, framealpha=0.3, facecolor='#333',
               labelcolor='white', bbox_to_anchor=(0.5, 0.01))

    plt.subplots_adjust(hspace=0.60, wspace=0.08, top=0.93, bottom=0.05)
    plt.savefig(filename, dpi=80, bbox_inches='tight',
                facecolor=fig.get_facecolor())
    plt.close(fig)
    display(Image(filename))

# ── Plots ─────────────────────────────────────────────────────────────────────
make_grid(
    well_sample,
    title=f'{len(well_sample)} most confidently CORRECT predictions (Validation)\n'
          'Border = true label',
    filename='well_detected_val.jpg'
)

make_grid(
    badly_sample,
    title=f'{len(badly_sample)} most confidently WRONG predictions (Validation)\n'
          'Border = true label',
    filename='badly_detected_val.jpg'
)
# Out:
# Validation inference: 100 images
#
# Done: 60/100 correct (60.0% accuracy)
# Min prob: 0.0083  Max: 0.9985  Mean: 0.3206
# Well detected:  60
# Badly detected: 40
# TP=19, TN=41, FP=9, FN=31

# %%
# !pip install nbconvert -q

NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/SPSL Train.ipynb"
OUTPUT_DIR    = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks"

# !jupyter nbconvert \
    --to html \
    --embed-images \
    --output-dir "{OUTPUT_DIR}" \
    "{NOTEBOOK_PATH}"

print("Done — check your Drive for the .html file")
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/SPSL Train.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 7 image(s).
# [NbConvertApp] Writing 1997958 bytes to /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks/SPSL Train.html
# Done — check your Drive for the .html file
