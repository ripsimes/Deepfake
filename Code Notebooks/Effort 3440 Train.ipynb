# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install -q "numpy<2" --force-reinstall

# %%
import numpy, torch, torchvision
print("numpy:", numpy.__version__)
print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# numpy: 1.26.4
# torch: 2.10.0+cu128
# torchvision: 0.25.0+cu128
# CUDA: True

# %%
from collections import defaultdict
from pathlib import Path

TRAIN_MIX_DIR = Path("/content/drive/MyDrive/Capstone_Hripsime/Database/3440_Train_Dataset")

real_counts = defaultdict(int)
fake_counts = defaultdict(int)

for p in TRAIN_MIX_DIR.iterdir():
    if not p.is_file():
        continue

    name = p.name.lower()
    parts = name.split("_")

    # detect source
    source = parts[1] if len(parts) >= 3 else "unknown"

    # detect label
    if "_real" in name:
        real_counts[source] += 1
    elif "_fake" in name:
        fake_counts[source] += 1

# =========================
# PRINT REAL DISTRIBUTION
# =========================
print("Real image distribution:\n")
total_real = 0
for k, v in sorted(real_counts.items()):
    print(f"{k:20s}: {v}")
    total_real += v

print("\nTotal real images:", total_real)

# =========================
# PRINT FAKE DISTRIBUTION
# =========================
print("\n" + "="*40 + "\n")

print("Fake image distribution:\n")
total_fake = 0
for k, v in sorted(fake_counts.items()):
    print(f"{k:20s}: {v}")
    total_fake += v

print("\nTotal fake images:", total_fake)

total_images = total_real+total_fake

# =========================
# OVERALL BALANCE
# =========================
print("\n" + "="*40 + "\n")
print("Overall dataset balance:")
print(f"Real: {total_real}")
print(f"Fake: {total_fake}")
print(f"Total: {total_images}")
# Out:
# Real image distribution:
#
# augreal             : 200
# challenge           : 500
# hardreal            : 120
# hidf                : 300
# whichfaceisreal     : 600
#
# Total real images: 1720
#
# ========================================
#
# Fake image distribution:
#
# challenge           : 500
# deepfacelab         : 270
# degradedfake        : 200
# e4s                 : 120
# faceswap            : 340
# inswap              : 65
# simswap             : 225
#
# Total fake images: 1720
#
# ========================================
#
# Overall dataset balance:
# Real: 1720
# Fake: 1720
# Total: 3440

# %%
import os, glob, json, random

random.seed(42)

TRAIN_MIX_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/3440_Train_Dataset"

VAL_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/validation_data"
VAL_REF = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/validation_reference/reference.txt"

TEST_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/publictest_data"
TEST_REF = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/publictest_reference/reference.txt"

STAGING = "/content/DiffusionForensics_Recons"
os.makedirs(STAGING, exist_ok=True)

IMG_EXTS = (".png", ".jpg", ".jpeg", ".webp", ".bmp", ".tif", ".tiff")


def label_from_name(path):
    name = os.path.basename(path).lower()
    if "_real" in name:
        return 0
    elif "_fake" in name:
        return 1
    return None


def collect_labeled_items_from_filenames(data_dir):
    paths = []
    for ext in IMG_EXTS:
        paths += glob.glob(os.path.join(data_dir, f"*{ext}"))

    items = []
    for p in sorted(set(paths)):
        label = label_from_name(p)
        if label is not None:
            items.append({"path": p, "label": label})
    return items


def collect_items_with_reference(data_dir, ref_path):
    with open(ref_path) as f:
        labels = [int(line.strip()) for line in f if line.strip()]

    images = sorted(glob.glob(os.path.join(data_dir, "*.*")))
    images = [p for p in images if os.path.splitext(p)[1].lower() in IMG_EXTS]

    assert len(images) == len(labels), (
        f"Mismatch: {len(images)} images vs {len(labels)} labels\n"
        f"data_dir={data_dir}\nref_path={ref_path}"
    )

    return [{"path": p, "label": l} for p, l in zip(images, labels)]


# ═══════════════════════════════════════
# TRAIN — expanded/mixed training set, label from filenames
# ═══════════════════════════════════════
train_items = collect_labeled_items_from_filenames(TRAIN_MIX_DIR)
random.shuffle(train_items)

n_real = sum(1 for x in train_items if x["label"] == 0)
n_fake = sum(1 for x in train_items if x["label"] == 1)
print(f"TRAIN: {len(train_items)} images  (real={n_real}, fake={n_fake})")


# ═══════════════════════════════════════
# VAL — MAIN 100 validation images, label from reference.txt
# ═══════════════════════════════════════
val_items = collect_items_with_reference(VAL_DIR, VAL_REF)

n_real = sum(1 for x in val_items if x["label"] == 0)
n_fake = sum(1 for x in val_items if x["label"] == 1)
print(f"VAL:   {len(val_items)} images  (real={n_real}, fake={n_fake})")


# ═══════════════════════════════════════
# TEST — public test, label from reference.txt
# ═══════════════════════════════════════
test_items = collect_items_with_reference(TEST_DIR, TEST_REF)

n_real = sum(1 for x in test_items if x["label"] == 0)
n_fake = sum(1 for x in test_items if x["label"] == 1)
print(f"TEST:  {len(test_items)} images  (real={n_real}, fake={n_fake})")


# ═══════════════════════════════════════
# SAVE
# ═══════════════════════════════════════
for name, data in [("train", train_items), ("val", val_items), ("test", test_items)]:
    out = os.path.join(STAGING, f"{name}.json")
    with open(out, "w") as f:
        json.dump(data, f, indent=2)
    print(f"\n{name}.json -> {len(data)} items -> {out}")
# Out:
# TRAIN: 3440 images  (real=1720, fake=1720)
# VAL:   100 images  (real=50, fake=50)
# TEST:  1000 images  (real=500, fake=500)
#
# train.json -> 3440 items -> /content/DiffusionForensics_Recons/train.json
#
# val.json -> 100 items -> /content/DiffusionForensics_Recons/val.json
#
# test.json -> 1000 items -> /content/DiffusionForensics_Recons/test.json

# %%
# %%capture
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench
# !pip install jedi
# !python -m pip install -U pip setuptools wheel
# !pip install -r requirements.txt
# !pip install -e .

# %%
# %%capture
# %cd "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub"
# !head -n -1 requirements.txt > requirements_no_flash.txt
# !pip install -r requirements_no_flash.txt

# %%
# import shutil
# from pathlib import Path

# CKPT_DIR = Path("/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train")

# if CKPT_DIR.exists():
#     shutil.rmtree(CKPT_DIR)
#     print("🧹 Old checkpoints deleted")

# CKPT_DIR.mkdir(parents=True, exist_ok=True)
# print("✅ Fresh checkpoint directory created:", CKPT_DIR)
# Out:
# 🧹 Old checkpoints deleted
# ✅ Fresh checkpoint directory created: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train

# %%
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub

# !PYTHONPATH=/content/drive/MyDrive/Capstone_Hripsime/Frameworks:$PWD \
# MASTER_ADDR=127.0.0.1 MASTER_PORT=29601 \
# python -m ForensicHub.training_scripts.train \
# --config "ForensicHub/statics/crossdataset_image/effort_3440val_train.yaml"
# Out:
# /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/timm/optim/optim_factory.py:7: FutureWarning: Importing from timm.optim.optim_factory is deprecated, please import via timm.optim
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.optim", FutureWarning)
# 2026-05-03 21:59:03.693716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.10.0+cu128
# Current Torch version: 2.10
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# Not using distributed mode
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [22:01:28.684258] [patch] initialized torch.distributed process group (single-process, gloo)
# [22:01:28.686597] job dir: /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub/ForensicHub/training_scripts
# [22:01:28.686722] =====args:=====
# [22:01:28.686887] Namespace(gpus=0.0,
# flag='train',
# log_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train',
# if_predict_label=True,
# if_predict_mask=False,
# num_classes=2,
# batch_size=32,
# test_batch_size=16,
# epochs=10,
# accum_iter=1,
# record_epoch=0,
# no_model_eval=False,
# test_period=1,
# log_per_epoch_count=20,
# find_unused_parameters=True,
# use_amp=True,
# weight_decay=0.05,
# lr=0.0001,
# blr=0.001,
# min_lr=1e-05,
# warmup_epochs=1,
# device='cuda',
# seed=42,
# resume='',
# start_epoch=0,
# num_workers=2,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# output_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train',
# if_not_amp=False,
# distributed=False)
# [22:01:30.458125] [build_from_registry] Creating model 'AIGCTransform' with args: {'norm_type': 'clip'}
# [22:01:30.458573] Train transform:  Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [22:01:30.459013] Test transform:  Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [22:01:30.459176] Post transform:  Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [22:01:30.459388] Post function check: effortdetector_post_func
# [22:01:30.459496] None
# [22:01:30.459780] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 224, 'path': '/content/DiffusionForensics_Recons/train.json', 'post_funcs': None, 'common_transform': Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [22:01:30.466224] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 224, 'path': '/content/DiffusionForensics_Recons/val.json', 'post_funcs': None, 'common_transform': Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [22:01:30.467122] Train dataset: DiffusionForensics_train.
# [22:01:30.467254] 3440
# [22:01:30.467378] [AIGCLabelDataset] at /content/DiffusionForensics_Recons/train.json, with length of 3,440
# [22:01:30.467468] Test dataset: ['DiffusionForensics_val'].
# [22:01:30.467583] [100]
# [22:01:31.225988] [lazy import] Loading 'EffortDetector' from 'DeepfakeBench.training.detectors.effort_detector'
# [22:01:31.226221] [build_from_registry] Creating model 'EffortDetector' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml'}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 4.52kB [00:00, 15.2MB/s]
# model.safetensors: 100% 1.71G/1.71G [00:12<00:00, 137MB/s]
# Loading weights: 100% 590/590 [00:00<00:00, 694.23it/s, Materializing param=visual_projection.weight]
# CLIPModel LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [22:02:39.432544] embeddings.class_embedding: False
# [22:02:39.432749] embeddings.patch_embedding.weight: False
# [22:02:39.432890] embeddings.position_embedding.weight: False
# [22:02:39.432981] pre_layrnorm.weight: False
# [22:02:39.433078] pre_layrnorm.bias: False
# [22:02:39.433189] encoder.layers.0.self_attn.k_proj.weight_main: False
# [22:02:39.433280] encoder.layers.0.self_attn.k_proj.bias: False
# [22:02:39.433373] encoder.layers.0.self_attn.k_proj.S_residual: True
# [22:02:39.433463] encoder.layers.0.self_attn.k_proj.U_residual: True
# [22:02:39.433551] encoder.layers.0.self_attn.k_proj.V_residual: True
# [22:02:39.433647] encoder.layers.0.self_attn.v_proj.weight_main: False
# [22:02:39.433737] encoder.layers.0.self_attn.v_proj.bias: False
# [22:02:39.433842] encoder.layers.0.self_attn.v_proj.S_residual: True
# [22:02:39.433922] encoder.layers.0.self_attn.v_proj.U_residual: True
# [22:02:39.434007] encoder.layers.0.self_attn.v_proj.V_residual: True
# [22:02:39.434096] encoder.layers.0.self_attn.q_proj.weight_main: False
# [22:02:39.434184] encoder.layers.0.self_attn.q_proj.bias: False
# [22:53:47.259869] !!!Start Test: DiffusionForensics_val 6
# [22:53:48.533869] Test: [4]  [0/6]  eta: 0:00:07    time: 1.2691  data: 0.3062  max mem: 9292
# [22:53:53.493129] Test: [4]  [5/6]  eta: 0:00:01    time: 1.0379  data: 0.0512  max mem: 9292
# [22:53:53.556182] Test: [4] Total time: 0:00:06 (1.0487 s / it)
# [22:53:53.563223] ---syncronized---
# [22:53:53.563377] image-level F1 reduced_count 1
# [22:53:53.563517] image-level F1 reduced_sum 0.5679012537002563
# [22:53:53.563646] image-level AUC reduced_count 1
# [22:53:53.563759] image-level AUC reduced_sum 0.6610243055555555
# [22:53:53.563893] ---syncronized done ---
# [22:53:53.842481] Averaged stats: image-level F1: [local: 0.5679 | reduced: 0.5679]  image-level AUC: [local: 0.6610 | reduced: 0.6610]
# [22:53:53.901100] Best image-level F1 image-level AUC = 0.6144627796279059
# [22:54:03.664062] Auto Mixed Precision (AMP) is enabled.
# [22:54:03.664560] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train
# [22:54:09.565980] Epoch: [5]  [  0/107]  eta: 0:10:31  lr: 0.000063  overall: [local: 0.1873 | reduced: 0.1873]  real_loss: [local: 0.1369 | reduced: 0.1369]  fake_loss: [local: 0.2610 | reduced: 0.2610]  time: 5.9000  data: 1.5574  max mem: 9292
# [22:55:26.914430] Epoch: [5]  [ 20/107]  eta: 0:05:44  lr: 0.000060  overall: [local: 0.2347 | reduced: 0.2446]  real_loss: [local: 0.1750 | reduced: 0.2275]  fake_loss: [local: 0.2549 | reduced: 0.2673]  time: 3.8674  data: 0.0005  max mem: 9292
# [22:56:39.127965] Epoch: [5]  [ 40/107]  eta: 0:04:14  lr: 0.000057  overall: [local: 0.1950 | reduced: 0.2325]  real_loss: [local: 0.2357 | reduced: 0.2430]  fake_loss: [local: 0.1544 | reduced: 0.2279]  time: 3.6106  data: 0.0003  max mem: 9292
# [22:57:51.707374] Epoch: [5]  [ 60/107]  eta: 0:02:55  lr: 0.000054  overall: [local: 0.2015 | reduced: 0.2310]  real_loss: [local: 0.2109 | reduced: 0.2409]  fake_loss: [local: 0.2034 | reduced: 0.2239]  time: 3.6289  data: 0.0002  max mem: 9292
# [22:59:04.222694] Epoch: [5]  [ 80/107]  eta: 0:01:40  lr: 0.000051  overall: [local: 0.1982 | reduced: 0.2252]  real_loss: [local: 0.2117 | reduced: 0.2398]  fake_loss: [local: 0.1735 | reduced: 0.2132]  time: 3.6256  data: 0.0002  max mem: 9292
# [23:00:17.154091] Epoch: [5]  [100/107]  eta: 0:00:25  lr: 0.000048  overall: [local: 0.2325 | reduced: 0.2276]  real_loss: [local: 0.2111 | reduced: 0.2371]  fake_loss: [local: 0.2290 | reduced: 0.2188]  time: 3.6465  data: 0.0002  max mem: 9292
# [23:00:37.262264] Epoch: [5]  [106/107]  eta: 0:00:03  lr: 0.000047  overall: [local: 0.2340 | reduced: 0.2274]  real_loss: [local: 0.2105 | reduced: 0.2367]  fake_loss: [local: 0.2259 | reduced: 0.2192]  time: 3.5589  data: 0.0002  max mem: 9292
# [23:07:29.035326] Epoch: [6]  [106/107]  eta: 0:00:03  lr: 0.000033  overall: [local: 0.2308 | reduced: 0.2117]  real_loss: [local: 0.2190 | reduced: 0.2221]  fake_loss: [local: 0.1832 | reduced: 0.2013]  time: 3.5633  data: 0.0002  max mem: 9292
# [23:07:29.167663] Epoch: [6] Total time: 0:06:35 (3.6984 s / it)
# [23:07:30.165676] Averaged stats: lr: 0.000033  overall: [local: 0.2308 | reduced: 0.2117]  real_loss: [local: 0.2190 | reduced: 0.2221]  fake_loss: [local: 0.1832 | reduced: 0.2013]
# [23:07:30.472032] !!!Start Test: DiffusionForensics_val 6
# [23:07:31.746601] Test: [6]  [0/6]  eta: 0:00:07    time: 1.2694  data: 0.3150  max mem: 9292
# [23:07:36.729981] Test: [6]  [5/6]  eta: 0:00:01    time: 1.0419  data: 0.0527  max mem: 9292
# [23:07:36.799286] Test: [6] Total time: 0:00:06 (1.0539 s / it)
# [23:07:36.807415] ---syncronized---
# [23:07:36.807629] image-level F1 reduced_count 1
# [23:07:36.807787] image-level F1 reduced_sum 0.5999999642372131
# [23:07:36.807935] image-level AUC reduced_count 1
# [23:07:36.808086] image-level AUC reduced_sum 0.6904038211029092
# [23:07:36.808229] ---syncronized done ---
# [23:07:37.159120] Averaged stats: image-level F1: [local: 0.6000 | reduced: 0.6000]  image-level AUC: [local: 0.6904 | reduced: 0.6904]
# [23:07:37.267917] Best image-level F1 image-level AUC = 0.6452018926700611
# [23:07:44.421282] Auto Mixed Precision (AMP) is enabled.
# [23:07:44.422607] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train
# [23:07:50.043648] Epoch: [7]  [  0/107]  eta: 0:10:01  lr: 0.000033  overall: [local: 0.1369 | reduced: 0.1369]  real_loss: [local: 0.1481 | reduced: 0.1481]  fake_loss: [local: 0.1241 | reduced: 0.1241]  time: 5.6200  data: 1.2896  max mem: 9292
# [23:09:07.693007] Epoch: [7]  [ 20/107]  eta: 0:05:44  lr: 0.000030  overall: [local: 0.2223 | reduced: 0.2165]  real_loss: [local: 0.1496 | reduced: 0.1930]  fake_loss: [local: 0.2150 | reduced: 0.2430]  time: 3.8824  data: 0.0002  max mem: 9292
# [23:10:20.645786] Epoch: [7]  [ 40/107]  eta: 0:04:15  lr: 0.000028  overall: [local: 0.1829 | reduced: 0.2045]  real_loss: [local: 0.1864 | reduced: 0.1927]  fake_loss: [local: 0.1535 | reduced: 0.2170]  time: 3.6476  data: 0.0003  max mem: 9292
# [23:11:33.348141] Epoch: [7]  [ 60/107]  eta: 0:02:56  lr: 0.000025  overall: [local: 0.2236 | reduced: 0.2153]  real_loss: [local: 0.1729 | reduced: 0.2003]  fake_loss: [local: 0.2041 | reduced: 0.2290]  time: 3.6351  data: 0.0002  max mem: 9292
# [23:12:45.876838] Epoch: [7]  [ 80/107]  eta: 0:01:40  lr: 0.000023  overall: [local: 0.1837 | reduced: 0.2134]  real_loss: [local: 0.1950 | reduced: 0.2052]  fake_loss: [local: 0.1669 | reduced: 0.2209]  time: 3.6264  data: 0.0003  max mem: 9292
# [23:13:59.205454] Epoch: [7]  [100/107]  eta: 0:00:25  lr: 0.000021  overall: [local: 0.2101 | reduced: 0.2125]  real_loss: [local: 0.1969 | reduced: 0.2065]  fake_loss: [local: 0.1701 | reduced: 0.2161]  time: 3.6664  data: 0.0002  max mem: 9292
# [23:14:19.631217] Epoch: [7]  [106/107]  eta: 0:00:03  lr: 0.000021  overall: [local: 0.2183 | reduced: 0.2141]  real_loss: [local: 0.1746 | reduced: 0.2107]  fake_loss: [local: 0.1504 | reduced: 0.2163]  time: 3.5747  data: 0.0002  max mem: 9292
# [23:14:19.700909] Epoch: [7] Total time: 0:06:35 (3.6942 s / it)
# [23:14:20.508065] Averaged stats: lr: 0.000021  overall: [local: 0.2183 | reduced: 0.2141]  real_loss: [local: 0.1746 | reduced: 0.2107]  fake_loss: [local: 0.1504 | reduced: 0.2163]
# [23:14:20.572481] !!!Start Test: DiffusionForensics_val 6
# [23:14:22.348842] Test: [7]  [0/6]  eta: 0:00:10    time: 1.7605  data: 0.7491  max mem: 9292
# [23:14:27.308418] Test: [7]  [5/6]  eta: 0:00:01    time: 1.1198  data: 0.1252  max mem: 9292
# [23:14:27.370828] Test: [7] Total time: 0:00:06 (1.1306 s / it)
# [23:14:27.377985] ---syncronized---
# [23:14:27.378129] image-level F1 reduced_count 1
# [23:14:27.378231] image-level F1 reduced_sum 0.6052631139755249
# [23:14:27.378336] image-level AUC reduced_count 1
# [23:14:27.378436] image-level AUC reduced_sum 0.6908380373425966
# [23:14:27.378623] ---syncronized done ---
# [23:14:27.680633] Averaged stats: image-level F1: [local: 0.6053 | reduced: 0.6053]  image-level AUC: [local: 0.6908 | reduced: 0.6908]
# [23:14:27.719134] Best image-level F1 image-level AUC = 0.6480505756590608
# [23:14:34.542268] Auto Mixed Precision (AMP) is enabled.
# [23:14:34.542814] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train
# [23:14:41.844631] Epoch: [8]  [  0/107]  eta: 0:13:01  lr: 0.000021  overall: [local: 0.2022 | reduced: 0.2022]  real_loss: [local: 0.2543 | reduced: 0.2543]  fake_loss: [local: 0.1352 | reduced: 0.1352]  time: 7.3007  data: 1.3220  max mem: 9292
# [23:15:59.414260] Epoch: [8]  [ 20/107]  eta: 0:05:51  lr: 0.000019  overall: [local: 0.1935 | reduced: 0.1883]  real_loss: [local: 0.2147 | reduced: 0.2070]  fake_loss: [local: 0.1666 | reduced: 0.1744]  time: 3.8784  data: 0.0002  max mem: 9292
# [23:17:12.166374] Epoch: [8]  [ 40/107]  eta: 0:04:17  lr: 0.000017  overall: [local: 0.1883 | reduced: 0.1895]  real_loss: [local: 0.1926 | reduced: 0.1932]  fake_loss: [local: 0.1652 | reduced: 0.1865]  time: 3.6376  data: 0.0003  max mem: 9292
# [23:18:25.339192] Epoch: [8]  [ 60/107]  eta: 0:02:57  lr: 0.000016  overall: [local: 0.2123 | reduced: 0.1988]  real_loss: [local: 0.2095 | reduced: 0.2076]  fake_loss: [local: 0.1988 | reduced: 0.1958]  time: 3.6586  data: 0.0002  max mem: 9292
# [23:19:38.376028] Epoch: [8]  [ 80/107]  eta: 0:01:41  lr: 0.000014  overall: [local: 0.2118 | reduced: 0.2058]  real_loss: [local: 0.2155 | reduced: 0.2125]  fake_loss: [local: 0.1802 | reduced: 0.2016]  time: 3.6518  data: 0.0002  max mem: 9292
# [23:20:50.503420] Epoch: [8]  [100/107]  eta: 0:00:26  lr: 0.000013  overall: [local: 0.1880 | reduced: 0.2066]  real_loss: [local: 0.2178 | reduced: 0.2106]  fake_loss: [local: 0.1991 | reduced: 0.2034]  time: 3.6063  data: 0.0002  max mem: 9292
# [23:21:11.117751] Epoch: [8]  [106/107]  eta: 0:00:03  lr: 0.000013  overall: [local: 0.1792 | reduced: 0.2058]  real_loss: [local: 0.1425 | reduced: 0.2094]  fake_loss: [local: 0.1981 | reduced: 0.2028]  time: 3.5593  data: 0.0002  max mem: 9292
# [23:21:11.187299] Epoch: [8] Total time: 0:06:36 (3.7070 s / it)
# [23:21:12.060523] Averaged stats: lr: 0.000013  overall: [local: 0.1792 | reduced: 0.2058]  real_loss: [local: 0.1425 | reduced: 0.2094]  fake_loss: [local: 0.1981 | reduced: 0.2028]
# [23:21:12.298216] !!!Start Test: DiffusionForensics_val 6
# [23:21:13.562962] Test: [8]  [0/6]  eta: 0:00:07    time: 1.2597  data: 0.2994  max mem: 9292
# [23:21:18.505245] Test: [8]  [5/6]  eta: 0:00:01    time: 1.0334  data: 0.0501  max mem: 9292
# [23:21:18.586610] Test: [8] Total time: 0:00:06 (1.0474 s / it)
# [23:21:18.594069] ---syncronized---
# [23:21:18.594203] image-level F1 reduced_count 1
# [23:21:18.594329] image-level F1 reduced_sum 0.6052631139755249
# [23:21:18.594454] image-level AUC reduced_count 1
# [23:21:18.594587] image-level AUC reduced_sum 0.7142857142857143
# [23:21:18.594708] ---syncronized done ---
# [23:21:18.967704] Averaged stats: image-level F1: [local: 0.6053 | reduced: 0.6053]  image-level AUC: [local: 0.7143 | reduced: 0.7143]
# [23:21:18.968522] Best image-level F1 image-level AUC = 0.6597744141306197
# [23:21:25.919601] Auto Mixed Precision (AMP) is enabled.
# [23:21:25.920064] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train
# [23:21:31.274401] Epoch: [9]  [  0/107]  eta: 0:09:32  lr: 0.000013  overall: [local: 0.4195 | reduced: 0.4195]  real_loss: [local: 0.2571 | reduced: 0.2571]  fake_loss: [local: 0.5307 | reduced: 0.5307]  time: 5.3530  data: 0.7647  max mem: 9292
# [23:22:48.397932] Epoch: [9]  [ 20/107]  eta: 0:05:41  lr: 0.000012  overall: [local: 0.2078 | reduced: 0.2328]  real_loss: [local: 0.2072 | reduced: 0.2154]  fake_loss: [local: 0.1880 | reduced: 0.2492]  time: 3.8561  data: 0.0002  max mem: 9292
# [23:24:00.838841] Epoch: [9]  [ 40/107]  eta: 0:04:13  lr: 0.000011  overall: [local: 0.2130 | reduced: 0.2212]  real_loss: [local: 0.1833 | reduced: 0.2085]  fake_loss: [local: 0.1849 | reduced: 0.2347]  time: 3.6220  data: 0.0002  max mem: 9292
# [23:25:13.319918] Epoch: [9]  [ 60/107]  eta: 0:02:55  lr: 0.000011  overall: [local: 0.1883 | reduced: 0.2139]  real_loss: [local: 0.1846 | reduced: 0.2020]  fake_loss: [local: 0.1991 | reduced: 0.2252]  time: 3.6240  data: 0.0002  max mem: 9292
# [23:26:26.044213] Epoch: [9]  [ 80/107]  eta: 0:01:40  lr: 0.000010  overall: [local: 0.1946 | reduced: 0.2093]  real_loss: [local: 0.1688 | reduced: 0.2013]  fake_loss: [local: 0.1690 | reduced: 0.2159]  time: 3.6362  data: 0.0002  max mem: 9292
# [23:27:38.401397] Epoch: [9]  [100/107]  eta: 0:00:25  lr: 0.000010  overall: [local: 0.1501 | reduced: 0.2032]  real_loss: [local: 0.1470 | reduced: 0.1948]  fake_loss: [local: 0.1681 | reduced: 0.2124]  time: 3.6178  data: 0.0002  max mem: 9292
# [23:27:58.954254] Epoch: [9]  [106/107]  eta: 0:00:03  lr: 0.000010  overall: [local: 0.2055 | reduced: 0.2049]  real_loss: [local: 0.1636 | reduced: 0.2005]  fake_loss: [local: 0.1681 | reduced: 0.2111]  time: 3.5583  data: 0.0002  max mem: 9292
# [23:27:59.054702] Epoch: [9] Total time: 0:06:33 (3.6742 s / it)
# [23:27:59.892726] Averaged stats: lr: 0.000010  overall: [local: 0.2055 | reduced: 0.2049]  real_loss: [local: 0.1636 | reduced: 0.2005]  fake_loss: [local: 0.1681 | reduced: 0.2111]
# [23:28:06.918279] !!!Start Test: DiffusionForensics_val 6
# [23:28:08.295072] Test: [9]  [0/6]  eta: 0:00:08    time: 1.3720  data: 0.3621  max mem: 9292
# [23:28:13.160051] Test: [9]  [5/6]  eta: 0:00:01    time: 1.0392  data: 0.0606  max mem: 9292
# [23:28:13.270093] Test: [9] Total time: 0:00:06 (1.0580 s / it)
# [23:28:13.277210] ---syncronized---
# [23:28:13.277344] image-level F1 reduced_count 1
# [23:28:13.277514] image-level F1 reduced_sum 0.6075949668884277
# [23:28:13.277656] image-level AUC reduced_count 1
# [23:28:13.277795] image-level AUC reduced_sum 0.6951801997394702
# [23:28:13.277932] ---syncronized done ---
# [23:28:13.614700] Averaged stats: image-level F1: [local: 0.6076 | reduced: 0.6076]  image-level AUC: [local: 0.6952 | reduced: 0.6952]
# [23:28:13.615521] Average image-level F1 image-level AUC = 0.651387583313949
# [23:28:14.079768] Training time 1:25:33

# %%
# %matplotlib inline
import os, json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from IPython.display import Image, display

LOG_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train/log.txt"


def parse_forensichub_json_log(path):
    entries = []

    with open(path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            try:
                entry = json.loads(line)
            except json.JSONDecodeError:
                continue

            if "epoch" in entry:
                entries.append(entry)

    if not entries:
        raise RuntimeError(f"No JSON epoch entries found in {path}")

    epochs = [int(e["epoch"]) + 1 for e in entries]

    train_losses = [float(e.get("train_overall", np.nan)) for e in entries]
    real_losses  = [float(e.get("train_real_loss", np.nan)) for e in entries]
    fake_losses  = [float(e.get("train_fake_loss", np.nan)) for e in entries]
    lrs          = [float(e.get("train_lr", np.nan)) for e in entries]

    test_aucs = [float(e.get("test_image-level AUC", np.nan)) for e in entries]
    test_f1s  = [float(e.get("test_image-level F1", np.nan)) for e in entries]

    return epochs, train_losses, real_losses, fake_losses, lrs, test_aucs, test_f1s


def plot_training(path):
    epochs, losses, real_losses, fake_losses, lrs, aucs, f1s = parse_forensichub_json_log(path)

    aucs_np = np.array(aucs, dtype=float)
    f1s_np = np.array(f1s, dtype=float)

    best_auc_idx = int(np.nanargmax(aucs_np))
    best_f1_idx = int(np.nanargmax(f1s_np))

    print(f"Parsed epochs: {len(epochs)}")
    print(f"Best AUC: {aucs[best_auc_idx]:.4f} at epoch {epochs[best_auc_idx]}")
    print(f"Best F1 : {f1s[best_f1_idx]:.4f} at epoch {epochs[best_f1_idx]}")

    fig, axes = plt.subplots(1, 4, figsize=(22, 4.8))
    fig.patch.set_facecolor("#FAFAFA")

    for ax in axes:
        ax.set_facecolor("#F4F4F4")
        ax.spines[["top", "right"]].set_visible(False)
        ax.spines[["left", "bottom"]].set_color("#CCCCCC")
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # 1. Training losses
    ax = axes[0]
    ax.plot(epochs, losses, marker="o", linewidth=2, markersize=5, label="Overall loss")
    ax.plot(epochs, real_losses, marker="s", linewidth=1.8, markersize=4, label="Real loss")
    ax.plot(epochs, fake_losses, marker="^", linewidth=1.8, markersize=4, label="Fake loss")
    ax.set_title("Training losses", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9, framealpha=0.5)

    # 2. Validation AUC
    ax = axes[1]
    ax.plot(epochs, aucs, marker="D", linewidth=2, markersize=5, label="Val AUC")
    ax.fill_between(epochs, 0.5, aucs, alpha=0.15)
    ax.scatter(epochs[best_auc_idx], aucs[best_auc_idx], s=80, zorder=5)
    ax.annotate(
        f"Best: {aucs[best_auc_idx]:.4f}",
        xy=(epochs[best_auc_idx], aucs[best_auc_idx]),
        xytext=(epochs[best_auc_idx] + max(epochs) * 0.03, aucs[best_auc_idx] - 0.05),
        fontsize=9,
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0.4, 1.05)
    ax.set_title("Validation AUC", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=9, framealpha=0.5)

    # 3. Validation F1
    ax = axes[2]
    ax.plot(epochs, f1s, marker="s", linewidth=2, markersize=5, label="Val F1")
    ax.scatter(epochs[best_f1_idx], f1s[best_f1_idx], s=80, zorder=5)
    ax.annotate(
        f"Best: {f1s[best_f1_idx]:.4f}",
        xy=(epochs[best_f1_idx], f1s[best_f1_idx]),
        xytext=(epochs[best_f1_idx] + max(epochs) * 0.03, f1s[best_f1_idx] - 0.08),
        fontsize=9,
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0, 1.05)
    ax.set_title("Validation F1", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("F1")
    ax.legend(fontsize=9, framealpha=0.5)

    # 4. Learning rate
    ax = axes[3]
    ax.plot(epochs, lrs, marker="o", linewidth=2, markersize=5, label="Learning rate")
    ax.set_title("Learning rate schedule", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("LR")
    ax.ticklabel_format(style="sci", axis="y", scilimits=(0, 0))
    ax.legend(fontsize=9, framealpha=0.5)

    plt.suptitle(
        f"ForensicHub · Effort on DiffusionForensics ({len(epochs)} epochs)",
        fontsize=14,
        y=1.03,
    )
    plt.tight_layout()

    out_path = "forensichub_effort_training_curves.jpg"
    plt.savefig(out_path, dpi=100, bbox_inches="tight", facecolor=fig.get_facecolor())
    plt.close(fig)

    display(Image(out_path))


plot_training(LOG_PATH)
# Out:
# Parsed epochs: 10
# Best AUC: 0.7143 at epoch 9
# Best F1 : 0.6076 at epoch 10

# %%
# model
import os
import json
import torch
from PIL import Image
from torchvision import transforms
import sys

BASE = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"

sys.path.insert(0, BASE)
sys.path.insert(0, os.path.join(BASE, "ForensicHub"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench"))
sys.path.insert(0, os.path.join(BASE, "IMDLBenCo"))

# Important: import deepfake tasks so EffortDetector gets registered
import ForensicHub.tasks.deepfake
from ForensicHub.registry import MODELS, build_from_registry

# ── Paths / constants ─────────────────────────────────────────────────────────
CHECKPOINT_DIR = f"{BASE}/ForensicHub/log/crossdataset_image_new/effort_3440val_train"
VAL_JSON = "/content/DiffusionForensics_Recons/val.json"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
THRESHOLD = 0.5

# ── Step 1: find best epoch automatically from the log ────────────────────────
LOG_PATH = os.path.join(CHECKPOINT_DIR, "log.txt")

all_entries = []
with open(LOG_PATH) as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            all_entries.append(json.loads(line))
        except Exception:
            continue

runs, current_run, prev_epoch = [], [], -1

for entry in all_entries:
    ep = entry.get("epoch", 0)

    # Detect restarted runs
    if ep <= prev_epoch and current_run:
        runs.append(current_run)
        current_run = []

    current_run.append(entry)
    prev_epoch = ep

if current_run:
    runs.append(current_run)

if not runs:
    raise RuntimeError(f"No valid log runs found in {LOG_PATH}")

last_run = runs[-1]

# Choose best checkpoint by validation AUC
best_entry = max(last_run, key=lambda e: e["test_image-level AUC"])
best_epoch = int(best_entry["epoch"])
best_auc = float(best_entry["test_image-level AUC"])
best_f1 = float(best_entry.get("test_image-level F1", float("nan")))

print(f"Best epoch from log by AUC: {best_epoch}")
print(f"Best val AUC: {best_auc:.6f}")
print(f"Val F1 at best-AUC epoch: {best_f1:.6f}")

# ── Step 2: select checkpoint ─────────────────────────────────────────────────
best_ckpt = os.path.join(CHECKPOINT_DIR, f"checkpoint-{best_epoch}.pth")

if not os.path.exists(best_ckpt):
    available = sorted(
        [
            f for f in os.listdir(CHECKPOINT_DIR)
            if f.startswith("checkpoint-") and f.endswith(".pth")
        ],
        key=lambda f: int(f.replace("checkpoint-", "").replace(".pth", ""))
    )

    if not available:
        raise FileNotFoundError(f"No checkpoint files found in {CHECKPOINT_DIR}")

    candidates = [
        f for f in available
        if int(f.replace("checkpoint-", "").replace(".pth", "")) <= best_epoch
    ]

    best_ckpt = os.path.join(
        CHECKPOINT_DIR,
        candidates[-1] if candidates else available[-1]
    )

print("Using checkpoint:")
print(best_ckpt)

# ── Step 3: build exact Effort model from ForensicHub registry ────────────────
model_args = {
    "name": "EffortDetector",
    "init_config": {
        "yaml_config_path": f"{BASE}/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml"
    }
}

model = build_from_registry(MODELS, model_args)

checkpoint = torch.load(best_ckpt, map_location=DEVICE, weights_only=False)
state_dict = checkpoint["model"] if "model" in checkpoint else checkpoint

missing, unexpected = model.load_state_dict(state_dict, strict=False)

print(f"Missing keys: {len(missing)}")
print(f"Unexpected keys: {len(unexpected)}")

if len(missing) > 0:
    print("First missing keys:", missing[:10])

if len(unexpected) > 0:
    print("First unexpected keys:", unexpected[:10])

model.to(DEVICE)
model.eval()

# ── Step 4: validation transform ──────────────────────────────────────────────
# Must match your Effort YAML:
# image_size: 224
# transform: AIGCTransform
# norm_type: clip

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.48145466, 0.4578275, 0.40821073],
        std=[0.26862954, 0.26130258, 0.27577711],
    ),
])

# ── Step 5: load validation items and run inference ───────────────────────────
with open(VAL_JSON) as f:
    val_items = json.load(f)

results = []
skipped = []

with torch.no_grad():
    for item in val_items:
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, 224, 224).to(DEVICE),
            }

            out_dict = model(**input_dict)

            prob = out_dict["pred_label"].view(-1)[0].item()
            pred = 1 if prob >= THRESHOLD else 0

            results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": float(prob),
                "correct": bool(pred == label),
            })

        except Exception as e:
            skipped.append({
                "path": path,
                "error": str(e),
            })

if len(results) == 0:
    raise RuntimeError("No validation images were processed successfully.")

print(f"Processed: {len(results)}")
print(f"Skipped: {len(skipped)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# Best epoch from log by AUC: 8
# Best val AUC: 0.714286
# Val F1 at best-AUC epoch: 0.605263
# Using checkpoint:
# /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_3440_train/checkpoint-8.pth
# [lazy import] Loading 'EffortDetector' from 'DeepfakeBench.training.detectors.effort_detector'
# [build_from_registry] Creating model 'EffortDetector' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml'}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/590 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# text_model.embeddings.position_ids   | UNEXPECTED |  |
# vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# embeddings.class_embedding: False
# embeddings.patch_embedding.weight: False
# embeddings.position_embedding.weight: False
# pre_layrnorm.weight: False
# pre_layrnorm.bias: False
# encoder.layers.0.self_attn.k_proj.weight_main: False
# encoder.layers.0.self_attn.k_proj.bias: False
# encoder.layers.0.self_attn.k_proj.S_residual: True
# encoder.layers.0.self_attn.k_proj.U_residual: True
# encoder.layers.0.self_attn.k_proj.V_residual: True
# encoder.layers.0.self_attn.v_proj.weight_main: False
# encoder.layers.0.self_attn.v_proj.bias: False
# encoder.layers.0.self_attn.v_proj.S_residual: True
# encoder.layers.0.self_attn.v_proj.U_residual: True
# encoder.layers.0.self_attn.v_proj.V_residual: True
# encoder.layers.0.self_attn.q_proj.weight_main: False
# encoder.layers.0.self_attn.q_proj.bias: False
# encoder.layers.0.self_attn.q_proj.S_residual: True
# encoder.layers.0.self_attn.q_proj.U_residual: True
# encoder.layers.0.self_attn.q_proj.V_residual: True
# encoder.layers.0.self_attn.out_proj.weight_main: False
# encoder.layers.0.self_attn.out_proj.bias: False
# encoder.layers.0.self_attn.out_proj.S_residual: True
# encoder.layers.0.self_attn.out_proj.U_residual: True
# encoder.layers.0.self_attn.out_proj.V_residual: True
# encoder.layers.0.layer_norm1.weight: False
# encoder.layers.0.layer_norm1.bias: False
# encoder.layers.0.mlp.fc1.weight: False
# encoder.layers.0.mlp.fc1.bias: False
# encoder.layers.0.mlp.fc2.weight: False
# encoder.layers.0.mlp.fc2.bias: False
# encoder.layers.0.layer_norm2.weight: False
# encoder.layers.0.layer_norm2.bias: False
# encoder.layers.1.self_attn.k_proj.weight_main: False
# encoder.layers.1.self_attn.k_proj.bias: False
# encoder.layers.1.self_attn.k_proj.S_residual: True
# encoder.layers.1.self_attn.k_proj.U_residual: True
# encoder.layers.1.self_attn.k_proj.V_residual: True
# encoder.layers.1.self_attn.v_proj.weight_main: False
# encoder.layers.1.self_attn.v_proj.bias: False
# encoder.layers.1.self_attn.v_proj.S_residual: True
# encoder.layers.1.self_attn.v_proj.U_residual: True
# encoder.layers.1.self_attn.v_proj.V_residual: True
# encoder.layers.1.self_attn.q_proj.weight_main: False
# encoder.layers.1.self_attn.q_proj.bias: False
# encoder.layers.1.self_attn.q_proj.S_residual: True
# encoder.layers.1.self_attn.q_proj.U_residual: True
# encoder.layers.1.self_attn.q_proj.V_residual: True
# encoder.layers.1.self_attn.out_proj.weight_main: False
# encoder.layers.1.self_attn.out_proj.bias: False
# encoder.layers.1.self_attn.out_proj.S_residual: True
# encoder.layers.1.self_attn.out_proj.U_residual: True
# encoder.layers.1.self_attn.out_proj.V_residual: True
# encoder.layers.1.layer_norm1.weight: False
# encoder.layers.1.layer_norm1.bias: False
# encoder.layers.1.mlp.fc1.weight: False
# encoder.layers.1.mlp.fc1.bias: False
# encoder.layers.1.mlp.fc2.weight: False
# encoder.layers.1.mlp.fc2.bias: False
# encoder.layers.1.layer_norm2.weight: False
# encoder.layers.1.layer_norm2.bias: False
# encoder.layers.2.self_attn.k_proj.weight_main: False
# encoder.layers.2.self_attn.k_proj.bias: False
# encoder.layers.2.self_attn.k_proj.S_residual: True
# encoder.layers.2.self_attn.k_proj.U_residual: True
# encoder.layers.2.self_attn.k_proj.V_residual: True
# encoder.layers.2.self_attn.v_proj.weight_main: False
# encoder.layers.2.self_attn.v_proj.bias: False
# encoder.layers.2.self_attn.v_proj.S_residual: True
# encoder.layers.2.self_attn.v_proj.U_residual: True
# encoder.layers.2.self_attn.v_proj.V_residual: True
# encoder.layers.2.self_attn.q_proj.weight_main: False
# encoder.layers.2.self_attn.q_proj.bias: False
# encoder.layers.2.self_attn.q_proj.S_residual: True
# encoder.layers.2.self_attn.q_proj.U_residual: True
# encoder.layers.2.self_attn.q_proj.V_residual: True
# encoder.layers.2.self_attn.out_proj.weight_main: False
# encoder.layers.2.self_attn.out_proj.bias: False
# encoder.layers.2.self_attn.out_proj.S_residual: True
# encoder.layers.2.self_attn.out_proj.U_residual: True
# encoder.layers.2.self_attn.out_proj.V_residual: True
# encoder.layers.2.layer_norm1.weight: False
# encoder.layers.2.layer_norm1.bias: False
# encoder.layers.2.mlp.fc1.weight: False
# encoder.layers.2.mlp.fc1.bias: False
# encoder.layers.2.mlp.fc2.weight: False
# encoder.layers.2.mlp.fc2.bias: False
# encoder.layers.2.layer_norm2.weight: False
# encoder.layers.2.layer_norm2.bias: False
# encoder.layers.3.self_attn.k_proj.weight_main: False
# encoder.layers.3.self_attn.k_proj.bias: False
# encoder.layers.3.self_attn.k_proj.S_residual: True
# encoder.layers.3.self_attn.k_proj.U_residual: True
# encoder.layers.3.self_attn.k_proj.V_residual: True
# encoder.layers.3.self_attn.v_proj.weight_main: False
# encoder.layers.3.self_attn.v_proj.bias: False
# encoder.layers.3.self_attn.v_proj.S_residual: True
# encoder.layers.3.self_attn.v_proj.U_residual: True
# encoder.layers.3.self_attn.v_proj.V_residual: True
# encoder.layers.3.self_attn.q_proj.weight_main: False
# encoder.layers.3.self_attn.q_proj.bias: False
# encoder.layers.3.self_attn.q_proj.S_residual: True
# encoder.layers.3.self_attn.q_proj.U_residual: True
# encoder.layers.3.self_attn.q_proj.V_residual: True
# encoder.layers.3.self_attn.out_proj.weight_main: False
# encoder.layers.3.self_attn.out_proj.bias: False
# encoder.layers.3.self_attn.out_proj.S_residual: True
# encoder.layers.3.self_attn.out_proj.U_residual: True
# encoder.layers.3.self_attn.out_proj.V_residual: True
# encoder.layers.3.layer_norm1.weight: False
# encoder.layers.3.layer_norm1.bias: False
# encoder.layers.3.mlp.fc1.weight: False
# encoder.layers.3.mlp.fc1.bias: False
# encoder.layers.3.mlp.fc2.weight: False
# encoder.layers.3.mlp.fc2.bias: False
# encoder.layers.3.layer_norm2.weight: False
# encoder.layers.3.layer_norm2.bias: False
# encoder.layers.4.self_attn.k_proj.weight_main: False
# encoder.layers.4.self_attn.k_proj.bias: False
# encoder.layers.4.self_attn.k_proj.S_residual: True
# encoder.layers.4.self_attn.k_proj.U_residual: True
# encoder.layers.4.self_attn.k_proj.V_residual: True
# encoder.layers.4.self_attn.v_proj.weight_main: False
# encoder.layers.4.self_attn.v_proj.bias: False
# encoder.layers.4.self_attn.v_proj.S_residual: True
# encoder.layers.4.self_attn.v_proj.U_residual: True
# encoder.layers.4.self_attn.v_proj.V_residual: True
# encoder.layers.4.self_attn.q_proj.weight_main: False
# encoder.layers.4.self_attn.q_proj.bias: False
# encoder.layers.4.self_attn.q_proj.S_residual: True
# encoder.layers.4.self_attn.q_proj.U_residual: True
# encoder.layers.4.self_attn.q_proj.V_residual: True
# encoder.layers.4.self_attn.out_proj.weight_main: False
# encoder.layers.4.self_attn.out_proj.bias: False
# encoder.layers.4.self_attn.out_proj.S_residual: True
# encoder.layers.4.self_attn.out_proj.U_residual: True
# encoder.layers.4.self_attn.out_proj.V_residual: True
# encoder.layers.4.layer_norm1.weight: False
# encoder.layers.4.layer_norm1.bias: False
# encoder.layers.4.mlp.fc1.weight: False
# encoder.layers.4.mlp.fc1.bias: False
# encoder.layers.4.mlp.fc2.weight: False
# encoder.layers.4.mlp.fc2.bias: False
# encoder.layers.4.layer_norm2.weight: False
# encoder.layers.4.layer_norm2.bias: False
# encoder.layers.5.self_attn.k_proj.weight_main: False
# encoder.layers.5.self_attn.k_proj.bias: False
# encoder.layers.5.self_attn.k_proj.S_residual: True
# encoder.layers.5.self_attn.k_proj.U_residual: True
# encoder.layers.5.self_attn.k_proj.V_residual: True
# encoder.layers.5.self_attn.v_proj.weight_main: False
# encoder.layers.5.self_attn.v_proj.bias: False
# encoder.layers.5.self_attn.v_proj.S_residual: True
# encoder.layers.5.self_attn.v_proj.U_residual: True
# encoder.layers.5.self_attn.v_proj.V_residual: True
# encoder.layers.5.self_attn.q_proj.weight_main: False
# encoder.layers.5.self_attn.q_proj.bias: False
# encoder.layers.5.self_attn.q_proj.S_residual: True
# encoder.layers.5.self_attn.q_proj.U_residual: True
# encoder.layers.5.self_attn.q_proj.V_residual: True
# encoder.layers.5.self_attn.out_proj.weight_main: False
# encoder.layers.5.self_attn.out_proj.bias: False
# encoder.layers.5.self_attn.out_proj.S_residual: True
# encoder.layers.5.self_attn.out_proj.U_residual: True
# encoder.layers.5.self_attn.out_proj.V_residual: True
# encoder.layers.5.layer_norm1.weight: False
# encoder.layers.5.layer_norm1.bias: False
# encoder.layers.5.mlp.fc1.weight: False
# encoder.layers.5.mlp.fc1.bias: False
# encoder.layers.5.mlp.fc2.weight: False
# encoder.layers.5.mlp.fc2.bias: False
# encoder.layers.5.layer_norm2.weight: False
# encoder.layers.5.layer_norm2.bias: False
# encoder.layers.6.self_attn.k_proj.weight_main: False
# encoder.layers.6.self_attn.k_proj.bias: False
# encoder.layers.6.self_attn.k_proj.S_residual: True
# encoder.layers.6.self_attn.k_proj.U_residual: True
# encoder.layers.6.self_attn.k_proj.V_residual: True
# encoder.layers.6.self_attn.v_proj.weight_main: False
# encoder.layers.6.self_attn.v_proj.bias: False
# encoder.layers.6.self_attn.v_proj.S_residual: True
# encoder.layers.6.self_attn.v_proj.U_residual: True
# encoder.layers.6.self_attn.v_proj.V_residual: True
# encoder.layers.6.self_attn.q_proj.weight_main: False
# encoder.layers.6.self_attn.q_proj.bias: False
# encoder.layers.6.self_attn.q_proj.S_residual: True
# encoder.layers.6.self_attn.q_proj.U_residual: True
# encoder.layers.6.self_attn.q_proj.V_residual: True
# encoder.layers.6.self_attn.out_proj.weight_main: False
# encoder.layers.6.self_attn.out_proj.bias: False
# encoder.layers.6.self_attn.out_proj.S_residual: True
# encoder.layers.6.self_attn.out_proj.U_residual: True
# encoder.layers.6.self_attn.out_proj.V_residual: True
# encoder.layers.6.layer_norm1.weight: False
# encoder.layers.6.layer_norm1.bias: False
# encoder.layers.6.mlp.fc1.weight: False
# encoder.layers.6.mlp.fc1.bias: False
# encoder.layers.6.mlp.fc2.weight: False
# encoder.layers.6.mlp.fc2.bias: False
# encoder.layers.6.layer_norm2.weight: False
# encoder.layers.6.layer_norm2.bias: False
# encoder.layers.7.self_attn.k_proj.weight_main: False
# encoder.layers.7.self_attn.k_proj.bias: False
# encoder.layers.7.self_attn.k_proj.S_residual: True
# encoder.layers.7.self_attn.k_proj.U_residual: True
# encoder.layers.7.self_attn.k_proj.V_residual: True
# encoder.layers.7.self_attn.v_proj.weight_main: False
# encoder.layers.7.self_attn.v_proj.bias: False
# encoder.layers.7.self_attn.v_proj.S_residual: True
# encoder.layers.7.self_attn.v_proj.U_residual: True
# encoder.layers.7.self_attn.v_proj.V_residual: True
# encoder.layers.7.self_attn.q_proj.weight_main: False
# encoder.layers.7.self_attn.q_proj.bias: False
# encoder.layers.7.self_attn.q_proj.S_residual: True
# encoder.layers.7.self_attn.q_proj.U_residual: True
# encoder.layers.7.self_attn.q_proj.V_residual: True
# encoder.layers.7.self_attn.out_proj.weight_main: False
# encoder.layers.7.self_attn.out_proj.bias: False
# encoder.layers.7.self_attn.out_proj.S_residual: True
# encoder.layers.7.self_attn.out_proj.U_residual: True
# encoder.layers.7.self_attn.out_proj.V_residual: True
# encoder.layers.7.layer_norm1.weight: False
# encoder.layers.7.layer_norm1.bias: False
# encoder.layers.7.mlp.fc1.weight: False
# encoder.layers.7.mlp.fc1.bias: False
# encoder.layers.7.mlp.fc2.weight: False
# encoder.layers.7.mlp.fc2.bias: False
# encoder.layers.7.layer_norm2.weight: False
# encoder.layers.7.layer_norm2.bias: False
# encoder.layers.8.self_attn.k_proj.weight_main: False
# encoder.layers.8.self_attn.k_proj.bias: False
# encoder.layers.8.self_attn.k_proj.S_residual: True
# encoder.layers.8.self_attn.k_proj.U_residual: True
# encoder.layers.8.self_attn.k_proj.V_residual: True
# encoder.layers.8.self_attn.v_proj.weight_main: False
# encoder.layers.8.self_attn.v_proj.bias: False
# encoder.layers.8.self_attn.v_proj.S_residual: True
# encoder.layers.8.self_attn.v_proj.U_residual: True
# encoder.layers.8.self_attn.v_proj.V_residual: True
# encoder.layers.8.self_attn.q_proj.weight_main: False
# encoder.layers.8.self_attn.q_proj.bias: False
# encoder.layers.8.self_attn.q_proj.S_residual: True
# encoder.layers.8.self_attn.q_proj.U_residual: True
# encoder.layers.8.self_attn.q_proj.V_residual: True
# encoder.layers.8.self_attn.out_proj.weight_main: False
# encoder.layers.8.self_attn.out_proj.bias: False
# encoder.layers.8.self_attn.out_proj.S_residual: True
# encoder.layers.8.self_attn.out_proj.U_residual: True
# encoder.layers.8.self_attn.out_proj.V_residual: True
# encoder.layers.8.layer_norm1.weight: False
# encoder.layers.8.layer_norm1.bias: False
# encoder.layers.8.mlp.fc1.weight: False
# encoder.layers.8.mlp.fc1.bias: False
# encoder.layers.8.mlp.fc2.weight: False
# encoder.layers.8.mlp.fc2.bias: False
# encoder.layers.8.layer_norm2.weight: False
# encoder.layers.8.layer_norm2.bias: False
# encoder.layers.9.self_attn.k_proj.weight_main: False
# encoder.layers.9.self_attn.k_proj.bias: False
# encoder.layers.9.self_attn.k_proj.S_residual: True
# encoder.layers.9.self_attn.k_proj.U_residual: True
# encoder.layers.9.self_attn.k_proj.V_residual: True
# encoder.layers.9.self_attn.v_proj.weight_main: False
# encoder.layers.9.self_attn.v_proj.bias: False
# encoder.layers.9.self_attn.v_proj.S_residual: True
# encoder.layers.9.self_attn.v_proj.U_residual: True
# encoder.layers.9.self_attn.v_proj.V_residual: True
# encoder.layers.9.self_attn.q_proj.weight_main: False
# encoder.layers.9.self_attn.q_proj.bias: False
# encoder.layers.9.self_attn.q_proj.S_residual: True
# encoder.layers.9.self_attn.q_proj.U_residual: True
# encoder.layers.9.self_attn.q_proj.V_residual: True
# encoder.layers.9.self_attn.out_proj.weight_main: False
# encoder.layers.9.self_attn.out_proj.bias: False
# encoder.layers.9.self_attn.out_proj.S_residual: True
# encoder.layers.9.self_attn.out_proj.U_residual: True
# encoder.layers.9.self_attn.out_proj.V_residual: True
# encoder.layers.9.layer_norm1.weight: False
# encoder.layers.9.layer_norm1.bias: False
# encoder.layers.9.mlp.fc1.weight: False
# encoder.layers.9.mlp.fc1.bias: False
# encoder.layers.9.mlp.fc2.weight: False
# encoder.layers.9.mlp.fc2.bias: False
# encoder.layers.9.layer_norm2.weight: False
# encoder.layers.9.layer_norm2.bias: False
# encoder.layers.10.self_attn.k_proj.weight_main: False
# encoder.layers.10.self_attn.k_proj.bias: False
# encoder.layers.10.self_attn.k_proj.S_residual: True
# encoder.layers.10.self_attn.k_proj.U_residual: True
# encoder.layers.10.self_attn.k_proj.V_residual: True
# encoder.layers.10.self_attn.v_proj.weight_main: False
# encoder.layers.10.self_attn.v_proj.bias: False
# encoder.layers.10.self_attn.v_proj.S_residual: True
# encoder.layers.10.self_attn.v_proj.U_residual: True
# encoder.layers.10.self_attn.v_proj.V_residual: True
# encoder.layers.10.self_attn.q_proj.weight_main: False
# encoder.layers.10.self_attn.q_proj.bias: False
# encoder.layers.10.self_attn.q_proj.S_residual: True
# encoder.layers.10.self_attn.q_proj.U_residual: True
# encoder.layers.10.self_attn.q_proj.V_residual: True
# encoder.layers.10.self_attn.out_proj.weight_main: False
# encoder.layers.10.self_attn.out_proj.bias: False
# encoder.layers.10.self_attn.out_proj.S_residual: True
# encoder.layers.10.self_attn.out_proj.U_residual: True
# encoder.layers.10.self_attn.out_proj.V_residual: True
# encoder.layers.10.layer_norm1.weight: False
# encoder.layers.10.layer_norm1.bias: False
# encoder.layers.10.mlp.fc1.weight: False
# encoder.layers.10.mlp.fc1.bias: False
# encoder.layers.10.mlp.fc2.weight: False
# encoder.layers.10.mlp.fc2.bias: False
# encoder.layers.10.layer_norm2.weight: False
# encoder.layers.10.layer_norm2.bias: False
# encoder.layers.11.self_attn.k_proj.weight_main: False
# encoder.layers.11.self_attn.k_proj.bias: False
# encoder.layers.11.self_attn.k_proj.S_residual: True
# encoder.layers.11.self_attn.k_proj.U_residual: True
# encoder.layers.11.self_attn.k_proj.V_residual: True
# encoder.layers.11.self_attn.v_proj.weight_main: False
# encoder.layers.11.self_attn.v_proj.bias: False
# encoder.layers.11.self_attn.v_proj.S_residual: True
# encoder.layers.11.self_attn.v_proj.U_residual: True
# encoder.layers.11.self_attn.v_proj.V_residual: True
# encoder.layers.11.self_attn.q_proj.weight_main: False
# encoder.layers.11.self_attn.q_proj.bias: False
# encoder.layers.11.self_attn.q_proj.S_residual: True
# encoder.layers.11.self_attn.q_proj.U_residual: True
# encoder.layers.11.self_attn.q_proj.V_residual: True
# encoder.layers.11.self_attn.out_proj.weight_main: False
# encoder.layers.11.self_attn.out_proj.bias: False
# encoder.layers.11.self_attn.out_proj.S_residual: True
# encoder.layers.11.self_attn.out_proj.U_residual: True
# encoder.layers.11.self_attn.out_proj.V_residual: True
# encoder.layers.11.layer_norm1.weight: False
# encoder.layers.11.layer_norm1.bias: False
# encoder.layers.11.mlp.fc1.weight: False
# encoder.layers.11.mlp.fc1.bias: False
# encoder.layers.11.mlp.fc2.weight: False
# encoder.layers.11.mlp.fc2.bias: False
# encoder.layers.11.layer_norm2.weight: False
# encoder.layers.11.layer_norm2.bias: False
# encoder.layers.12.self_attn.k_proj.weight_main: False
# encoder.layers.12.self_attn.k_proj.bias: False
# encoder.layers.12.self_attn.k_proj.S_residual: True
# encoder.layers.12.self_attn.k_proj.U_residual: True
# encoder.layers.12.self_attn.k_proj.V_residual: True
# encoder.layers.12.self_attn.v_proj.weight_main: False
# encoder.layers.12.self_attn.v_proj.bias: False
# encoder.layers.12.self_attn.v_proj.S_residual: True
# encoder.layers.12.self_attn.v_proj.U_residual: True
# encoder.layers.12.self_attn.v_proj.V_residual: True
# encoder.layers.12.self_attn.q_proj.weight_main: False
# encoder.layers.12.self_attn.q_proj.bias: False
# encoder.layers.12.self_attn.q_proj.S_residual: True
# encoder.layers.12.self_attn.q_proj.U_residual: True
# encoder.layers.12.self_attn.q_proj.V_residual: True
# encoder.layers.12.self_attn.out_proj.weight_main: False
# encoder.layers.12.self_attn.out_proj.bias: False
# encoder.layers.12.self_attn.out_proj.S_residual: True
# encoder.layers.12.self_attn.out_proj.U_residual: True
# encoder.layers.12.self_attn.out_proj.V_residual: True
# encoder.layers.12.layer_norm1.weight: False
# encoder.layers.12.layer_norm1.bias: False
# encoder.layers.12.mlp.fc1.weight: False
# encoder.layers.12.mlp.fc1.bias: False
# encoder.layers.12.mlp.fc2.weight: False
# encoder.layers.12.mlp.fc2.bias: False
# encoder.layers.12.layer_norm2.weight: False
# encoder.layers.12.layer_norm2.bias: False
# encoder.layers.13.self_attn.k_proj.weight_main: False
# encoder.layers.13.self_attn.k_proj.bias: False
# encoder.layers.13.self_attn.k_proj.S_residual: True
# encoder.layers.13.self_attn.k_proj.U_residual: True
# encoder.layers.13.self_attn.k_proj.V_residual: True
# encoder.layers.13.self_attn.v_proj.weight_main: False
# encoder.layers.13.self_attn.v_proj.bias: False
# encoder.layers.13.self_attn.v_proj.S_residual: True
# encoder.layers.13.self_attn.v_proj.U_residual: True
# encoder.layers.13.self_attn.v_proj.V_residual: True
# encoder.layers.13.self_attn.q_proj.weight_main: False
# encoder.layers.13.self_attn.q_proj.bias: False
# encoder.layers.13.self_attn.q_proj.S_residual: True
# encoder.layers.13.self_attn.q_proj.U_residual: True
# encoder.layers.13.self_attn.q_proj.V_residual: True
# encoder.layers.13.self_attn.out_proj.weight_main: False
# encoder.layers.13.self_attn.out_proj.bias: False
# encoder.layers.13.self_attn.out_proj.S_residual: True
# encoder.layers.13.self_attn.out_proj.U_residual: True
# encoder.layers.13.self_attn.out_proj.V_residual: True
# encoder.layers.13.layer_norm1.weight: False
# encoder.layers.13.layer_norm1.bias: False
# encoder.layers.13.mlp.fc1.weight: False
# encoder.layers.13.mlp.fc1.bias: False
# encoder.layers.13.mlp.fc2.weight: False
# encoder.layers.13.mlp.fc2.bias: False
# encoder.layers.13.layer_norm2.weight: False
# encoder.layers.13.layer_norm2.bias: False
# encoder.layers.14.self_attn.k_proj.weight_main: False
# encoder.layers.14.self_attn.k_proj.bias: False
# encoder.layers.14.self_attn.k_proj.S_residual: True
# encoder.layers.14.self_attn.k_proj.U_residual: True
# encoder.layers.14.self_attn.k_proj.V_residual: True
# encoder.layers.14.self_attn.v_proj.weight_main: False
# encoder.layers.14.self_attn.v_proj.bias: False
# encoder.layers.14.self_attn.v_proj.S_residual: True
# encoder.layers.14.self_attn.v_proj.U_residual: True
# encoder.layers.14.self_attn.v_proj.V_residual: True
# encoder.layers.14.self_attn.q_proj.weight_main: False
# encoder.layers.14.self_attn.q_proj.bias: False
# encoder.layers.14.self_attn.q_proj.S_residual: True
# encoder.layers.14.self_attn.q_proj.U_residual: True
# encoder.layers.14.self_attn.q_proj.V_residual: True
# encoder.layers.14.self_attn.out_proj.weight_main: False
# encoder.layers.14.self_attn.out_proj.bias: False
# encoder.layers.14.self_attn.out_proj.S_residual: True
# encoder.layers.14.self_attn.out_proj.U_residual: True
# encoder.layers.14.self_attn.out_proj.V_residual: True
# encoder.layers.14.layer_norm1.weight: False
# encoder.layers.14.layer_norm1.bias: False
# encoder.layers.14.mlp.fc1.weight: False
# encoder.layers.14.mlp.fc1.bias: False
# encoder.layers.14.mlp.fc2.weight: False
# encoder.layers.14.mlp.fc2.bias: False
# encoder.layers.14.layer_norm2.weight: False
# encoder.layers.14.layer_norm2.bias: False
# encoder.layers.15.self_attn.k_proj.weight_main: False
# encoder.layers.15.self_attn.k_proj.bias: False
# encoder.layers.15.self_attn.k_proj.S_residual: True
# encoder.layers.15.self_attn.k_proj.U_residual: True
# encoder.layers.15.self_attn.k_proj.V_residual: True
# encoder.layers.15.self_attn.v_proj.weight_main: False
# encoder.layers.15.self_attn.v_proj.bias: False
# encoder.layers.15.self_attn.v_proj.S_residual: True
# encoder.layers.15.self_attn.v_proj.U_residual: True
# encoder.layers.15.self_attn.v_proj.V_residual: True
# encoder.layers.15.self_attn.q_proj.weight_main: False
# encoder.layers.15.self_attn.q_proj.bias: False
# encoder.layers.15.self_attn.q_proj.S_residual: True
# encoder.layers.15.self_attn.q_proj.U_residual: True
# encoder.layers.15.self_attn.q_proj.V_residual: True
# encoder.layers.15.self_attn.out_proj.weight_main: False
# encoder.layers.15.self_attn.out_proj.bias: False
# encoder.layers.15.self_attn.out_proj.S_residual: True
# encoder.layers.15.self_attn.out_proj.U_residual: True
# encoder.layers.15.self_attn.out_proj.V_residual: True
# encoder.layers.15.layer_norm1.weight: False
# encoder.layers.15.layer_norm1.bias: False
# encoder.layers.15.mlp.fc1.weight: False
# encoder.layers.15.mlp.fc1.bias: False
# encoder.layers.15.mlp.fc2.weight: False
# encoder.layers.15.mlp.fc2.bias: False
# encoder.layers.15.layer_norm2.weight: False
# encoder.layers.15.layer_norm2.bias: False
# encoder.layers.16.self_attn.k_proj.weight_main: False
# encoder.layers.16.self_attn.k_proj.bias: False
# encoder.layers.16.self_attn.k_proj.S_residual: True
# encoder.layers.16.self_attn.k_proj.U_residual: True
# encoder.layers.16.self_attn.k_proj.V_residual: True
# encoder.layers.16.self_attn.v_proj.weight_main: False
# encoder.layers.16.self_attn.v_proj.bias: False
# encoder.layers.16.self_attn.v_proj.S_residual: True
# encoder.layers.16.self_attn.v_proj.U_residual: True
# encoder.layers.16.self_attn.v_proj.V_residual: True
# encoder.layers.16.self_attn.q_proj.weight_main: False
# encoder.layers.16.self_attn.q_proj.bias: False
# encoder.layers.16.self_attn.q_proj.S_residual: True
# encoder.layers.16.self_attn.q_proj.U_residual: True
# encoder.layers.16.self_attn.q_proj.V_residual: True
# encoder.layers.16.self_attn.out_proj.weight_main: False
# encoder.layers.16.self_attn.out_proj.bias: False
# encoder.layers.16.self_attn.out_proj.S_residual: True
# encoder.layers.16.self_attn.out_proj.U_residual: True
# encoder.layers.16.self_attn.out_proj.V_residual: True
# encoder.layers.16.layer_norm1.weight: False
# encoder.layers.16.layer_norm1.bias: False
# encoder.layers.16.mlp.fc1.weight: False
# encoder.layers.16.mlp.fc1.bias: False
# encoder.layers.16.mlp.fc2.weight: False
# encoder.layers.16.mlp.fc2.bias: False
# encoder.layers.16.layer_norm2.weight: False
# encoder.layers.16.layer_norm2.bias: False
# encoder.layers.17.self_attn.k_proj.weight_main: False
# encoder.layers.17.self_attn.k_proj.bias: False
# encoder.layers.17.self_attn.k_proj.S_residual: True
# encoder.layers.17.self_attn.k_proj.U_residual: True
# encoder.layers.17.self_attn.k_proj.V_residual: True
# encoder.layers.17.self_attn.v_proj.weight_main: False
# encoder.layers.17.self_attn.v_proj.bias: False
# encoder.layers.17.self_attn.v_proj.S_residual: True
# encoder.layers.17.self_attn.v_proj.U_residual: True
# encoder.layers.17.self_attn.v_proj.V_residual: True
# encoder.layers.17.self_attn.q_proj.weight_main: False
# encoder.layers.17.self_attn.q_proj.bias: False
# encoder.layers.17.self_attn.q_proj.S_residual: True
# encoder.layers.17.self_attn.q_proj.U_residual: True
# encoder.layers.17.self_attn.q_proj.V_residual: True
# encoder.layers.17.self_attn.out_proj.weight_main: False
# encoder.layers.17.self_attn.out_proj.bias: False
# encoder.layers.17.self_attn.out_proj.S_residual: True
# encoder.layers.17.self_attn.out_proj.U_residual: True
# encoder.layers.17.self_attn.out_proj.V_residual: True
# encoder.layers.17.layer_norm1.weight: False
# encoder.layers.17.layer_norm1.bias: False
# encoder.layers.17.mlp.fc1.weight: False
# encoder.layers.17.mlp.fc1.bias: False
# encoder.layers.17.mlp.fc2.weight: False
# encoder.layers.17.mlp.fc2.bias: False
# encoder.layers.17.layer_norm2.weight: False
# encoder.layers.17.layer_norm2.bias: False
# encoder.layers.18.self_attn.k_proj.weight_main: False
# encoder.layers.18.self_attn.k_proj.bias: False
# encoder.layers.18.self_attn.k_proj.S_residual: True
# encoder.layers.18.self_attn.k_proj.U_residual: True
# encoder.layers.18.self_attn.k_proj.V_residual: True
# encoder.layers.18.self_attn.v_proj.weight_main: False
# encoder.layers.18.self_attn.v_proj.bias: False
# encoder.layers.18.self_attn.v_proj.S_residual: True
# encoder.layers.18.self_attn.v_proj.U_residual: True
# encoder.layers.18.self_attn.v_proj.V_residual: True
# encoder.layers.18.self_attn.q_proj.weight_main: False
# encoder.layers.18.self_attn.q_proj.bias: False
# encoder.layers.18.self_attn.q_proj.S_residual: True
# encoder.layers.18.self_attn.q_proj.U_residual: True
# encoder.layers.18.self_attn.q_proj.V_residual: True
# encoder.layers.18.self_attn.out_proj.weight_main: False
# encoder.layers.18.self_attn.out_proj.bias: False
# encoder.layers.18.self_attn.out_proj.S_residual: True
# encoder.layers.18.self_attn.out_proj.U_residual: True
# encoder.layers.18.self_attn.out_proj.V_residual: True
# encoder.layers.18.layer_norm1.weight: False
# encoder.layers.18.layer_norm1.bias: False
# encoder.layers.18.mlp.fc1.weight: False
# encoder.layers.18.mlp.fc1.bias: False
# encoder.layers.18.mlp.fc2.weight: False
# encoder.layers.18.mlp.fc2.bias: False
# encoder.layers.18.layer_norm2.weight: False
# encoder.layers.18.layer_norm2.bias: False
# encoder.layers.19.self_attn.k_proj.weight_main: False
# encoder.layers.19.self_attn.k_proj.bias: False
# encoder.layers.19.self_attn.k_proj.S_residual: True
# encoder.layers.19.self_attn.k_proj.U_residual: True
# encoder.layers.19.self_attn.k_proj.V_residual: True
# encoder.layers.19.self_attn.v_proj.weight_main: False
# encoder.layers.19.self_attn.v_proj.bias: False
# encoder.layers.19.self_attn.v_proj.S_residual: True
# encoder.layers.19.self_attn.v_proj.U_residual: True
# encoder.layers.19.self_attn.v_proj.V_residual: True
# encoder.layers.19.self_attn.q_proj.weight_main: False
# encoder.layers.19.self_attn.q_proj.bias: False
# encoder.layers.19.self_attn.q_proj.S_residual: True
# encoder.layers.19.self_attn.q_proj.U_residual: True
# encoder.layers.19.self_attn.q_proj.V_residual: True
# encoder.layers.19.self_attn.out_proj.weight_main: False
# encoder.layers.19.self_attn.out_proj.bias: False
# encoder.layers.19.self_attn.out_proj.S_residual: True
# encoder.layers.19.self_attn.out_proj.U_residual: True
# encoder.layers.19.self_attn.out_proj.V_residual: True
# encoder.layers.19.layer_norm1.weight: False
# encoder.layers.19.layer_norm1.bias: False
# encoder.layers.19.mlp.fc1.weight: False
# encoder.layers.19.mlp.fc1.bias: False
# encoder.layers.19.mlp.fc2.weight: False
# encoder.layers.19.mlp.fc2.bias: False
# encoder.layers.19.layer_norm2.weight: False
# encoder.layers.19.layer_norm2.bias: False
# encoder.layers.20.self_attn.k_proj.weight_main: False
# encoder.layers.20.self_attn.k_proj.bias: False
# encoder.layers.20.self_attn.k_proj.S_residual: True
# encoder.layers.20.self_attn.k_proj.U_residual: True
# encoder.layers.20.self_attn.k_proj.V_residual: True
# encoder.layers.20.self_attn.v_proj.weight_main: False
# encoder.layers.20.self_attn.v_proj.bias: False
# encoder.layers.20.self_attn.v_proj.S_residual: True
# encoder.layers.20.self_attn.v_proj.U_residual: True
# encoder.layers.20.self_attn.v_proj.V_residual: True
# encoder.layers.20.self_attn.q_proj.weight_main: False
# encoder.layers.20.self_attn.q_proj.bias: False
# encoder.layers.20.self_attn.q_proj.S_residual: True
# encoder.layers.20.self_attn.q_proj.U_residual: True
# encoder.layers.20.self_attn.q_proj.V_residual: True
# encoder.layers.20.self_attn.out_proj.weight_main: False
# encoder.layers.20.self_attn.out_proj.bias: False
# encoder.layers.20.self_attn.out_proj.S_residual: True
# encoder.layers.20.self_attn.out_proj.U_residual: True
# encoder.layers.20.self_attn.out_proj.V_residual: True
# encoder.layers.20.layer_norm1.weight: False
# encoder.layers.20.layer_norm1.bias: False
# encoder.layers.20.mlp.fc1.weight: False
# encoder.layers.20.mlp.fc1.bias: False
# encoder.layers.20.mlp.fc2.weight: False
# encoder.layers.20.mlp.fc2.bias: False
# encoder.layers.20.layer_norm2.weight: False
# encoder.layers.20.layer_norm2.bias: False
# encoder.layers.21.self_attn.k_proj.weight_main: False
# encoder.layers.21.self_attn.k_proj.bias: False
# encoder.layers.21.self_attn.k_proj.S_residual: True
# encoder.layers.21.self_attn.k_proj.U_residual: True
# encoder.layers.21.self_attn.k_proj.V_residual: True
# encoder.layers.21.self_attn.v_proj.weight_main: False
# encoder.layers.21.self_attn.v_proj.bias: False
# encoder.layers.21.self_attn.v_proj.S_residual: True
# encoder.layers.21.self_attn.v_proj.U_residual: True
# encoder.layers.21.self_attn.v_proj.V_residual: True
# encoder.layers.21.self_attn.q_proj.weight_main: False
# encoder.layers.21.self_attn.q_proj.bias: False
# encoder.layers.21.self_attn.q_proj.S_residual: True
# encoder.layers.21.self_attn.q_proj.U_residual: True
# encoder.layers.21.self_attn.q_proj.V_residual: True
# encoder.layers.21.self_attn.out_proj.weight_main: False
# encoder.layers.21.self_attn.out_proj.bias: False
# encoder.layers.21.self_attn.out_proj.S_residual: True
# encoder.layers.21.self_attn.out_proj.U_residual: True
# encoder.layers.21.self_attn.out_proj.V_residual: True
# encoder.layers.21.layer_norm1.weight: False
# encoder.layers.21.layer_norm1.bias: False
# encoder.layers.21.mlp.fc1.weight: False
# encoder.layers.21.mlp.fc1.bias: False
# encoder.layers.21.mlp.fc2.weight: False
# encoder.layers.21.mlp.fc2.bias: False
# encoder.layers.21.layer_norm2.weight: False
# encoder.layers.21.layer_norm2.bias: False
# encoder.layers.22.self_attn.k_proj.weight_main: False
# encoder.layers.22.self_attn.k_proj.bias: False
# encoder.layers.22.self_attn.k_proj.S_residual: True
# encoder.layers.22.self_attn.k_proj.U_residual: True
# encoder.layers.22.self_attn.k_proj.V_residual: True
# encoder.layers.22.self_attn.v_proj.weight_main: False
# encoder.layers.22.self_attn.v_proj.bias: False
# encoder.layers.22.self_attn.v_proj.S_residual: True
# encoder.layers.22.self_attn.v_proj.U_residual: True
# encoder.layers.22.self_attn.v_proj.V_residual: True
# encoder.layers.22.self_attn.q_proj.weight_main: False
# encoder.layers.22.self_attn.q_proj.bias: False
# encoder.layers.22.self_attn.q_proj.S_residual: True
# encoder.layers.22.self_attn.q_proj.U_residual: True
# encoder.layers.22.self_attn.q_proj.V_residual: True
# encoder.layers.22.self_attn.out_proj.weight_main: False
# encoder.layers.22.self_attn.out_proj.bias: False
# encoder.layers.22.self_attn.out_proj.S_residual: True
# encoder.layers.22.self_attn.out_proj.U_residual: True
# encoder.layers.22.self_attn.out_proj.V_residual: True
# encoder.layers.22.layer_norm1.weight: False
# encoder.layers.22.layer_norm1.bias: False
# encoder.layers.22.mlp.fc1.weight: False
# encoder.layers.22.mlp.fc1.bias: False
# encoder.layers.22.mlp.fc2.weight: False
# encoder.layers.22.mlp.fc2.bias: False
# encoder.layers.22.layer_norm2.weight: False
# encoder.layers.22.layer_norm2.bias: False
# encoder.layers.23.self_attn.k_proj.weight_main: False
# encoder.layers.23.self_attn.k_proj.bias: False
# encoder.layers.23.self_attn.k_proj.S_residual: True
# encoder.layers.23.self_attn.k_proj.U_residual: True
# encoder.layers.23.self_attn.k_proj.V_residual: True
# encoder.layers.23.self_attn.v_proj.weight_main: False
# encoder.layers.23.self_attn.v_proj.bias: False
# encoder.layers.23.self_attn.v_proj.S_residual: True
# encoder.layers.23.self_attn.v_proj.U_residual: True
# encoder.layers.23.self_attn.v_proj.V_residual: True
# encoder.layers.23.self_attn.q_proj.weight_main: False
# encoder.layers.23.self_attn.q_proj.bias: False
# encoder.layers.23.self_attn.q_proj.S_residual: True
# encoder.layers.23.self_attn.q_proj.U_residual: True
# encoder.layers.23.self_attn.q_proj.V_residual: True
# encoder.layers.23.self_attn.out_proj.weight_main: False
# encoder.layers.23.self_attn.out_proj.bias: False
# encoder.layers.23.self_attn.out_proj.S_residual: True
# encoder.layers.23.self_attn.out_proj.U_residual: True
# encoder.layers.23.self_attn.out_proj.V_residual: True
# encoder.layers.23.layer_norm1.weight: False
# encoder.layers.23.layer_norm1.bias: False
# encoder.layers.23.mlp.fc1.weight: False
# encoder.layers.23.mlp.fc1.bias: False
# encoder.layers.23.mlp.fc2.weight: False
# encoder.layers.23.mlp.fc2.bias: False
# encoder.layers.23.layer_norm2.weight: False
# encoder.layers.23.layer_norm2.bias: False
# post_layernorm.weight: False
# post_layernorm.bias: False
# Number of total parameters: 303376480, tunable parameters: 196704
# Missing keys: 0
# Unexpected keys: 0
# Processed: 100
# Skipped: 0

# %%
# ── Inference on TRAINING set, Effort model already loaded ──
import json
import torch
from PIL import Image
import numpy as np
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score

TRAIN_JSON = "/content/DiffusionForensics_Recons/train.json"

with open(TRAIN_JSON) as f:
    train_items = json.load(f)

print(f"Running inference on {len(train_items)} training images...")

train_results = []
train_skipped = []

with torch.no_grad():
    for i, item in enumerate(train_items):
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, 224, 224).to(DEVICE),
            }

            out_dict = model(**input_dict)

            prob = out_dict["pred_label"].view(-1)[0].item()
            pred = 1 if prob >= THRESHOLD else 0

            train_results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": float(prob),
                "correct": bool(pred == label),
            })

        except Exception as e:
            train_skipped.append({
                "path": path,
                "error": str(e),
            })

        if (i + 1) % 500 == 0:
            print(f"  {i+1}/{len(train_items)} processed | ok={len(train_results)} | skipped={len(train_skipped)}")

if len(train_results) == 0:
    raise RuntimeError("No training images were processed successfully.")

train_labels = np.array([r["true_label"] for r in train_results])
train_scores = np.array([r["confidence"] for r in train_results])
train_preds = np.array([r["pred"] for r in train_results])

train_acc = accuracy_score(train_labels, train_preds)
train_f1 = f1_score(train_labels, train_preds)
train_auc = roc_auc_score(train_labels, train_scores)

print("\n=== Train set results ===")
print(f"Processed: {len(train_results)}")
print(f"Skipped:   {len(train_skipped)}")
print(f"Train accuracy: {train_acc * 100:.2f}%")
print(f"Train F1:       {train_f1:.4f}")
print(f"Train AUC:      {train_auc:.4f}")
# Out:
# Running inference on 3440 training images...
#   500/3440 processed | ok=500 | skipped=0
#   1000/3440 processed | ok=1000 | skipped=0
#   1500/3440 processed | ok=1500 | skipped=0
#   2000/3440 processed | ok=2000 | skipped=0
#   2500/3440 processed | ok=2500 | skipped=0
#   3000/3440 processed | ok=3000 | skipped=0
#
# === Train set results ===
# Processed: 3440
# Skipped:   0
# Train accuracy: 92.97%
# Train F1:       0.9291
# Train AUC:      0.9843

# %%
# ── ROC Curve: Validation only ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from IPython.display import Image, display

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

# ── Validation ROC ──
y_true = np.array([r["true_label"] for r in results])
y_score = np.array([r["confidence"] for r in results])

fpr, tpr, thresh = roc_curve(y_true, y_score)
auc_val = auc(fpr, tpr)

# ── Plot ──
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor('#FAFAFA')

ax.set_facecolor('#F4F4F4')
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_color('#CCCCCC')
ax.set_aspect('equal')

ax.plot(fpr, tpr, color='#7B4FB5', linewidth=2.5, label='ROC curve')
ax.fill_between(fpr, tpr, alpha=0.25, color='#9B7FD4')

ax.text(0.55, 0.35, f'AUC = {auc_val:.2f}', fontsize=20,
        fontweight='bold', color='#5A3A8A',
        ha='center', va='center')

# Random baseline
ax.plot([0, 1], [0, 1], color='#888', linestyle='--', linewidth=1,
        label='Random (0.50)')

# Best threshold (Youden)
opt_idx = np.argmax(tpr - fpr)
ax.scatter(fpr[opt_idx], tpr[opt_idx], color='#7B4FB5',
           s=100, zorder=5, edgecolors='white', linewidths=2)

ax.annotate(f'Best: {thresh[opt_idx]:.3f}\n'
            f'TPR={tpr[opt_idx]:.2f}, FPR={fpr[opt_idx]:.2f}',
            xy=(fpr[opt_idx], tpr[opt_idx]),
            xytext=(fpr[opt_idx] + 0.15, tpr[opt_idx] - 0.12),
            fontsize=9, color='#5A3A8A',
            arrowprops=dict(arrowstyle='->', color='#7B4FB5', lw=1.5))

ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_xlabel('FPR', fontsize=12)
ax.set_ylabel('TPR', fontsize=12)
ax.set_title('ROC — Validation Set (Effort FHub)', fontsize=14, pad=12)

ax.legend(fontsize=10, loc='lower right', framealpha=0.5)

plt.tight_layout()
plt.savefig('roc_val.jpg', dpi=80, bbox_inches='tight',
            facecolor=fig.get_facecolor())
plt.close(fig)

display(Image('roc_val.jpg'))

print(f"\nValidation AUC: {auc_val:.4f}")
print(f"Best threshold: {thresh[opt_idx]:.4f}")
# Out:
# Validation AUC: 0.7048
# Best threshold: 0.7368

# %%
# ── Confusion Matrix: Validation only ──
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from IPython.display import Image, display

def compute_metrics(res):
    y_true = [r["true_label"] for r in res]
    y_pred = [r["pred"]       for r in res]

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    TN, FP, FN, TP = cm.ravel()

    total     = TP + TN + FP + FN
    accuracy  = (TP + TN) / total                if total > 0 else 0.0
    precision = TP / (TP + FP)                   if (TP + FP) > 0 else 0.0
    recall    = TP / (TP + FN)                   if (TP + FN) > 0 else 0.0
    f1        = 2*TP / (2*TP + FP + FN)          if (2*TP+FP+FN) > 0 else 0.0

    return TN, FP, FN, TP, accuracy, precision, recall, f1

def draw_cm(ax, TN, FP, FN, TP, title):
    cell_labels = [['TN', 'FP'], ['FN', 'TP']]
    cell_values = [[TN, FP], [FN, TP]]
    cell_colors = [['#d4edda', '#f8d7da'],
                   ['#f8d7da', '#d4edda']]

    for i in range(2):
        for j in range(2):
            ax.add_patch(plt.Rectangle((j, 1 - i), 1, 1,
                                       facecolor=cell_colors[i][j],
                                       edgecolor='black', linewidth=1.5))
            ax.text(j + 0.5, 1 - i + 0.5,
                    f'{cell_labels[i][j]}\n{cell_values[i][j]}',
                    ha='center', va='center',
                    fontsize=18, fontweight='bold', color='black')

    ax.set_xlim(0, 2)
    ax.set_ylim(0, 2)
    ax.set_xticks([0.5, 1.5])
    ax.set_yticks([0.5, 1.5])

    ax.set_xticklabels(['Predicted REAL', 'Predicted FAKE'], fontsize=10)
    ax.set_yticklabels(['FAKE (1)', 'REAL (0)'], fontsize=10)

    ax.set_xlabel('Predicted label', fontsize=11, labelpad=8)
    ax.set_ylabel('True label',      fontsize=11, labelpad=8)

    ax.tick_params(length=0)
    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_title(title, fontsize=11, pad=14)

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

# Compute validation metrics
TN, FP, FN, TP, acc, prec, rec, f1 = compute_metrics(results)

# Print summary
print(f"{'═'*50}")
print(f"  Validation Metrics")
print(f"{'═'*50}")
print(f"  TP (correct fake): {TP}")
print(f"  TN (correct real): {TN}")
print(f"  FP (false alarm): {FP}")
print(f"  FN (missed fake): {FN}")


# Plot
fig, ax = plt.subplots(figsize=(6, 5))
fig.patch.set_facecolor('white')

draw_cm(
    ax,
    TN, FP, FN, TP,
    f''
    # f'Validation  ·  Acc {acc*100:.1f}%  ·  Prec {prec*100:.1f}%  ·  '
    # f'Rec {rec*100:.1f}%  ·  F1 {f1*100:.1f}%'
)

plt.suptitle('Confusion Matrix — Validation 100 (Effort)', fontsize=14, y=1.02)
plt.tight_layout()

plt.savefig('confusion_matrix_val.jpg', dpi=80, bbox_inches='tight',
            facecolor=fig.get_facecolor())
plt.close(fig)

display(Image('confusion_matrix_val.jpg'))
# Out:
# ══════════════════════════════════════════════════
#   Validation Metrics
# ══════════════════════════════════════════════════
#   TP (correct fake): 26
#   TN (correct real): 44
#   FP (false alarm): 6
#   FN (missed fake): 24

# %%
# Badly / Well Detected dataset — VALIDATION
# Full updated cell: includes image number extracted from filename/path

# %matplotlib inline

import os
import re
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image, display

# ── Rebuild all summary information from `results` ────────────────────────────
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

total = len(results)
n_correct = sum(r["correct"] for r in results)
accuracy = 100 * n_correct / total

probs = [r["confidence"] for r in results]

well  = [r for r in results if r["correct"]]
badly = [r for r in results if not r["correct"]]

well_sorted  = sorted(well,  key=lambda x: abs(x["confidence"] - 0.5), reverse=True)
badly_sorted = sorted(badly, key=lambda x: abs(x["confidence"] - 0.5), reverse=True)

well_sample  = well_sorted[:100]
badly_sample = badly_sorted[:100]

n_real = sum(r["true_label"] == 0 for r in results)
n_fake = sum(r["true_label"] == 1 for r in results)

tp = sum((r["true_label"] == 1 and r["pred"] == 1) for r in results)
tn = sum((r["true_label"] == 0 and r["pred"] == 0) for r in results)
fp = sum((r["true_label"] == 0 and r["pred"] == 1) for r in results)
fn = sum((r["true_label"] == 1 and r["pred"] == 0) for r in results)

real_acc = 100 * tn / max(1, n_real)
fake_acc = 100 * tp / max(1, n_fake)
precision_fake = tp / max(1, tp + fp)
recall_fake = tp / max(1, tp + fn)
f1_fake = 2 * precision_fake * recall_fake / max(1e-12, precision_fake + recall_fake)

# ── Print validation info ─────────────────────────────────────────────────────
print(f"Validation inference: {total} images\n")
print(f"Done: {n_correct}/{total} correct ({accuracy:.1f}% accuracy)")
print(f"Min prob: {min(probs):.4f}  Max: {max(probs):.4f}  Mean: {sum(probs)/len(probs):.4f}")
print(f"Well detected:  {len(well)}")
print(f"Badly detected: {len(badly)}")
print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")
print(f"Real accuracy: {real_acc:.1f}%")
print(f"Fake accuracy: {fake_acc:.1f}%")
print(f"Fake precision: {precision_fake:.4f}")
print(f"Fake recall:    {recall_fake:.4f}")
print(f"Fake F1:        {f1_fake:.4f}")

if "skipped" in globals() and len(skipped) > 0:
    print(f"\nSkipped images: {len(skipped)}")
    for s in skipped[:10]:
        print(f"  {os.path.basename(s['path'])}: {s['error']}")

# ── Helpers ───────────────────────────────────────────────────────────────────
def label_str(l):
    return "REAL" if int(l) == 0 else "FAKE"

def get_image_number(path):
    """
    Extracts image number from filename.
    Examples:
      /.../0005.png -> 0005
      /.../fake_0005_img.png -> 0005
    """
    fname = os.path.basename(path)
    stem = os.path.splitext(fname)[0]

    if stem.isdigit():
        return stem

    m = re.search(r"\d+", stem)
    return m.group(0) if m else "unknown"

def load_thumb(path, size=128):
    img = PILImage.open(path).convert("RGB")
    w, h = img.size
    side = min(w, h)
    img = img.crop((
        (w - side) // 2,
        (h - side) // 2,
        (w + side) // 2,
        (h + side) // 2
    ))
    return img.resize((size, size), PILImage.LANCZOS)

def make_grid(samples, title, filename, max_rows=10, cols=10):
    n = len(samples)
    if n == 0:
        print(f"No samples to plot for {filename}")
        return

    rows = min(max_rows, (n + cols - 1) // cols)
    show = min(n, rows * cols)

    fig, axes = plt.subplots(rows, cols, figsize=(22, rows * 2.9))
    fig.patch.set_facecolor("#1a1a1a")
    fig.suptitle(title, fontsize=15, color="white", y=0.995, fontweight="medium")

    # Make axes iterable for both 1-row and multi-row cases
    if rows == 1:
        flat_axes = axes.flatten() if hasattr(axes, "flatten") else [axes]
    else:
        flat_axes = axes.flatten()

    for idx, ax in enumerate(flat_axes):
        if idx >= show:
            ax.axis("off")
            continue

        r = samples[idx]

        try:
            ax.imshow(load_thumb(r["path"]))
        except Exception:
            ax.set_facecolor("#333")
            ax.text(
                0.5, 0.5, "error",
                ha="center", va="center",
                color="white", fontsize=7,
                transform=ax.transAxes
            )

        true_color = "#2ecc71" if int(r["true_label"]) == 0 else "#e74c3c"
        for spine in ax.spines.values():
            spine.set_edgecolor(true_color)
            spine.set_linewidth(3)

        ax.set_xticks([])
        ax.set_yticks([])

        img_num = get_image_number(r["path"])

        ax.set_title(
            f"Image #{img_num}\n"
            f"True: {label_str(r['true_label'])} → Pred: {label_str(r['pred'])}\n"
            f"conf: {r['confidence']:.3f}",
            fontsize=7,
            color="white",
            pad=4
        )

    for ax in flat_axes[show:]:
        ax.axis("off")

    real_p = mpatches.Patch(color="#2ecc71", label="True label: REAL")
    fake_p = mpatches.Patch(color="#e74c3c", label="True label: FAKE")
    fig.legend(
        handles=[real_p, fake_p],
        loc="lower center",
        ncol=2,
        fontsize=10,
        framealpha=0.3,
        facecolor="#333",
        labelcolor="white",
        bbox_to_anchor=(0.5, 0.01)
    )

    plt.subplots_adjust(hspace=0.75, wspace=0.08, top=0.92, bottom=0.06)
    plt.savefig(
        filename,
        dpi=80,
        bbox_inches="tight",
        facecolor=fig.get_facecolor()
    )
    plt.close(fig)
    display(Image(filename))

# ── Plots ─────────────────────────────────────────────────────────────────────
make_grid(
    well_sample,
    title=f"{len(well_sample)} most confidently CORRECT predictions (Validation)\n"
          "Border = true label",
    filename="well_detected_val.jpg"
)

make_grid(
    badly_sample,
    title=f"{len(badly_sample)} most confidently WRONG predictions (Validation)\n"
          "Border = true label",
    filename="badly_detected_val.jpg"
)
# Out:
# Validation inference: 100 images
#
# Done: 70/100 correct (70.0% accuracy)
# Min prob: 0.0261  Max: 0.9975  Mean: 0.4071
# Well detected:  70
# Badly detected: 30
# TP=26, TN=44, FP=6, FN=24
# Real accuracy: 88.0%
# Fake accuracy: 52.0%
# Fake precision: 0.8125
# Fake recall:    0.5200
# Fake F1:        0.6341

# %%
import nbformat
NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort 3440val Train.ipynb"

nb = nbformat.read(NOTEBOOK_PATH, as_version=4)

if "widgets" in nb.metadata:
    del nb.metadata["widgets"]

nbformat.write(nb, NOTEBOOK_PATH)

# %%
# !pip install nbconvert -q

NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort 3440val Train.ipynb"
OUTPUT_DIR    = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks"

# !jupyter nbconvert \
    --to html \
    --embed-images \
    --output-dir "{OUTPUT_DIR}" \
    "{NOTEBOOK_PATH}"

print("Done — check your Drive for the .html file")
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort 3440val Train.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 676945 bytes to /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks/Effort 3440val Train.html
# Done — check your Drive for the .html file
