# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install -q "numpy<2" --force-reinstall

# %%
import numpy, torch, torchvision
# print("numpy:", numpy.__version__)
# print("torch:", torch.__version__)
# print("torchvision:", torchvision.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# CUDA: True

# %%
import os, glob, json, random

TRAIN_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/training_data"
VAL_DIR   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/validation_data"
TEST_DIR  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/publictest_data"

VAL_REF   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/validation_reference/reference.txt"
TEST_REF  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/publictest_reference/reference.txt"

STAGING = "/content/DiffusionForensics_Recons"
os.makedirs(STAGING, exist_ok=True)

IMG_EXTS = (".png", ".jpg", ".jpeg", ".webp", ".bmp", ".tif", ".tiff")

# ═══════════════════════════════════════════════════
# TRAINING — training_data_final
# ═══════════════════════════════════════════════════
train_items = []
for ext in IMG_EXTS:
    for p in glob.glob(os.path.join(TRAIN_DIR, f"*{ext}")):
        name = os.path.basename(p).lower()
        if "_real" in name:
            train_items.append({"path": p, "label": 0})
        elif "_fake" in name:
            train_items.append({"path": p, "label": 1})

random.seed(42)
random.shuffle(train_items)

n_real = sum(1 for x in train_items if x["label"] == 0)
n_fake = sum(1 for x in train_items if x["label"] == 1)
print(f"TRAIN: {len(train_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# VALIDATION — validation_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(VAL_REF) as f:
    val_labels = [int(line.strip()) for line in f if line.strip()]

val_images = sorted(glob.glob(os.path.join(VAL_DIR, "*.*")))
val_images = [p for p in val_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(val_images) == len(val_labels), \
    f"Mismatch: {len(val_images)} images vs {len(val_labels)} labels"

val_items = [{"path": p, "label": l} for p, l in zip(val_images, val_labels)]

n_real = sum(1 for x in val_items if x["label"] == 0)
n_fake = sum(1 for x in val_items if x["label"] == 1)
print(f"VAL:   {len(val_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# TEST — publictest_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(TEST_REF) as f:
    test_labels = [int(line.strip()) for line in f if line.strip()]

test_images = sorted(glob.glob(os.path.join(TEST_DIR, "*.*")))
test_images = [p for p in test_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(test_images) == len(test_labels), \
    f"Mismatch: {len(test_images)} images vs {len(test_labels)} labels"

test_items = [{"path": p, "label": l} for p, l in zip(test_images, test_labels)]

n_real = sum(1 for x in test_items if x["label"] == 0)
n_fake = sum(1 for x in test_items if x["label"] == 1)
print(f"TEST:  {len(test_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# SAVE JSONs
# ═══════════════════════════════════════════════════
for name, data in [("train", train_items), ("val", val_items), ("test", test_items)]:
    out = os.path.join(STAGING, f"{name}.json")
    with open(out, "w") as f:
        json.dump(data, f)
    print(f"\n✓ {name}.json → {len(data)} items → {out}")
# Out:
# TRAIN: 1000 images  (real=500, fake=500)
# VAL:   100 images  (real=50, fake=50)
# TEST:  1000 images  (real=500, fake=500)
#
# ✓ train.json → 1000 items → /content/DiffusionForensics_Recons/train.json
#
# ✓ val.json → 100 items → /content/DiffusionForensics_Recons/val.json
#
# ✓ test.json → 1000 items → /content/DiffusionForensics_Recons/test.json

# %%
# %%capture
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench
# !pip install jedi
# !python -m pip install -U pip setuptools wheel
# !pip install -r requirements.txt
# !pip install -e .

# %%
# %%capture
# %cd "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub"
# !head -n -1 requirements.txt > requirements_no_flash.txt
# !pip install -r requirements_no_flash.txt

# %%
# import shutil
# from pathlib import Path

# CKPT_DIR = Path("/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train")

# if CKPT_DIR.exists():
#     shutil.rmtree(CKPT_DIR)
#     print("🧹 Old checkpoints deleted")

# CKPT_DIR.mkdir(parents=True, exist_ok=True)
# print("✅ Fresh checkpoint directory created:", CKPT_DIR)
# Out:
# 🧹 Old checkpoints deleted
# ✅ Fresh checkpoint directory created: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train

# %%
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub

# !PYTHONPATH=/content/drive/MyDrive/Capstone_Hripsime/Frameworks:$PWD \
# MASTER_ADDR=127.0.0.1 MASTER_PORT=29601 \
# python -m ForensicHub.training_scripts.train \
# --config "ForensicHub/statics/crossdataset_image/recce_train.yaml"
# Out:
# /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/timm/optim/optim_factory.py:7: FutureWarning: Importing from timm.optim.optim_factory is deprecated, please import via timm.optim
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.optim", FutureWarning)
# 2026-04-25 16:41:50.729466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777135310.754493    9644 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777135310.763769    9644 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777135310.784472    9644 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777135310.784513    9644 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777135310.784518    9644 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777135310.784534    9644 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-25 16:41:50.789344: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/IMDLBenCo/training_scripts/trainer/trainer.py:25: UserWarning: HOPE YOU TO READ: Starting from IMDLBenCo version v0.1.31, we have discovered a misdefinition regarding the --if_not_amp parameter in the argument parser. For more details, please refer to: https://github.com/scu-zjz/IMDLBenCo/issues/89. As a result, if you use the train.py script generated by an earlier version of 'benco init' before v0.1.30, along with the latest version of trainer.py, it may lead to AMP (Automatic Mixed Precision) being incorrectly enabled or disabled. We recommend updating to the latest version(after v0.1.31, include) of IMDLBenCo and re-initializing the project using 'benco init' to ensure that the --if_not_amp parameter is correctly defined.  Or for already initialized projects, please manually modify the action of the --if_not_amp parameter in train.py to 'store_true' to ensure correct logic.  We apologize for any inconvenience this may have caused.!!!!!!
#   warnings.warn(
# Not using distributed mode
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [16:41:54.491551] [patch] initialized torch.distributed process group (single-process, gloo)
# [16:41:54.493830] job dir: /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub/ForensicHub/training_scripts
# [16:41:54.493967] =====args:=====
# [16:41:54.494139] Namespace(gpus=0.0,
# flag='train',
# log_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train',
# if_predict_label=True,
# if_predict_mask=False,
# num_classes=2,
# batch_size=32,
# test_batch_size=16,
# epochs=10,
# accum_iter=1,
# record_epoch=0,
# no_model_eval=False,
# test_period=1,
# log_per_epoch_count=20,
# find_unused_parameters=False,
# use_amp=False,
# weight_decay=0.05,
# lr=0.0001,
# blr=0.001,
# min_lr=1e-05,
# warmup_epochs=1,
# device='cuda',
# seed=42,
# resume='',
# start_epoch=0,
# num_workers=2,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# output_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train',
# if_not_amp=True,
# distributed=False)
# [16:41:54.506036] [build_from_registry] Creating model 'AIGCTransform' with args: {'norm_type': 'image_net'}
# [16:41:54.506699] Train transform:  Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:41:54.507017] Test transform:  Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:41:54.507155] Post transform:  Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [16:41:54.507326] Post function check: recce_post_func
# [16:41:54.507416] None
# [16:41:54.507706] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 256, 'path': '/content/DiffusionForensics_Recons/train.json', 'post_funcs': None, 'common_transform': Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [16:41:54.509227] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 256, 'path': '/content/DiffusionForensics_Recons/val.json', 'post_funcs': None, 'common_transform': Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [16:41:54.509639] Train dataset: DiffusionForensics_train.
# [16:41:54.509743] 1000
# [16:41:54.509834] [AIGCLabelDataset] at /content/DiffusionForensics_Recons/train.json, with length of 1,000
# [16:41:54.509906] Test dataset: ['DiffusionForensics_val'].
# [16:41:54.509986] [100]
# [16:41:55.214777] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [16:41:55.214942] spatial_count=0 keep_stride_count=0
# [16:41:58.931520] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [16:41:58.932036] spatial_count=0 keep_stride_count=0
# [16:41:59.012522] [build_from_registry] Creating model 'Recce' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/recce.yaml'}
# [16:41:59.746188] [build_from_registry] Creating model 'ImageF1' with args: {'threshold': 0.5}
# [16:41:59.746431] [build_from_registry] Creating model 'ImageAUC' with args: {}
# [16:41:59.746544] Evaluators: [<IMDLBenCo.evaluation.F1.ImageF1 object at 0x7dab9813b4a0>, <IMDLBenCo.evaluation.AUC.ImageAUC object at 0x7dab8eb6f8f0>]
# [16:42:00.027887] Model = RecceDetector(
#   (model): Recce(
#     (encoder): Xception(
#       (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#       (block1): Block(
#         (skip): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (skipbn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (rep): Sequential(
#           (0): SeparableConv2d(
#             (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): SeparableConv2d(
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#             (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#       )
#       (block2): Block(
#         (skip): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (skipbn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#             (pointwise): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#             (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#       )
#       (block3): Block(
#         (skip): Conv2d(256, 728, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (skipbn): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#             (pointwise): Conv2d(256, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#       )
#       (block4): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block5): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block6): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block7): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block8): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block9): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block10): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block11): Block(
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (block12): Block(
#         (skip): Conv2d(728, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (skipbn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (rep): Sequential(
#           (0): ReLU()
#           (1): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU(inplace=True)
#           (4): SeparableConv2d(
#             (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#             (pointwise): Conv2d(728, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#       )
#       (conv3): SeparableConv2d(
#         (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#         (pointwise): Conv2d(1024, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn3): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (conv4): SeparableConv2d(
#         (conv1): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#         (pointwise): Conv2d(1536, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (bn4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act4): ReLU(inplace=True)
#       (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#       (fc): Linear(in_features=2048, out_features=1000, bias=True)
#     )
#     (global_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc): Linear(in_features=2048, out_features=2, bias=True)
#     (attention): GuidedAttention(
#       (gated): Sequential(
#         (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Sigmoid()
#       )
#       (h): Sequential(
#         (0): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (reasoning): GraphReasoning(
#       (va_embedding): Sequential(
#         (0): Conv2d(728, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (va_gated_b): Sequential(
#         (0): Conv2d(728, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Sigmoid()
#       )
#       (va_gated_c): Sequential(
#         (0): Conv2d(728, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): Sigmoid()
#       )
#       (vb_embedding): Sequential(
#         (0): Linear(in_features=256, out_features=256, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=256, out_features=256, bias=False)
#       )
#       (vc_embedding): Sequential(
#         (0): Linear(in_features=128, out_features=256, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=256, out_features=256, bias=False)
#       )
#       (unfold_b): Unfold(kernel_size=2, dilation=1, padding=0, stride=2)
#       (unfold_c): Unfold(kernel_size=4, dilation=1, padding=0, stride=4)
#       (reweight_ab): Sequential(
#         (0): Linear(in_features=512, out_features=1, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Softmax(dim=1)
#       )
#       (reweight_ac): Sequential(
#         (0): Linear(in_features=512, out_features=1, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Softmax(dim=1)
#       )
#       (reproject): Sequential(
#         (0): Conv2d(768, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): Dropout(p=0.2, inplace=False)
#       )
#     )
#     (decoder1): Sequential(
#       (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#       (1): SeparableConv2d(
#         (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#         (pointwise): Conv2d(728, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (decoder2): Block(
#       (relu): ReLU(inplace=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (decoder3): Sequential(
#       (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#       (1): SeparableConv2d(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#         (pointwise): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (decoder4): Block(
#       (relu): ReLU(inplace=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (decoder5): Sequential(
#       (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#       (1): SeparableConv2d(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (pointwise): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU(inplace=True)
#     )
#     (decoder6): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (loss_func): CrossEntropyLoss()
# )
# [16:42:00.110677] base lr: 8.00e-04
# [16:42:00.110775] actual lr: 1.00e-04
# [16:42:00.110856] accumulate grad iterations: 1
# [16:42:00.110934] effective batch size: 32
# [16:42:00.111023] master port: 29601
# [16:42:00.113345] AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.05
# )
# [16:42:00.113656] Start training for 10 epochs
# [16:42:00.115646] Auto Mixed Precision (AMP) is disabled.
# [16:42:00.116206] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [16:42:14.346944] Epoch: [0]  [ 0/31]  eta: 0:07:21  lr: 0.000000  combined_loss: [local: 0.6763 | reduced: 0.6763]  time: 14.2295  data: 1.3639  max mem: 8940
# [16:45:54.025675] Epoch: [0]  [20/31]  eta: 0:02:02  lr: 0.000065  combined_loss: [local: 0.6936 | reduced: 0.6930]  time: 10.9838  data: 0.0003  max mem: 9131
# [16:47:42.792044] Epoch: [0]  [30/31]  eta: 0:00:11  lr: 0.000097  combined_loss: [local: 0.6932 | reduced: 0.6923]  time: 10.9280  data: 0.0003  max mem: 9131
# [16:47:42.845675] Epoch: [0] Total time: 0:05:42 (11.0558 s / it)
# [16:47:43.741518] Averaged stats: lr: 0.000097  combined_loss: [local: 0.6932 | reduced: 0.6923]
# [16:47:45.465375] !!!Start Test: DiffusionForensics_val 6
# [16:47:46.168670] Test: [0]  [0/6]  eta: 0:00:04    time: 0.6978  data: 0.3345  max mem: 9131
# [16:47:47.346919] Test: [0]  [5/6]  eta: 0:00:00    time: 0.3124  data: 0.0559  max mem: 9131
# [16:47:47.402664] Test: [0] Total time: 0:00:01 (0.3223 s / it)
# [16:47:47.419137] ---syncronized---
# [16:47:47.419308] image-level F1 reduced_count 1
# [16:47:47.419439] image-level F1 reduced_sum 0.3661971688270569
# [16:47:47.419566] image-level AUC reduced_count 1
# [16:47:47.419729] image-level AUC reduced_sum 0.5392965696917065
# [16:47:47.419872] ---syncronized done ---
# [16:47:47.784056] Averaged stats: image-level F1: [local: 0.3662 | reduced: 0.3662]  image-level AUC: [local: 0.5393 | reduced: 0.5393]
# [16:47:47.903911] Best image-level F1 image-level AUC = 0.4527468692593817
# [16:47:49.922780] Auto Mixed Precision (AMP) is disabled.
# [16:47:49.923222] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [16:48:03.387498] Epoch: [1]  [ 0/31]  eta: 0:06:57  lr: 0.000100  combined_loss: [local: 0.6858 | reduced: 0.6858]  time: 13.4626  data: 0.8511  max mem: 9131
# [16:51:46.909570] Epoch: [1]  [20/31]  eta: 0:02:04  lr: 0.000099  combined_loss: [local: 0.6783 | reduced: 0.6762]  time: 11.1760  data: 0.0003  max mem: 9131
# [16:53:35.779895] Epoch: [1]  [30/31]  eta: 0:00:11  lr: 0.000097  combined_loss: [local: 0.6679 | reduced: 0.6730]  time: 10.9444  data: 0.0003  max mem: 9131
# [16:53:35.840844] Epoch: [1] Total time: 0:05:45 (11.1586 s / it)
# [16:53:36.668654] Averaged stats: lr: 0.000097  combined_loss: [local: 0.6679 | reduced: 0.6730]
# [16:53:37.327675] !!!Start Test: DiffusionForensics_val 6
# [16:53:38.527346] Test: [1]  [0/6]  eta: 0:00:07    time: 1.1946  data: 0.9218  max mem: 9131
# [16:53:40.803997] Test: [1]  [5/6]  eta: 0:00:00    time: 0.5783  data: 0.3671  max mem: 9131
# [16:53:40.862528] Test: [1] Total time: 0:00:03 (0.5887 s / it)
# [16:53:40.869418] ---syncronized---
# [16:53:40.869572] image-level F1 reduced_count 1
# [16:53:40.869732] image-level F1 reduced_sum 0.1428571492433548
# [16:53:40.869847] image-level AUC reduced_count 1
# [16:53:40.869963] image-level AUC reduced_sum 0.4861111111111111
# [16:53:40.870087] ---syncronized done ---
# [16:53:41.273272] Averaged stats: image-level F1: [local: 0.1429 | reduced: 0.1429]  image-level AUC: [local: 0.4861 | reduced: 0.4861]
# [16:53:41.383451] Average image-level F1 image-level AUC = 0.314484130177233
# [16:53:41.859153] Auto Mixed Precision (AMP) is disabled.
# [16:53:41.859747] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [16:53:54.706856] Epoch: [2]  [ 0/31]  eta: 0:06:38  lr: 0.000097  combined_loss: [local: 0.5632 | reduced: 0.5632]  time: 12.8458  data: 0.9068  max mem: 9131
# [16:57:35.985301] Epoch: [2]  [20/31]  eta: 0:02:02  lr: 0.000093  combined_loss: [local: 0.6149 | reduced: 0.6094]  time: 11.0639  data: 0.0003  max mem: 9131
# [16:59:28.025738] Epoch: [2]  [30/31]  eta: 0:00:11  lr: 0.000090  combined_loss: [local: 0.6290 | reduced: 0.6198]  time: 11.1442  data: 0.0004  max mem: 9131
# [16:59:28.106677] Epoch: [2] Total time: 0:05:46 (11.1692 s / it)
# [16:59:29.015626] Averaged stats: lr: 0.000090  combined_loss: [local: 0.6290 | reduced: 0.6198]
# [16:59:29.608241] !!!Start Test: DiffusionForensics_val 6
# [16:59:30.369911] Test: [2]  [0/6]  eta: 0:00:04    time: 0.7562  data: 0.3118  max mem: 9131
# [16:59:31.438507] Test: [2]  [5/6]  eta: 0:00:00    time: 0.3039  data: 0.0522  max mem: 9131
# [16:59:31.499449] Test: [2] Total time: 0:00:01 (0.3147 s / it)
# [16:59:31.507158] ---syncronized---
# [16:59:31.507304] image-level F1 reduced_count 1
# [16:59:31.507430] image-level F1 reduced_sum 0.040816325694322586
# [16:59:31.507540] image-level AUC reduced_count 1
# [16:59:31.507715] image-level AUC reduced_sum 0.4107685627442466
# [16:59:31.507840] ---syncronized done ---
# [16:59:31.921412] Averaged stats: image-level F1: [local: 0.0408 | reduced: 0.0408]  image-level AUC: [local: 0.4108 | reduced: 0.4108]
# [16:59:32.070764] Average image-level F1 image-level AUC = 0.2257924442192846
# [16:59:32.303486] Auto Mixed Precision (AMP) is disabled.
# [16:59:32.305069] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [16:59:44.648351] Epoch: [3]  [ 0/31]  eta: 0:06:22  lr: 0.000089  combined_loss: [local: 0.6039 | reduced: 0.6039]  time: 12.3418  data: 0.5780  max mem: 9131
# [17:03:36.843945] Epoch: [3]  [20/31]  eta: 0:02:08  lr: 0.000082  combined_loss: [local: 0.5523 | reduced: 0.5495]  time: 11.6097  data: 0.0004  max mem: 9131
# [17:05:28.833047] Epoch: [3]  [30/31]  eta: 0:00:11  lr: 0.000078  combined_loss: [local: 0.5417 | reduced: 0.5503]  time: 11.3540  data: 0.0004  max mem: 9131
# [17:05:28.899927] Epoch: [3] Total time: 0:05:56 (11.5031 s / it)
# [17:05:29.757096] Averaged stats: lr: 0.000078  combined_loss: [local: 0.5417 | reduced: 0.5503]
# [17:05:30.302368] !!!Start Test: DiffusionForensics_val 6
# [17:05:30.957949] Test: [3]  [0/6]  eta: 0:00:03    time: 0.6469  data: 0.3130  max mem: 9131
# [17:05:32.020894] Test: [3]  [5/6]  eta: 0:00:00    time: 0.2847  data: 0.0524  max mem: 9131
# [17:05:32.079733] Test: [3] Total time: 0:00:01 (0.2951 s / it)
# [17:05:32.086781] ---syncronized---
# [17:05:32.086907] image-level F1 reduced_count 1
# [17:05:32.087027] image-level F1 reduced_sum 0.1818181723356247
# [17:05:32.087148] image-level AUC reduced_count 1
# [17:05:32.087259] image-level AUC reduced_sum 0.47048611111111116
# [17:05:32.087373] ---syncronized done ---
# [17:05:32.527534] Averaged stats: image-level F1: [local: 0.1818 | reduced: 0.1818]  image-level AUC: [local: 0.4705 | reduced: 0.4705]
# [17:05:32.528596] Average image-level F1 image-level AUC = 0.3261521417233679
# [17:05:33.288459] Auto Mixed Precision (AMP) is disabled.
# [17:05:33.289017] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:05:46.254999] Epoch: [4]  [ 0/31]  eta: 0:06:41  lr: 0.000077  combined_loss: [local: 0.4892 | reduced: 0.4892]  time: 12.9644  data: 0.8603  max mem: 9131
# [17:09:25.715836] Epoch: [4]  [20/31]  eta: 0:02:01  lr: 0.000068  combined_loss: [local: 0.4721 | reduced: 0.4897]  time: 10.9730  data: 0.0004  max mem: 9131
# [17:11:14.303808] Epoch: [4]  [30/31]  eta: 0:00:11  lr: 0.000063  combined_loss: [local: 0.4807 | reduced: 0.5003]  time: 10.8856  data: 0.0003  max mem: 9131
# [17:11:14.370137] Epoch: [4] Total time: 0:05:41 (11.0026 s / it)
# [17:11:15.278876] Averaged stats: lr: 0.000063  combined_loss: [local: 0.4807 | reduced: 0.5003]
# [17:11:15.793251] !!!Start Test: DiffusionForensics_val 6
# [17:11:16.460374] Test: [4]  [0/6]  eta: 0:00:03    time: 0.6580  data: 0.2959  max mem: 9131
# [17:11:17.495352] Test: [4]  [5/6]  eta: 0:00:00    time: 0.2820  data: 0.0495  max mem: 9131
# [17:11:17.556340] Test: [4] Total time: 0:00:01 (0.2928 s / it)
# [17:11:17.563927] ---syncronized---
# [17:11:17.564071] image-level F1 reduced_count 1
# [17:11:17.564190] image-level F1 reduced_sum 0.111111119389534
# [17:11:17.564299] image-level AUC reduced_count 1
# [17:11:17.564410] image-level AUC reduced_sum 0.5015197568389058
# [17:11:17.564534] ---syncronized done ---
# [17:11:17.941412] Averaged stats: image-level F1: [local: 0.1111 | reduced: 0.1111]  image-level AUC: [local: 0.5015 | reduced: 0.5015]
# [17:11:18.095607] Average image-level F1 image-level AUC = 0.3063154381142199
# [17:11:18.336414] Auto Mixed Precision (AMP) is disabled.
# [17:11:18.336914] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:11:30.317574] Epoch: [5]  [ 0/31]  eta: 0:06:11  lr: 0.000063  combined_loss: [local: 0.4936 | reduced: 0.4936]  time: 11.9794  data: 0.6654  max mem: 9131
# [17:15:09.721643] Epoch: [5]  [20/31]  eta: 0:02:01  lr: 0.000053  combined_loss: [local: 0.4476 | reduced: 0.4545]  time: 10.9701  data: 0.0002  max mem: 9131
# [17:16:58.980379] Epoch: [5]  [30/31]  eta: 0:00:10  lr: 0.000048  combined_loss: [local: 0.4210 | reduced: 0.4495]  time: 10.9390  data: 0.0002  max mem: 9131
# [17:16:59.046015] Epoch: [5] Total time: 0:05:40 (10.9906 s / it)
# [17:16:59.860564] Averaged stats: lr: 0.000048  combined_loss: [local: 0.4210 | reduced: 0.4495]
# [17:17:00.550522] !!!Start Test: DiffusionForensics_val 6
# [17:17:01.373418] Test: [5]  [0/6]  eta: 0:00:04    time: 0.8147  data: 0.3031  max mem: 9131
# [17:17:02.666547] Test: [5]  [5/6]  eta: 0:00:00    time: 0.3508  data: 0.0507  max mem: 9131
# [17:17:02.759081] Test: [5] Total time: 0:00:02 (0.3675 s / it)
# [17:17:02.767414] ---syncronized---
# [17:17:02.767613] image-level F1 reduced_count 1
# [17:17:02.767805] image-level F1 reduced_sum 0.11538461595773697
# [17:17:02.767961] image-level AUC reduced_count 1
# [17:17:02.768102] image-level AUC reduced_sum 0.4661458333333333
# [17:17:02.768243] ---syncronized done ---
# [17:17:03.232886] Averaged stats: image-level F1: [local: 0.1154 | reduced: 0.1154]  image-level AUC: [local: 0.4661 | reduced: 0.4661]
# [17:17:03.240992] Average image-level F1 image-level AUC = 0.2907652246455351
# [17:17:03.991736] Auto Mixed Precision (AMP) is disabled.
# [17:17:03.992337] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:17:16.911379] Epoch: [6]  [ 0/31]  eta: 0:06:40  lr: 0.000047  combined_loss: [local: 0.3832 | reduced: 0.3832]  time: 12.9176  data: 0.6812  max mem: 9131
# [17:20:57.093627] Epoch: [6]  [20/31]  eta: 0:02:02  lr: 0.000037  combined_loss: [local: 0.4107 | reduced: 0.4129]  time: 11.0090  data: 0.0003  max mem: 9131
# [17:22:45.203638] Epoch: [6]  [30/31]  eta: 0:00:11  lr: 0.000033  combined_loss: [local: 0.3820 | reduced: 0.4107]  time: 10.8917  data: 0.0003  max mem: 9131
# [17:22:45.269827] Epoch: [6] Total time: 0:05:41 (11.0089 s / it)
# [17:22:46.050730] Averaged stats: lr: 0.000033  combined_loss: [local: 0.3820 | reduced: 0.4107]
# [17:22:46.702298] !!!Start Test: DiffusionForensics_val 6
# [17:22:47.384729] Test: [6]  [0/6]  eta: 0:00:04    time: 0.6773  data: 0.2879  max mem: 9131
# [17:22:48.457751] Test: [6]  [5/6]  eta: 0:00:00    time: 0.2915  data: 0.0482  max mem: 9131
# [17:22:48.521267] Test: [6] Total time: 0:00:01 (0.3027 s / it)
# [17:22:48.528906] ---syncronized---
# [17:22:48.529051] image-level F1 reduced_count 1
# [17:22:48.529176] image-level F1 reduced_sum 0.0784313753247261
# [17:22:48.529298] image-level AUC reduced_count 1
# [17:22:48.529412] image-level AUC reduced_sum 0.46701388888888884
# [17:22:48.529537] ---syncronized done ---
# [17:22:48.868144] Averaged stats: image-level F1: [local: 0.0784 | reduced: 0.0784]  image-level AUC: [local: 0.4670 | reduced: 0.4670]
# [17:22:49.011724] Average image-level F1 image-level AUC = 0.27272263210680747
# [17:22:49.318098] Auto Mixed Precision (AMP) is disabled.
# [17:22:49.318695] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:23:01.384295] Epoch: [7]  [ 0/31]  eta: 0:06:13  lr: 0.000033  combined_loss: [local: 0.4053 | reduced: 0.4053]  time: 12.0639  data: 0.5801  max mem: 9131
# [17:26:40.940701] Epoch: [7]  [20/31]  eta: 0:02:01  lr: 0.000024  combined_loss: [local: 0.3412 | reduced: 0.3837]  time: 10.9778  data: 0.0004  max mem: 9131
# [17:28:29.364036] Epoch: [7]  [30/31]  eta: 0:00:10  lr: 0.000021  combined_loss: [local: 0.3412 | reduced: 0.3759]  time: 10.9358  data: 0.0004  max mem: 9131
# [17:28:29.480760] Epoch: [7] Total time: 0:05:40 (10.9730 s / it)
# [17:28:30.452170] Averaged stats: lr: 0.000021  combined_loss: [local: 0.3412 | reduced: 0.3759]
# [17:28:30.621546] !!!Start Test: DiffusionForensics_val 6
# [17:28:32.734350] Test: [7]  [0/6]  eta: 0:00:12    time: 2.0805  data: 0.7945  max mem: 9131
# [17:28:33.965131] Test: [7]  [5/6]  eta: 0:00:00    time: 0.5507  data: 0.1326  max mem: 9131
# [17:28:34.024481] Test: [7] Total time: 0:00:03 (0.5653 s / it)
# [17:28:34.031620] ---syncronized---
# [17:28:34.031750] image-level F1 reduced_count 1
# [17:28:34.031867] image-level F1 reduced_sum 0.111111119389534
# [17:28:34.031982] image-level AUC reduced_count 1
# [17:28:34.032092] image-level AUC reduced_sum 0.500651324359531
# [17:28:34.032204] ---syncronized done ---
# [17:28:34.401116] Averaged stats: image-level F1: [local: 0.1111 | reduced: 0.1111]  image-level AUC: [local: 0.5007 | reduced: 0.5007]
# [17:28:34.549737] Average image-level F1 image-level AUC = 0.3058812218745325
# [17:28:34.743213] Auto Mixed Precision (AMP) is disabled.
# [17:28:34.743661] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:28:47.088970] Epoch: [8]  [ 0/31]  eta: 0:06:22  lr: 0.000021  combined_loss: [local: 0.4229 | reduced: 0.4229]  time: 12.3433  data: 0.5529  max mem: 9131
# [17:32:27.910437] Epoch: [8]  [20/31]  eta: 0:02:02  lr: 0.000015  combined_loss: [local: 0.3309 | reduced: 0.3501]  time: 11.0410  data: 0.0003  max mem: 9131
# [17:34:16.757422] Epoch: [8]  [30/31]  eta: 0:00:11  lr: 0.000013  combined_loss: [local: 0.3431 | reduced: 0.3457]  time: 10.9781  data: 0.0003  max mem: 9131
# [17:34:16.822495] Epoch: [8] Total time: 0:05:42 (11.0348 s / it)
# [17:34:17.628172] Averaged stats: lr: 0.000013  combined_loss: [local: 0.3431 | reduced: 0.3457]
# [17:34:18.205713] !!!Start Test: DiffusionForensics_val 6
# [17:34:18.869909] Test: [8]  [0/6]  eta: 0:00:03    time: 0.6583  data: 0.3273  max mem: 9131
# [17:34:20.029678] Test: [8]  [5/6]  eta: 0:00:00    time: 0.3028  data: 0.0547  max mem: 9131
# [17:34:20.134169] Test: [8] Total time: 0:00:01 (0.3207 s / it)
# [17:34:20.142030] ---syncronized---
# [17:34:20.142184] image-level F1 reduced_count 1
# [17:34:20.142368] image-level F1 reduced_sum 0.11764706671237946
# [17:34:20.142530] image-level AUC reduced_count 1
# [17:34:20.142724] image-level AUC reduced_sum 0.5158488927485887
# [17:34:20.142870] ---syncronized done ---
# [17:34:20.659880] Averaged stats: image-level F1: [local: 0.1176 | reduced: 0.1176]  image-level AUC: [local: 0.5158 | reduced: 0.5158]
# [17:34:20.672541] Average image-level F1 image-level AUC = 0.3167479797304841
# [17:34:21.436088] Auto Mixed Precision (AMP) is disabled.
# [17:34:21.437346] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train
# [17:34:34.396924] Epoch: [9]  [ 0/31]  eta: 0:06:41  lr: 0.000013  combined_loss: [local: 0.3170 | reduced: 0.3170]  time: 12.9582  data: 0.8283  max mem: 9131
# [17:38:14.617745] Epoch: [9]  [20/31]  eta: 0:02:02  lr: 0.000010  combined_loss: [local: 0.3147 | reduced: 0.3089]  time: 11.0110  data: 0.0004  max mem: 9131
# [17:40:02.945166] Epoch: [9]  [30/31]  eta: 0:00:11  lr: 0.000010  combined_loss: [local: 0.2923 | reduced: 0.2998]  time: 10.8997  data: 0.0002  max mem: 9131
# [17:40:03.028429] Epoch: [9] Total time: 0:05:41 (11.0191 s / it)
# [17:40:03.870920] Averaged stats: lr: 0.000010  combined_loss: [local: 0.2923 | reduced: 0.2998]
# [17:40:05.307962] !!!Start Test: DiffusionForensics_val 6
# [17:40:05.989786] Test: [9]  [0/6]  eta: 0:00:04    time: 0.6743  data: 0.3232  max mem: 9131
# [17:40:07.124136] Test: [9]  [5/6]  eta: 0:00:00    time: 0.3012  data: 0.0543  max mem: 9131
# [17:40:07.195752] Test: [9] Total time: 0:00:01 (0.3139 s / it)
# [17:40:07.205150] ---syncronized---
# [17:40:07.205288] image-level F1 reduced_count 1
# [17:40:07.205419] image-level F1 reduced_sum 0.15094338357448578
# [17:40:07.205549] image-level AUC reduced_count 1
# [17:40:07.205707] image-level AUC reduced_sum 0.5054277029960921
# [17:40:07.205830] ---syncronized done ---
# [17:40:07.592156] Averaged stats: image-level F1: [local: 0.1509 | reduced: 0.1509]  image-level AUC: [local: 0.5054 | reduced: 0.5054]
# [17:40:07.730755] Average image-level F1 image-level AUC = 0.3281855432852889
# [17:40:07.915524] Training time 0:58:07

# %%
# %matplotlib inline
import os, json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from IPython.display import Image, display

LOG_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train/log.txt"


def parse_forensichub_recce_json_log(path):
    all_entries = []

    with open(path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            try:
                entry = json.loads(line)
            except json.JSONDecodeError:
                continue

            if "epoch" in entry:
                all_entries.append(entry)

    if not all_entries:
        raise RuntimeError(f"No JSON epoch entries found in {path}")

    # Use only the last run if the log contains restarted runs
    runs = []
    current_run = []
    prev_epoch = -1

    for entry in all_entries:
        ep = int(entry.get("epoch", 0))

        if ep <= prev_epoch and current_run:
            runs.append(current_run)
            current_run = []

        current_run.append(entry)
        prev_epoch = ep

    if current_run:
        runs.append(current_run)

    entries = runs[-1]

    # Match SPSL style: display epochs as 1-based
    epochs = [int(e["epoch"]) + 1 for e in entries]

    train_losses = [
        float(e.get("train_combined_loss", e.get("train_overall", np.nan)))
        for e in entries
    ]

    lrs = [
        float(e.get("train_lr", np.nan))
        for e in entries
    ]

    test_aucs = [
        float(e.get("test_image-level AUC", np.nan))
        for e in entries
    ]

    test_f1s = [
        float(e.get("test_image-level F1", np.nan))
        for e in entries
    ]

    train_aucs = [
        float(e.get("traineval_image-level AUC", np.nan))
        for e in entries
    ]

    train_f1s = [
        float(e.get("traineval_image-level F1", np.nan))
        for e in entries
    ]

    return epochs, train_losses, lrs, test_aucs, test_f1s, train_aucs, train_f1s, len(runs)


def plot_training(path):
    epochs, losses, lrs, aucs, f1s, train_aucs, train_f1s, n_runs = parse_forensichub_recce_json_log(path)

    aucs_np = np.array(aucs, dtype=float)
    f1s_np = np.array(f1s, dtype=float)

    best_auc_idx = int(np.nanargmax(aucs_np))

    best_auc_epoch = epochs[best_auc_idx]
    best_auc = aucs[best_auc_idx]
    f1_at_best_auc = f1s[best_auc_idx]

    print(f"Best AUC: {best_auc:.4f} at epoch {best_auc_epoch}")
    print(f"F1 at best AUC epoch: {f1_at_best_auc:.4f} at epoch {best_auc_epoch}")

    fig, axes = plt.subplots(1, 4, figsize=(22, 4.8))
    fig.patch.set_facecolor("#FAFAFA")

    for ax in axes:
        ax.set_facecolor("#F4F4F4")
        ax.spines[["top", "right"]].set_visible(False)
        ax.spines[["left", "bottom"]].set_color("#CCCCCC")
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # 1. Training loss
    ax = axes[0]
    ax.plot(
        epochs,
        losses,
        marker="o",
        linewidth=2,
        markersize=5,
        label="Combined loss",
    )
    ax.axhline(
        0.693,
        linestyle="--",
        linewidth=1,
        alpha=0.7,
        label="Random baseline (0.693)",
    )
    ax.set_title("Training loss", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9, framealpha=0.5)

    # 2. Validation AUC
    ax = axes[1]
    ax.plot(
        epochs,
        aucs,
        marker="D",
        linewidth=2,
        markersize=5,
        label="Val AUC",
    )
    ax.fill_between(epochs, 0.5, aucs, alpha=0.15)

    if not np.all(np.isnan(train_aucs)):
        ax.plot(
            epochs,
            train_aucs,
            marker="o",
            linewidth=1.8,
            markersize=4,
            alpha=0.8,
            label="Train AUC",
        )

    ax.scatter(best_auc_epoch, best_auc, s=90, zorder=5, label="Best AUC")
    ax.annotate(
        f"Best AUC: {best_auc:.4f}",
        xy=(best_auc_epoch, best_auc),
        xytext=(best_auc_epoch - max(epochs) * 0.12, best_auc + 0.08),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0.4, 1.05)
    ax.set_title("Validation AUC", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=9, framealpha=0.5)

    # 3. Validation F1 at best-AUC epoch
    ax = axes[2]
    ax.plot(
        epochs,
        f1s,
        marker="s",
        linewidth=2,
        markersize=5,
        label="Val F1",
    )

    if not np.all(np.isnan(train_f1s)):
        ax.plot(
            epochs,
            train_f1s,
            marker="o",
            linewidth=1.8,
            markersize=4,
            alpha=0.8,
            label="Train F1",
        )

    ax.scatter(
        best_auc_epoch,
        f1_at_best_auc,
        s=90,
        zorder=5,
        label="F1 at best-AUC epoch",
    )
    ax.annotate(
        f"F1 @ best AUC: {f1_at_best_auc:.4f}",
        xy=(best_auc_epoch, f1_at_best_auc),
        xytext=(best_auc_epoch + max(epochs) * 0.12, f1_at_best_auc + 0.10),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0, 1.05)
    ax.set_title("Validation F1", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("F1")
    ax.legend(fontsize=9, framealpha=0.5)

    # 4. Learning rate
    ax = axes[3]
    ax.plot(
        epochs,
        lrs,
        marker="o",
        linewidth=2,
        markersize=5,
        label="Learning rate",
    )
    ax.set_title("Learning rate schedule", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("LR")
    ax.ticklabel_format(style="sci", axis="y", scilimits=(0, 0))
    ax.legend(fontsize=9, framealpha=0.5)

    plt.suptitle(
        f"ForensicHub · Recce on DiffusionForensics ({len(epochs)} epochs)",
        fontsize=14,
        y=1.03,
    )
    plt.tight_layout()

    out_path = "forensichub_recce_training_curves.jpg"
    plt.savefig(out_path, dpi=100, bbox_inches="tight", facecolor=fig.get_facecolor())
    plt.close(fig)

    display(Image(out_path))


plot_training(LOG_PATH)
# Out:
# Best AUC: 0.5393 at epoch 1
# F1 at best AUC epoch: 0.3662 at epoch 1

# %%
# import sys, os

# base = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"
# print("DeepfakeBench exists:", os.path.exists(os.path.join(base, "DeepfakeBench")))
# print("ForensicHub exists:", os.path.exists(os.path.join(base, "ForensicHub")))

# sys.path.insert(0, base)
# sys.path.insert(0, os.path.join(base, "ForensicHub"))

# import DeepfakeBench
# print("DeepfakeBench import OK:", DeepfakeBench.__file__)

# %%
# RECCE Validation inference

import os
import json
import glob
import torch
from PIL import Image
from torchvision import transforms
import sys

BASE = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"

sys.path.insert(0, BASE)
sys.path.insert(0, os.path.join(BASE, "ForensicHub"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench", "DeepfakeBench"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench", "DeepfakeBench", "training"))

# ── Auto-locate and import RECCE detector ─────────────────────────────────────
recce_files = glob.glob(
    os.path.join(BASE, "**", "recce_detector.py"),
    recursive=True
)

if not recce_files:
    raise RuntimeError(f"Could not find recce_detector.py anywhere under:\n{BASE}")

RECCE_FILE = recce_files[0]

DETECTORS_DIR = os.path.dirname(RECCE_FILE)
DETECTORS_PARENT = os.path.dirname(DETECTORS_DIR)

if DETECTORS_PARENT not in sys.path:
    sys.path.insert(0, DETECTORS_PARENT)

from detectors.recce_detector import RecceDetector
from detectors import DETECTOR

if "recce" not in DETECTOR.data:
    raise RuntimeError("RECCE detector was not registered correctly.")

# ── Paths / constants ─────────────────────────────────────────────────────────
CHECKPOINT_DIR = f"{BASE}/ForensicHub/log/crossdataset_image_new/crossdataset_recce_train"
VAL_JSON = "/content/DiffusionForensics_Recons/val.json"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
THRESHOLD = 0.5

# ── Step 1: find best checkpoint metadata automatically from log.txt by AUC ───
LOG_PATH = os.path.join(CHECKPOINT_DIR, "log.txt")

all_entries = []

with open(LOG_PATH) as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        try:
            entry = json.loads(line)
        except json.JSONDecodeError:
            continue

        if "epoch" in entry:
            all_entries.append(entry)

if not all_entries:
    raise RuntimeError(f"No valid JSON epoch entries found in {LOG_PATH}")

# If log contains restarted runs, use only the last run
runs = []
current_run = []
prev_epoch = -1

for entry in all_entries:
    ep = int(entry.get("epoch", 0))

    if ep <= prev_epoch and current_run:
        runs.append(current_run)
        current_run = []

    current_run.append(entry)
    prev_epoch = ep

if current_run:
    runs.append(current_run)

if not runs:
    raise RuntimeError(f"No valid log runs found in {LOG_PATH}")

last_run = runs[-1]

valid_auc_entries = [
    e for e in last_run
    if e.get("test_image-level AUC") is not None
]

if not valid_auc_entries:
    raise RuntimeError(f"No validation AUC entries found in last run of {LOG_PATH}")

best_entry = max(
    valid_auc_entries,
    key=lambda e: float(e["test_image-level AUC"])
)

best_epoch = int(best_entry["epoch"])
best_auc = float(best_entry["test_image-level AUC"])
best_f1 = float(best_entry.get("test_image-level F1", float("nan")))

# Optional train-eval values, if they exist in the log
best_train_auc = float(best_entry.get("traineval_image-level AUC", float("nan")))
best_train_f1 = float(best_entry.get("traineval_image-level F1", float("nan")))

print(f"Best epoch from log by AUC: {best_epoch}")
print(f"Best val AUC from log: {best_auc:.6f}")
print(f"Val F1 at best-AUC epoch from log: {best_f1:.6f}")

if not np.isnan(best_train_auc):
    print(f"Train AUC at best-AUC epoch from log: {best_train_auc:.6f}")

if not np.isnan(best_train_f1):
    print(f"Train F1 at best-AUC epoch from log: {best_train_f1:.6f}")

# ── Step 2: select checkpoint file ────────────────────────────────────────────
# We use log.txt to choose the best epoch/metrics.
# For weights, PyTorch still needs an actual .pth file.

epoch_ckpt = os.path.join(CHECKPOINT_DIR, f"checkpoint-{best_epoch}.pth")
ckpt_best = os.path.join(CHECKPOINT_DIR, "ckpt_best.pth")

if os.path.exists(epoch_ckpt):
    best_ckpt = epoch_ckpt
    checkpoint_source = f"exact epoch checkpoint: checkpoint-{best_epoch}.pth"

elif os.path.exists(ckpt_best):
    best_ckpt = ckpt_best
    checkpoint_source = "ckpt_best.pth"

else:
    available_pths = sorted([
        f for f in os.listdir(CHECKPOINT_DIR)
        if f.endswith(".pth")
    ])

    if not available_pths:
        raise FileNotFoundError(
            f"No .pth checkpoint files found in:\n{CHECKPOINT_DIR}\n\n"
            "log.txt contains only metrics. Inference still needs a saved .pth model checkpoint."
        )

    checkpoint_files = [
        f for f in available_pths
        if f.startswith("checkpoint-") and f.endswith(".pth")
    ]

    if checkpoint_files:
        checkpoint_files = sorted(
            checkpoint_files,
            key=lambda f: int(f.replace("checkpoint-", "").replace(".pth", ""))
        )

        candidates = [
            f for f in checkpoint_files
            if int(f.replace("checkpoint-", "").replace(".pth", "")) <= best_epoch
        ]

        selected = candidates[-1] if candidates else checkpoint_files[-1]
        best_ckpt = os.path.join(CHECKPOINT_DIR, selected)
        checkpoint_source = f"nearest available checkpoint: {selected}"

    else:
        selected = available_pths[0]
        best_ckpt = os.path.join(CHECKPOINT_DIR, selected)
        checkpoint_source = f"fallback .pth file: {selected}"

print("Using checkpoint:")
print(best_ckpt)
print(f"Checkpoint source: {checkpoint_source}")

print("Checkpoint metadata from log.txt:")
print(f"  best_epoch: {best_epoch}")
print(f"  best_val_auc: {best_auc:.6f}")
print(f"  val_f1_at_best_auc_epoch: {best_f1:.6f}")

# ── Step 3: build exact RECCE model from DeepfakeBench detector registry ──────
recce_config = {
    "backbone_name": "xception",
    "backbone_config": {
        "mode": "original",
        "num_classes": 2,
        "inc": 3,
        "dropout": False,
    },
    "loss_func": "cross_entropy",
}

model = DETECTOR["recce"](recce_config)

checkpoint = torch.load(best_ckpt, map_location=DEVICE, weights_only=False)
state_dict = checkpoint["model"] if "model" in checkpoint else checkpoint

new_state_dict = {}

for k, v in state_dict.items():
    new_k = k

    for prefix in [
        "module.",
        "detector.",
    ]:
        if new_k.startswith(prefix):
            new_k = new_k[len(prefix):]

    new_state_dict[new_k] = v

missing, unexpected = model.load_state_dict(new_state_dict, strict=False)

print(f"Missing keys: {len(missing)}")
print(f"Unexpected keys: {len(unexpected)}")

if len(missing) > 0:
    print("First missing keys:", missing[:10])

if len(unexpected) > 0:
    print("First unexpected keys:", unexpected[:10])

model.to(DEVICE)
model.eval()

# ── Step 4: validation transform ──────────────────────────────────────────────
# RECCE / Xception-style preprocessing:
# image_size: usually 256
# norm_type: ImageNet

IMAGE_SIZE = 256

val_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
])

# ── Step 5: load validation items and run inference ───────────────────────────
with open(VAL_JSON) as f:
    val_items = json.load(f)

results = []
skipped = []

with torch.no_grad():
    for item in val_items:
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
            }

            out_dict = model(input_dict)

            prob = float(out_dict["prob"].view(-1)[0].item())
            pred = 1 if prob >= THRESHOLD else 0

            results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": prob,
                "correct": bool(pred == label),
                "checkpoint_epoch_from_log": best_epoch,
                "checkpoint_val_auc_from_log": best_auc,
                "checkpoint_val_f1_from_log": best_f1,
                "checkpoint_file_used": best_ckpt,
            })

        except Exception as e:
            skipped.append({
                "path": path,
                "error": str(e),
            })

if len(results) == 0:
    print("First skipped errors:")
    for s in skipped[:10]:
        print(s)

    raise RuntimeError("No validation images were processed successfully.")

print(f"Processed: {len(results)}")
print(f"Skipped: {len(skipped)}")
# Out:
# Best epoch from log by AUC: 0
# Best val AUC from log: 0.539297
# Val F1 at best-AUC epoch from log: 0.366197
# Using checkpoint:
# /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/recce_train/ckpt_best.pth
# Checkpoint source: ckpt_best.pth
# Checkpoint metadata from log.txt:
#   best_epoch: 0
#   best_val_auc: 0.539297
#   val_f1_at_best_auc_epoch: 0.366197
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-cadene/xception-43020ad28.pth" to /root/.cache/torch/hub/checkpoints/xception-43020ad28.pth
# Missing keys: 242
# Unexpected keys: 0
# First missing keys: ['backbone.conv1.weight', 'backbone.bn1.weight', 'backbone.bn1.bias', 'backbone.bn1.running_mean', 'backbone.bn1.running_var', 'backbone.conv2.weight', 'backbone.bn2.weight', 'backbone.bn2.bias', 'backbone.bn2.running_mean', 'backbone.bn2.running_var']
# Processed: 100
# Skipped: 0

# %%
# model_missing = [k for k in missing if k.startswith("model.")]
# backbone_missing = [k for k in missing if k.startswith("backbone.")]

# print("Missing active self.model keys:", len(model_missing))
# print("Missing unused self.backbone keys:", len(backbone_missing))

# if model_missing:
#     print("First active model missing keys:", model_missing[:20])
# Out:
# Missing active self.model keys: 0
# Missing unused self.backbone keys: 242

# %%
# ── Inference on TRAINING set: RECCE / DeepfakeBench ───────────────────────
TRAIN_JSON = "/content/DiffusionForensics_Recons/train.json"

with open(TRAIN_JSON) as f:
    train_items = json.load(f)

print(f"Running inference on {len(train_items)} training images...")

train_results = []
train_skipped = []

model.eval()

with torch.no_grad():
    for i, item in enumerate(train_items):
        path = item["path"]
        label = item["label"]

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
            }

            # DeepfakeBench RecceDetector expects a single data_dict argument
            out_dict = model(input_dict)

            # RecceDetector returns: {"cls": pred, "prob": prob, "feat": features}
            prob = out_dict["prob"].view(-1)[0].item()
            pred = 1 if prob >= THRESHOLD else 0

            train_results.append({
                "path": path,
                "true_label": int(label),
                "pred": int(pred),
                "confidence": float(prob),
                "correct": bool(pred == label),
            })

        except Exception as e:
            train_skipped.append({
                "path": path,
                "error": str(e),
            })

        if (i + 1) % 500 == 0:
            print(f"  {i + 1}/{len(train_items)}... processed={len(train_results)} skipped={len(train_skipped)}")

if len(train_results) == 0:
    print("First skipped errors:")
    for s in train_skipped[:10]:
        print(s)
    raise RuntimeError("No training images were processed successfully.")

train_acc = 100 * sum(r["correct"] for r in train_results) / len(train_results)

print(f"Done: {len(train_results)} images, Train accuracy: {train_acc:.1f}%, skipped: {len(train_skipped)}")
# Out:
# Running inference on 1000 training images...
#   500/1000... processed=500 skipped=0
#   1000/1000... processed=1000 skipped=0
# Done: 1000 images, Train accuracy: 50.4%, skipped: 0

# %%
# ── ROC Curve: Validation only ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from IPython.display import Image, display

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

# ── Validation ROC ──
y_true = np.array([r["true_label"] for r in results])
y_score = np.array([r["confidence"] for r in results])

fpr, tpr, thresh = roc_curve(y_true, y_score)
auc_val = auc(fpr, tpr)

# ── Plot ──
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor('#FAFAFA')

ax.set_facecolor('#F4F4F4')
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_color('#CCCCCC')
ax.set_aspect('equal')

ax.plot(fpr, tpr, color='#7B4FB5', linewidth=2.5, label='ROC curve')
ax.fill_between(fpr, tpr, alpha=0.25, color='#9B7FD4')

ax.text(0.55, 0.35, f'AUC = {auc_val:.2f}', fontsize=20,
        fontweight='bold', color='#5A3A8A',
        ha='center', va='center')

# Random baseline
ax.plot([0, 1], [0, 1], color='#888', linestyle='--', linewidth=1,
        label='Random (0.50)')

# Best threshold (Youden)
opt_idx = np.argmax(tpr - fpr)
ax.scatter(fpr[opt_idx], tpr[opt_idx], color='#7B4FB5',
           s=100, zorder=5, edgecolors='white', linewidths=2)

ax.annotate(f'Best: {thresh[opt_idx]:.3f}\n'
            f'TPR={tpr[opt_idx]:.2f}, FPR={fpr[opt_idx]:.2f}',
            xy=(fpr[opt_idx], tpr[opt_idx]),
            xytext=(fpr[opt_idx] + 0.15, tpr[opt_idx] - 0.12),
            fontsize=9, color='#5A3A8A',
            arrowprops=dict(arrowstyle='->', color='#7B4FB5', lw=1.5))

ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_xlabel('FPR', fontsize=12)
ax.set_ylabel('TPR', fontsize=12)
ax.set_title('ROC — Validation Set (CapsuleNet)', fontsize=14, pad=12)

ax.legend(fontsize=10, loc='lower right', framealpha=0.5)

plt.tight_layout()
plt.savefig('roc_val.jpg', dpi=80, bbox_inches='tight',
            facecolor=fig.get_facecolor())
plt.close(fig)

display(Image('roc_val.jpg'))

print(f"\nValidation AUC: {auc_val:.4f}")
print(f"Best threshold: {thresh[opt_idx]:.4f}")
# Out:
# Validation AUC: 0.5028
# Best threshold: 0.4843

# %%
# ── Confusion Matrix: Validation only, RECCE — best-AUC checkpoint results ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
)
from IPython.display import Image, display

MODEL_NAME = "RECCE"

def compute_metrics(res):
    y_true = np.array([int(r["true_label"]) for r in res])
    y_pred = np.array([int(r["pred"]) for r in res])

    # Some inference cells use "confidence", others use "score"
    if "confidence" in res[0]:
        y_score = np.array([float(r["confidence"]) for r in res])
    elif "score" in res[0]:
        y_score = np.array([float(r["score"]) for r in res])
    else:
        raise KeyError("results must contain either 'confidence' or 'score'.")

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    TN, FP, FN, TP = cm.ravel()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    auc_direct = roc_auc_score(y_true, y_score)
    auc_inverted = roc_auc_score(y_true, 1.0 - y_score)

    # Use whichever direction gives better fake-vs-real ranking
    if auc_inverted > auc_direct:
        auc_val = auc_inverted
        score_mode = "1 - score"
    else:
        auc_val = auc_direct
        score_mode = "score"

    return TN, FP, FN, TP, accuracy, precision, recall, f1, auc_val, score_mode


def draw_cm(ax, TN, FP, FN, TP, title):
    cell_labels = [["TN", "FP"], ["FN", "TP"]]
    cell_values = [[TN, FP], [FN, TP]]
    cell_colors = [["#d4edda", "#f8d7da"],
                   ["#f8d7da", "#d4edda"]]

    for i in range(2):
        for j in range(2):
            ax.add_patch(
                plt.Rectangle(
                    (j, 1 - i), 1, 1,
                    facecolor=cell_colors[i][j],
                    edgecolor="black",
                    linewidth=1.5,
                )
            )
            ax.text(
                j + 0.5,
                1 - i + 0.5,
                f"{cell_labels[i][j]}\n{cell_values[i][j]}",
                ha="center",
                va="center",
                fontsize=18,
                fontweight="bold",
                color="black",
            )

    ax.set_xlim(0, 2)
    ax.set_ylim(0, 2)
    ax.set_xticks([0.5, 1.5])
    ax.set_yticks([1.5, 0.5])

    ax.set_xticklabels(["Predicted REAL", "Predicted FAKE"], fontsize=10)
    ax.set_yticklabels(["REAL (0)", "FAKE (1)"], fontsize=10)

    ax.set_xlabel("Predicted label", fontsize=11, labelpad=8)
    ax.set_ylabel("True label", fontsize=11, labelpad=8)

    ax.tick_params(length=0)
    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_title(title, fontsize=10, pad=14)


# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

TN, FP, FN, TP, acc, prec, rec, f1, auc_val, score_mode = compute_metrics(results)

# Pull checkpoint metadata from RECCE inference results
ckpt_epoch = results[0].get(
    "checkpoint_epoch",
    results[0].get("checkpoint_epoch_from_log", None)
)

ckpt_val_auc = results[0].get(
    "checkpoint_val_auc",
    results[0].get("checkpoint_val_auc_from_log", None)
)

ckpt_val_f1 = results[0].get(
    "checkpoint_val_f1",
    results[0].get("checkpoint_val_f1_from_log", None)
)

print(f"{'═' * 60}")
print(f"  Validation Metrics — {MODEL_NAME}")
print(f"{'═' * 60}")

if ckpt_epoch is not None:
    print(f"  Selected checkpoint epoch: {ckpt_epoch}")
if ckpt_val_auc is not None:
    print(f"  AUC Best Epoch:     {float(ckpt_val_auc):.4f}")
if ckpt_val_f1 is not None:
    print(f"  F1 Best-AUC epoch:  {float(ckpt_val_f1):.4f}")

print(f"  Accuracy:           {acc:.4f}")
print(f"  Precision:          {prec:.4f}")
print(f"  Recall:             {rec:.4f}")
print(f"  F1:                 {f1:.4f}")
print(f"  AUC:                {auc_val:.4f}")
print(f"  Score mode:         {score_mode}")
print(f"{'─' * 60}")
print(f"  TP (correct fake):         {TP}")
print(f"  TN (correct real):         {TN}")
print(f"  FP (false alarm):          {FP}")
print(f"  FN (missed fake):          {FN}")
print(f"{'═' * 60}")

fig, ax = plt.subplots(figsize=(6, 5))
fig.patch.set_facecolor("white")

draw_cm(
    ax,
    TN, FP, FN, TP,
    f"Val · AUC {auc_val:.3f} · Acc {acc * 100:.1f}% · F1 {f1 * 100:.1f}%"
)

plt.suptitle(f"Confusion Matrix — Validation ({MODEL_NAME})", fontsize=14, y=1.02)
plt.tight_layout()

out_path = "confusion_matrix_val_recce.jpg"
plt.savefig(out_path, dpi=80, bbox_inches="tight", facecolor=fig.get_facecolor())
plt.close(fig)

display(Image(out_path))
# Out:
# ════════════════════════════════════════════════════════════
#   Validation Metrics — RECCE
# ════════════════════════════════════════════════════════════
#   Selected checkpoint epoch: 0
#   AUC Best Epoch:     0.5393
#   F1 Best-AUC epoch:  0.3662
#   Accuracy:           0.5100
#   Precision:          0.5200
#   Recall:             0.2600
#   F1:                 0.3467
#   AUC:                0.5028
#   Score mode:         score
# ────────────────────────────────────────────────────────────
#   TP (correct fake):         13
#   TN (correct real):         38
#   FP (false alarm):          12
#   FN (missed fake):          37
# ════════════════════════════════════════════════════════════

# %%
# Badly / Well Detected dataset — VALIDATION

# %matplotlib inline

import os
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image, display

# ── Rebuild all summary information from `results` ────────────────────────────
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

total = len(results)
n_correct = sum(r["correct"] for r in results)
accuracy = 100 * n_correct / total

probs = [r["confidence"] for r in results]

well  = [r for r in results if r["correct"]]
badly = [r for r in results if not r["correct"]]

well_sorted  = sorted(well,  key=lambda x: abs(x["confidence"] - 0.5), reverse=True)
badly_sorted = sorted(badly, key=lambda x: abs(x["confidence"] - 0.5), reverse=True)

well_sample  = well_sorted[:100]
badly_sample = badly_sorted[:100]

n_real = sum(r["true_label"] == 0 for r in results)
n_fake = sum(r["true_label"] == 1 for r in results)

tp = sum((r["true_label"] == 1 and r["pred"] == 1) for r in results)
tn = sum((r["true_label"] == 0 and r["pred"] == 0) for r in results)
fp = sum((r["true_label"] == 0 and r["pred"] == 1) for r in results)
fn = sum((r["true_label"] == 1 and r["pred"] == 0) for r in results)

real_acc = 100 * tn / max(1, n_real)
fake_acc = 100 * tp / max(1, n_fake)
precision_fake = tp / max(1, tp + fp)
recall_fake = tp / max(1, tp + fn)
f1_fake = 2 * precision_fake * recall_fake / max(1e-12, precision_fake + recall_fake)

# ── Print validation info ─────────────────────────────────────────────────────
print(f"Validation inference: {total} images\n")
print(f"Done: {n_correct}/{total} correct ({accuracy:.1f}% accuracy)")
print(f"Min prob: {min(probs):.4f}  Max: {max(probs):.4f}  Mean: {sum(probs)/len(probs):.4f}")
print(f"Well detected:  {len(well)}")
print(f"Badly detected: {len(badly)}")
print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")



# ── Per-source breakdown from validation mixed filenames ──────────────────────
def get_source(path):
    name = os.path.basename(path).lower()
    parts = name.split("_")
    return parts[1] if len(parts) >= 3 else "unknown"



if len(skipped) > 0:
    print(f"\nSkipped images: {len(skipped)}")
    for s in skipped[:10]:
        print(f"  {os.path.basename(s['path'])}: {s['error']}")

# ── Helpers ───────────────────────────────────────────────────────────────────
def label_str(l):
    return "REAL" if l == 0 else "FAKE"

def load_thumb(path, size=128):
    img = PILImage.open(path).convert("RGB")
    w, h = img.size
    side = min(w, h)
    img = img.crop(((w - side) // 2, (h - side) // 2,
                    (w + side) // 2, (h + side) // 2))
    return img.resize((size, size), PILImage.LANCZOS)

def make_grid(samples, title, filename, max_rows=10, cols=10):
    n = len(samples)
    if n == 0:
        print(f"No samples to plot for {filename}")
        return

    rows = min(max_rows, (n + cols - 1) // cols)
    show = min(n, rows * cols)

    fig, axes = plt.subplots(rows, cols, figsize=(22, rows * 2.7))
    fig.patch.set_facecolor('#1a1a1a')
    fig.suptitle(title, fontsize=15, color='white', y=0.995, fontweight='medium')

    if rows == 1:
        axes = [axes]
    flat_axes = [a for row in axes for a in row]

    for idx, ax in enumerate(flat_axes):
        if idx >= show:
            ax.axis('off')
            continue

        r = samples[idx]
        try:
            ax.imshow(load_thumb(r["path"]))
        except Exception:
            ax.set_facecolor('#333')
            ax.text(0.5, 0.5, 'error', ha='center', va='center',
                    color='white', fontsize=7, transform=ax.transAxes)

        true_color = '#2ecc71' if r["true_label"] == 0 else '#e74c3c'
        for spine in ax.spines.values():
            spine.set_edgecolor(true_color)
            spine.set_linewidth(3)

        ax.set_xticks([])
        ax.set_yticks([])

        src = get_source(r["path"])
        fname = os.path.basename(r["path"])
        ax.set_title(
            f"\nTrue: {label_str(r['true_label'])} → Pred: {label_str(r['pred'])}\n"
            f"conf: {r['confidence']:.3f}",
            fontsize=7, color='white', pad=4
        )

    for ax in flat_axes[show:]:
        ax.axis('off')

    real_p = mpatches.Patch(color='#2ecc71', label='True label: REAL')
    fake_p = mpatches.Patch(color='#e74c3c', label='True label: FAKE')
    fig.legend(handles=[real_p, fake_p], loc='lower center', ncol=2,
               fontsize=10, framealpha=0.3, facecolor='#333',
               labelcolor='white', bbox_to_anchor=(0.5, 0.01))

    plt.subplots_adjust(hspace=0.60, wspace=0.08, top=0.93, bottom=0.05)
    plt.savefig(filename, dpi=80, bbox_inches='tight',
                facecolor=fig.get_facecolor())
    plt.close(fig)
    display(Image(filename))

# ── Plots ─────────────────────────────────────────────────────────────────────
make_grid(
    well_sample,
    title=f'{len(well_sample)} most confidently CORRECT predictions (Validation)\n'
          'Border = true label',
    filename='well_detected_val.jpg'
)

make_grid(
    badly_sample,
    title=f'{len(badly_sample)} most confidently WRONG predictions (Validation)\n'
          'Border = true label',
    filename='badly_detected_val.jpg'
)
# Out:
# Validation inference: 100 images
#
# Done: 51/100 correct (51.0% accuracy)
# Min prob: 0.3406  Max: 0.6208  Mean: 0.4644
# Well detected:  51
# Badly detected: 49
# TP=13, TN=38, FP=12, FN=37

# %%
# !pip install nbconvert -q

NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Recce Train.ipynb"
OUTPUT_DIR    = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks"

# !jupyter nbconvert \
    --to html \
    --embed-images \
    --output-dir "{OUTPUT_DIR}" \
    "{NOTEBOOK_PATH}"

print("Done — check your Drive for the .html file")
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Recce Train.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 5 image(s).
# [NbConvertApp] Writing 1329714 bytes to /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks/Recce Train.html
# Done — check your Drive for the .html file
