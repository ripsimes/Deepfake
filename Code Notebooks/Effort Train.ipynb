# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip3 install -q imgaug albumentations==1.3.1 timm einops ftfy regex lmdb fvcore
# !pip install -q "numpy<2" --force-reinstall

# %%
import numpy, torch, torchvision
# print("numpy:", numpy.__version__)
# print("torch:", torch.__version__)
# print("torchvision:", torchvision.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# CUDA: True

# %%
# %%capture
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench
# !pip install jedi
# !python -m pip install -U pip setuptools wheel
# !pip install -r requirements.txt
# !pip install -e .

# %%
# %%capture
# %cd "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub"
# !head -n -1 requirements.txt > requirements_no_flash.txt
# !pip install -r requirements_no_flash.txt

# %%
import os, glob, json, random

TRAIN_DIR = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/training_data"
VAL_DIR   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/validation_data"
TEST_DIR  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/Datasets/publictest_data"

VAL_REF   = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/validation_reference/reference.txt"
TEST_REF  = "/content/drive/MyDrive/Capstone_Hripsime/Database/RDDC_Dataset/RDDC_References/publictest_reference/reference.txt"

STAGING = "/content/DiffusionForensics_Recons"
os.makedirs(STAGING, exist_ok=True)

IMG_EXTS = (".png", ".jpg", ".jpeg", ".webp", ".bmp", ".tif", ".tiff")

# ═══════════════════════════════════════════════════
# TRAINING — training_data_final
# ═══════════════════════════════════════════════════
train_items = []
for ext in IMG_EXTS:
    for p in glob.glob(os.path.join(TRAIN_DIR, f"*{ext}")):
        name = os.path.basename(p).lower()
        if "_real" in name:
            train_items.append({"path": p, "label": 0})
        elif "_fake" in name:
            train_items.append({"path": p, "label": 1})

random.seed(42)
random.shuffle(train_items)

n_real = sum(1 for x in train_items if x["label"] == 0)
n_fake = sum(1 for x in train_items if x["label"] == 1)
print(f"TRAIN: {len(train_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# VALIDATION — validation_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(VAL_REF) as f:
    val_labels = [int(line.strip()) for line in f if line.strip()]

val_images = sorted(glob.glob(os.path.join(VAL_DIR, "*.*")))
val_images = [p for p in val_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(val_images) == len(val_labels), \
    f"Mismatch: {len(val_images)} images vs {len(val_labels)} labels"

val_items = [{"path": p, "label": l} for p, l in zip(val_images, val_labels)]

n_real = sum(1 for x in val_items if x["label"] == 0)
n_fake = sum(1 for x in val_items if x["label"] == 1)
print(f"VAL:   {len(val_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# TEST — publictest_data_final + reference.txt
# ═══════════════════════════════════════════════════
with open(TEST_REF) as f:
    test_labels = [int(line.strip()) for line in f if line.strip()]

test_images = sorted(glob.glob(os.path.join(TEST_DIR, "*.*")))
test_images = [p for p in test_images if os.path.splitext(p)[1].lower() in IMG_EXTS]

assert len(test_images) == len(test_labels), \
    f"Mismatch: {len(test_images)} images vs {len(test_labels)} labels"

test_items = [{"path": p, "label": l} for p, l in zip(test_images, test_labels)]

n_real = sum(1 for x in test_items if x["label"] == 0)
n_fake = sum(1 for x in test_items if x["label"] == 1)
print(f"TEST:  {len(test_items)} images  (real={n_real}, fake={n_fake})")

# ═══════════════════════════════════════════════════
# SAVE JSONs
# ═══════════════════════════════════════════════════
for name, data in [("train", train_items), ("val", val_items), ("test", test_items)]:
    out = os.path.join(STAGING, f"{name}.json")
    with open(out, "w") as f:
        json.dump(data, f)
    print(f"\n✓ {name}.json → {len(data)} items → {out}")
# Out:
# TRAIN: 1000 images  (real=500, fake=500)
# VAL:   100 images  (real=50, fake=50)
# TEST:  1000 images  (real=500, fake=500)
#
# ✓ train.json → 1000 items → /content/DiffusionForensics_Recons/train.json
#
# ✓ val.json → 100 items → /content/DiffusionForensics_Recons/val.json
#
# ✓ test.json → 1000 items → /content/DiffusionForensics_Recons/test.json

# %%
# import shutil
# from pathlib import Path

# CKPT_DIR = Path("/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train")

# if CKPT_DIR.exists():
#     shutil.rmtree(CKPT_DIR)
#     print("🧹 Old checkpoints deleted")

# CKPT_DIR.mkdir(parents=True, exist_ok=True)
# print("✅ Fresh checkpoint directory created:", CKPT_DIR)
# Out:
# 🧹 Old checkpoints deleted
# ✅ Fresh checkpoint directory created: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train

# %%
# %cd /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub

# !PYTHONPATH=/content/drive/MyDrive/Capstone_Hripsime/Frameworks:$PWD \
# MASTER_ADDR=127.0.0.1 MASTER_PORT=29601 \
# python -m ForensicHub.training_scripts.train \
# --config "ForensicHub/statics/crossdataset_image/effort_train.yaml"
# Out:
# /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/timm/optim/optim_factory.py:7: FutureWarning: Importing from timm.optim.optim_factory is deprecated, please import via timm.optim
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.optim", FutureWarning)
# 2026-04-29 10:29:06.054589: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.10.0+cu128
# Current Torch version: 2.10
# /usr/local/lib/python3.12/dist-packages/IMDLBenCo/training_scripts/trainer/trainer.py:25: UserWarning: HOPE YOU TO READ: Starting from IMDLBenCo version v0.1.31, we have discovered a misdefinition regarding the --if_not_amp parameter in the argument parser. For more details, please refer to: https://github.com/scu-zjz/IMDLBenCo/issues/89. As a result, if you use the train.py script generated by an earlier version of 'benco init' before v0.1.30, along with the latest version of trainer.py, it may lead to AMP (Automatic Mixed Precision) being incorrectly enabled or disabled. We recommend updating to the latest version(after v0.1.31, include) of IMDLBenCo and re-initializing the project using 'benco init' to ensure that the --if_not_amp parameter is correctly defined.  Or for already initialized projects, please manually modify the action of the --if_not_amp parameter in train.py to 'store_true' to ensure correct logic.  We apologize for any inconvenience this may have caused.!!!!!!
#   warnings.warn(
# Not using distributed mode
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [10:29:09.075255] [patch] initialized torch.distributed process group (single-process, gloo)
# [10:29:09.077464] job dir: /content/drive/.shortcut-targets-by-id/1dhyo0l8QyhlSMCpS1lnpG93K1z7h6d4K/Capstone_Hripsime/Frameworks/ForensicHub/ForensicHub/training_scripts
# [10:29:09.077601] =====args:=====
# [10:29:09.077760] Namespace(gpus=0.0,
# flag='train',
# log_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train',
# if_predict_label=True,
# if_predict_mask=False,
# num_classes=2,
# batch_size=32,
# test_batch_size=16,
# epochs=20,
# accum_iter=1,
# record_epoch=0,
# no_model_eval=False,
# test_period=1,
# log_per_epoch_count=20,
# find_unused_parameters=True,
# use_amp=True,
# weight_decay=0.05,
# lr=0.0001,
# blr=0.001,
# min_lr=1e-05,
# warmup_epochs=1,
# device='cuda',
# seed=42,
# resume='',
# start_epoch=0,
# num_workers=2,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# output_dir='/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train',
# if_not_amp=False,
# distributed=False)
# [10:29:09.088126] [build_from_registry] Creating model 'AIGCTransform' with args: {'norm_type': 'clip'}
# [10:29:09.088708] Train transform:  Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [10:29:09.089016] Test transform:  Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [10:29:09.089151] Post transform:  Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})
# [10:29:09.089334] Post function check: effortdetector_post_func
# [10:29:09.089420] None
# [10:29:09.089660] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 224, 'path': '/content/DiffusionForensics_Recons/train.json', 'post_funcs': None, 'common_transform': Compose([
#   HorizontalFlip(always_apply=False, p=0.5),
#   VerticalFlip(always_apply=False, p=0.5),
#   RandomBrightnessContrast(always_apply=False, p=1, brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), brightness_by_max=True),
#   ImageCompression(always_apply=False, p=0.2, quality_lower=70, quality_upper=100, compression_type=0),
#   RandomRotate90(always_apply=False, p=0.5),
#   GaussianBlur(always_apply=False, p=0.2, blur_limit=(3, 7), sigma_limit=(0, 0)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [10:29:09.091183] [build_from_registry] Creating model 'AIGCLabelDataset' with args: {'image_size': 224, 'path': '/content/DiffusionForensics_Recons/val.json', 'post_funcs': None, 'common_transform': Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}), 'post_transform': Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.48145466, 0.4578275, 0.40821073], std=[0.26862954, 0.26130258, 0.27577711], max_pixel_value=255.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=True),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={})}
# [10:29:09.091515] Train dataset: DiffusionForensics_train.
# [10:29:09.091614] 1000
# [10:29:09.091697] [AIGCLabelDataset] at /content/DiffusionForensics_Recons/train.json, with length of 1,000
# [10:29:09.091765] Test dataset: ['DiffusionForensics_val'].
# [10:29:09.091839] [100]
# [10:29:09.788047] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [10:29:09.788246] spatial_count=0 keep_stride_count=0
# [10:29:13.691677] ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# [10:29:13.691838] spatial_count=0 keep_stride_count=0
# [10:29:13.752722] [lazy import] Loading 'EffortDetector' from 'DeepfakeBench.training.detectors.effort_detector'
# [10:29:13.762050] [build_from_registry] Creating model 'EffortDetector' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml'}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 590/590 [00:00<00:00, 752.34it/s, Materializing param=visual_projection.weight]
# CLIPModel LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [10:30:06.735398] embeddings.class_embedding: False
# [10:30:06.735645] embeddings.patch_embedding.weight: False
# [10:30:06.735794] embeddings.position_embedding.weight: False
# [10:30:06.735920] pre_layrnorm.weight: False
# [10:30:06.736035] pre_layrnorm.bias: False
# [10:30:06.736164] encoder.layers.0.self_attn.k_proj.weight_main: False
# [10:30:06.736263] encoder.layers.0.self_attn.k_proj.bias: False
# [10:30:06.736374] encoder.layers.0.self_attn.k_proj.S_residual: True
# [10:30:06.736466] encoder.layers.0.self_attn.k_proj.U_residual: True
# [10:30:06.736557] encoder.layers.0.self_attn.k_proj.V_residual: True
# [10:30:06.736654] encoder.layers.0.self_attn.v_proj.weight_main: False
# [10:30:06.736744] encoder.layers.0.self_attn.v_proj.bias: False
# [10:30:06.736835] encoder.layers.0.self_attn.v_proj.S_residual: True
# [10:30:06.736939] encoder.layers.0.self_attn.v_proj.U_residual: True
# [10:30:06.737030] encoder.layers.0.self_attn.v_proj.V_residual: True
# [10:30:06.737148] encoder.layers.0.self_attn.q_proj.weight_main: False
# [10:30:06.737268] encoder.layers.0.self_attn.q_proj.bias: False
# [10:30:06.737366] encoder.layers.0.self_attn.q_proj.S_residual: True
# [10:30:06.737465] encoder.layers.0.self_attn.q_proj.U_residual: True
# [10:30:06.737562] encoder.layers.0.self_attn.q_proj.V_residual: True
# [10:30:06.737665] encoder.layers.0.self_attn.out_proj.weight_main: False
# [10:30:06.737762] encoder.layers.0.self_attn.out_proj.bias: False
# [10:30:06.737860] encoder.layers.0.self_attn.out_proj.S_residual: True
# [10:30:06.737967] encoder.layers.0.self_attn.out_proj.U_residual: True
# [10:30:06.738064] encoder.layers.0.self_attn.out_proj.V_residual: True
# [10:30:06.738175] encoder.layers.0.layer_norm1.weight: False
# [10:30:06.738277] encoder.layers.0.layer_norm1.bias: False
# [10:30:06.738388] encoder.layers.0.mlp.fc1.weight: False
# [10:30:06.738483] encoder.layers.0.mlp.fc1.bias: False
# [10:30:06.738585] encoder.layers.0.mlp.fc2.weight: False
# [10:30:06.738684] encoder.layers.0.mlp.fc2.bias: False
# [10:30:06.738787] encoder.layers.0.layer_norm2.weight: False
# [10:30:06.738884] encoder.layers.0.layer_norm2.bias: False
# [10:30:06.738992] encoder.layers.1.self_attn.k_proj.weight_main: False
# [10:30:06.739087] encoder.layers.1.self_attn.k_proj.bias: False
# [10:30:06.739185] encoder.layers.1.self_attn.k_proj.S_residual: True
# [10:30:06.739289] encoder.layers.1.self_attn.k_proj.U_residual: True
# [10:30:06.739392] encoder.layers.1.self_attn.k_proj.V_residual: True
# [10:30:06.739517] encoder.layers.1.self_attn.v_proj.weight_main: False
# [10:30:06.739615] encoder.layers.1.self_attn.v_proj.bias: False
# [10:30:06.739714] encoder.layers.1.self_attn.v_proj.S_residual: True
# [10:30:06.739811] encoder.layers.1.self_attn.v_proj.U_residual: True
# [10:30:06.739919] encoder.layers.1.self_attn.v_proj.V_residual: True
# [10:30:06.740028] encoder.layers.1.self_attn.q_proj.weight_main: False
# [10:30:06.740125] encoder.layers.1.self_attn.q_proj.bias: False
# [10:30:06.740241] encoder.layers.1.self_attn.q_proj.S_residual: True
# [10:30:06.740335] encoder.layers.1.self_attn.q_proj.U_residual: True
# [10:30:06.740433] encoder.layers.1.self_attn.q_proj.V_residual: True
# [10:30:06.740539] encoder.layers.1.self_attn.out_proj.weight_main: False
# [10:30:06.740636] encoder.layers.1.self_attn.out_proj.bias: False
# [10:30:06.740734] encoder.layers.1.self_attn.out_proj.S_residual: True
# [10:30:06.740831] encoder.layers.1.self_attn.out_proj.U_residual: True
# [10:30:06.740942] encoder.layers.1.self_attn.out_proj.V_residual: True
# [10:30:06.741046] encoder.layers.1.layer_norm1.weight: False
# [10:30:06.741143] encoder.layers.1.layer_norm1.bias: False
# [10:30:06.741256] encoder.layers.1.mlp.fc1.weight: False
# [10:30:06.741362] encoder.layers.1.mlp.fc1.bias: False
# [10:30:06.741480] encoder.layers.1.mlp.fc2.weight: False
# [10:30:06.741581] encoder.layers.1.mlp.fc2.bias: False
# [10:30:06.741682] encoder.layers.1.layer_norm2.weight: False
# [10:30:06.741778] encoder.layers.1.layer_norm2.bias: False
# [10:30:06.741887] encoder.layers.2.self_attn.k_proj.weight_main: False
# [10:30:06.741986] encoder.layers.2.self_attn.k_proj.bias: False
# [10:30:06.742086] encoder.layers.2.self_attn.k_proj.S_residual: True
# [10:30:06.742188] encoder.layers.2.self_attn.k_proj.U_residual: True
# [10:30:06.742291] encoder.layers.2.self_attn.k_proj.V_residual: True
# [10:30:06.742393] encoder.layers.2.self_attn.v_proj.weight_main: False
# [10:30:06.742489] encoder.layers.2.self_attn.v_proj.bias: False
# [10:30:06.742587] encoder.layers.2.self_attn.v_proj.S_residual: True
# [10:30:06.742685] encoder.layers.2.self_attn.v_proj.U_residual: True
# [10:30:06.742782] encoder.layers.2.self_attn.v_proj.V_residual: True
# [10:30:06.742883] encoder.layers.2.self_attn.q_proj.weight_main: False
# [10:30:06.742980] encoder.layers.2.self_attn.q_proj.bias: False
# [10:30:06.743078] encoder.layers.2.self_attn.q_proj.S_residual: True
# [10:30:06.743175] encoder.layers.2.self_attn.q_proj.U_residual: True
# [10:30:06.743278] encoder.layers.2.self_attn.q_proj.V_residual: True
# [10:30:06.743384] encoder.layers.2.self_attn.out_proj.weight_main: False
# [10:30:06.743491] encoder.layers.2.self_attn.out_proj.bias: False
# [10:30:06.743602] encoder.layers.2.self_attn.out_proj.S_residual: True
# [10:30:06.743700] encoder.layers.2.self_attn.out_proj.U_residual: True
# [10:30:06.743797] encoder.layers.2.self_attn.out_proj.V_residual: True
# [10:30:06.743899] encoder.layers.2.layer_norm1.weight: False
# [10:30:06.744016] encoder.layers.2.layer_norm1.bias: False
# [10:30:06.744124] encoder.layers.2.mlp.fc1.weight: False
# [10:30:06.744219] encoder.layers.2.mlp.fc1.bias: False
# [10:30:06.744329] encoder.layers.2.mlp.fc2.weight: False
# [10:30:06.744425] encoder.layers.2.mlp.fc2.bias: False
# [10:30:06.744528] encoder.layers.2.layer_norm2.weight: False
# [10:30:06.744624] encoder.layers.2.layer_norm2.bias: False
# [10:30:06.744734] encoder.layers.3.self_attn.k_proj.weight_main: False
# [10:30:06.744828] encoder.layers.3.self_attn.k_proj.bias: False
# [10:30:06.744938] encoder.layers.3.self_attn.k_proj.S_residual: True
# [10:30:06.745036] encoder.layers.3.self_attn.k_proj.U_residual: True
# [10:30:06.745134] encoder.layers.3.self_attn.k_proj.V_residual: True
# [10:30:06.745246] encoder.layers.3.self_attn.v_proj.weight_main: False
# [10:30:06.745340] encoder.layers.3.self_attn.v_proj.bias: False
# [10:30:06.745439] encoder.layers.3.self_attn.v_proj.S_residual: True
# [10:30:06.745543] encoder.layers.3.self_attn.v_proj.U_residual: True
# [10:30:06.745638] encoder.layers.3.self_attn.v_proj.V_residual: True
# [10:30:06.745740] encoder.layers.3.self_attn.q_proj.weight_main: False
# [10:30:06.745835] encoder.layers.3.self_attn.q_proj.bias: False
# [10:30:06.745946] encoder.layers.3.self_attn.q_proj.S_residual: True
# [10:30:06.746044] encoder.layers.3.self_attn.q_proj.U_residual: True
# [10:30:06.746139] encoder.layers.3.self_attn.q_proj.V_residual: True
# [10:30:06.746261] encoder.layers.3.self_attn.out_proj.weight_main: False
# [10:30:06.746353] encoder.layers.3.self_attn.out_proj.bias: False
# [10:30:06.746450] encoder.layers.3.self_attn.out_proj.S_residual: True
# [10:30:06.746534] encoder.layers.3.self_attn.out_proj.U_residual: True
# [10:30:06.746630] encoder.layers.3.self_attn.out_proj.V_residual: True
# [10:30:06.746733] encoder.layers.3.layer_norm1.weight: False
# [10:30:06.746831] encoder.layers.3.layer_norm1.bias: False
# [10:30:06.746951] encoder.layers.3.mlp.fc1.weight: False
# [10:30:06.747046] encoder.layers.3.mlp.fc1.bias: False
# [10:30:06.747148] encoder.layers.3.mlp.fc2.weight: False
# [10:30:06.747257] encoder.layers.3.mlp.fc2.bias: False
# [10:30:06.747357] encoder.layers.3.layer_norm2.weight: False
# [10:30:06.747454] encoder.layers.3.layer_norm2.bias: False
# [10:30:06.747565] encoder.layers.4.self_attn.k_proj.weight_main: False
# [10:30:06.747667] encoder.layers.4.self_attn.k_proj.bias: False
# [10:30:06.747766] encoder.layers.4.self_attn.k_proj.S_residual: True
# [10:30:06.747863] encoder.layers.4.self_attn.k_proj.U_residual: True
# [10:30:06.747959] encoder.layers.4.self_attn.k_proj.V_residual: True
# [10:30:06.748062] encoder.layers.4.self_attn.v_proj.weight_main: False
# [10:30:06.748159] encoder.layers.4.self_attn.v_proj.bias: False
# [10:30:06.748270] encoder.layers.4.self_attn.v_proj.S_residual: True
# [10:30:06.748371] encoder.layers.4.self_attn.v_proj.U_residual: True
# [10:30:06.748468] encoder.layers.4.self_attn.v_proj.V_residual: True
# [10:30:06.748570] encoder.layers.4.self_attn.q_proj.weight_main: False
# [10:30:06.748667] encoder.layers.4.self_attn.q_proj.bias: False
# [10:30:06.748764] encoder.layers.4.self_attn.q_proj.S_residual: True
# [10:30:06.748860] encoder.layers.4.self_attn.q_proj.U_residual: True
# [10:30:06.748955] encoder.layers.4.self_attn.q_proj.V_residual: True
# [10:30:06.749058] encoder.layers.4.self_attn.out_proj.weight_main: False
# [10:30:06.749154] encoder.layers.4.self_attn.out_proj.bias: False
# [10:30:06.749257] encoder.layers.4.self_attn.out_proj.S_residual: True
# [10:30:06.749355] encoder.layers.4.self_attn.out_proj.U_residual: True
# [10:30:06.749453] encoder.layers.4.self_attn.out_proj.V_residual: True
# [10:30:06.749558] encoder.layers.4.layer_norm1.weight: False
# [10:30:06.749655] encoder.layers.4.layer_norm1.bias: False
# [10:30:06.749762] encoder.layers.4.mlp.fc1.weight: False
# [10:30:06.749857] encoder.layers.4.mlp.fc1.bias: False
# [10:30:06.749963] encoder.layers.4.mlp.fc2.weight: False
# [10:30:06.750060] encoder.layers.4.mlp.fc2.bias: False
# [10:30:06.750161] encoder.layers.4.layer_norm2.weight: False
# [10:30:06.750271] encoder.layers.4.layer_norm2.bias: False
# [10:30:06.750381] encoder.layers.5.self_attn.k_proj.weight_main: False
# [10:30:06.750475] encoder.layers.5.self_attn.k_proj.bias: False
# [10:30:06.750572] encoder.layers.5.self_attn.k_proj.S_residual: True
# [10:30:06.750670] encoder.layers.5.self_attn.k_proj.U_residual: True
# [10:30:06.750767] encoder.layers.5.self_attn.k_proj.V_residual: True
# [10:30:06.750869] encoder.layers.5.self_attn.v_proj.weight_main: False
# [10:30:06.750964] encoder.layers.5.self_attn.v_proj.bias: False
# [10:30:06.751062] encoder.layers.5.self_attn.v_proj.S_residual: True
# [10:30:06.751159] encoder.layers.5.self_attn.v_proj.U_residual: True
# [10:30:06.751264] encoder.layers.5.self_attn.v_proj.V_residual: True
# [10:30:06.751364] encoder.layers.5.self_attn.q_proj.weight_main: False
# [10:30:06.751472] encoder.layers.5.self_attn.q_proj.bias: False
# [10:30:06.751572] encoder.layers.5.self_attn.q_proj.S_residual: True
# [10:30:06.751669] encoder.layers.5.self_attn.q_proj.U_residual: True
# [10:30:06.751767] encoder.layers.5.self_attn.q_proj.V_residual: True
# [10:30:06.751868] encoder.layers.5.self_attn.out_proj.weight_main: False
# [10:30:06.751965] encoder.layers.5.self_attn.out_proj.bias: False
# [10:30:06.752063] encoder.layers.5.self_attn.out_proj.S_residual: True
# [10:30:06.752164] encoder.layers.5.self_attn.out_proj.U_residual: True
# [10:30:06.752270] encoder.layers.5.self_attn.out_proj.V_residual: True
# [10:30:06.752373] encoder.layers.5.layer_norm1.weight: False
# [10:30:06.752467] encoder.layers.5.layer_norm1.bias: False
# [10:30:06.752579] encoder.layers.5.mlp.fc1.weight: False
# [10:30:06.752672] encoder.layers.5.mlp.fc1.bias: False
# [10:30:06.752773] encoder.layers.5.mlp.fc2.weight: False
# [10:30:06.752870] encoder.layers.5.mlp.fc2.bias: False
# [10:30:06.752969] encoder.layers.5.layer_norm2.weight: False
# [10:30:06.753065] encoder.layers.5.layer_norm2.bias: False
# [10:30:06.753174] encoder.layers.6.self_attn.k_proj.weight_main: False
# [10:30:06.753275] encoder.layers.6.self_attn.k_proj.bias: False
# [10:30:06.753372] encoder.layers.6.self_attn.k_proj.S_residual: True
# [10:30:06.753468] encoder.layers.6.self_attn.k_proj.U_residual: True
# [10:30:06.753569] encoder.layers.6.self_attn.k_proj.V_residual: True
# [10:30:06.753671] encoder.layers.6.self_attn.v_proj.weight_main: False
# [10:30:06.753768] encoder.layers.6.self_attn.v_proj.bias: False
# [10:30:06.753866] encoder.layers.6.self_attn.v_proj.S_residual: True
# [10:30:06.753960] encoder.layers.6.self_attn.v_proj.U_residual: True
# [10:30:06.754058] encoder.layers.6.self_attn.v_proj.V_residual: True
# [10:30:06.754163] encoder.layers.6.self_attn.q_proj.weight_main: False
# [10:30:06.754263] encoder.layers.6.self_attn.q_proj.bias: False
# [10:30:06.754361] encoder.layers.6.self_attn.q_proj.S_residual: True
# [10:30:06.754458] encoder.layers.6.self_attn.q_proj.U_residual: True
# [10:30:06.754555] encoder.layers.6.self_attn.q_proj.V_residual: True
# [10:30:06.754656] encoder.layers.6.self_attn.out_proj.weight_main: False
# [10:30:06.754751] encoder.layers.6.self_attn.out_proj.bias: False
# [10:30:06.754848] encoder.layers.6.self_attn.out_proj.S_residual: True
# [10:30:06.754963] encoder.layers.6.self_attn.out_proj.U_residual: True
# [10:30:06.755061] encoder.layers.6.self_attn.out_proj.V_residual: True
# [10:30:06.755163] encoder.layers.6.layer_norm1.weight: False
# [10:30:06.755265] encoder.layers.6.layer_norm1.bias: False
# [10:30:06.755371] encoder.layers.6.mlp.fc1.weight: False
# [10:30:06.755464] encoder.layers.6.mlp.fc1.bias: False
# [10:30:06.755566] encoder.layers.6.mlp.fc2.weight: False
# [10:30:06.755662] encoder.layers.6.mlp.fc2.bias: False
# [10:30:06.755764] encoder.layers.6.layer_norm2.weight: False
# [10:30:06.755867] encoder.layers.6.layer_norm2.bias: False
# [10:30:06.755973] encoder.layers.7.self_attn.k_proj.weight_main: False
# [10:30:06.756072] encoder.layers.7.self_attn.k_proj.bias: False
# [10:30:06.756169] encoder.layers.7.self_attn.k_proj.S_residual: True
# [10:30:06.756272] encoder.layers.7.self_attn.k_proj.U_residual: True
# [10:30:06.756370] encoder.layers.7.self_attn.k_proj.V_residual: True
# [10:30:06.756472] encoder.layers.7.self_attn.v_proj.weight_main: False
# [10:30:06.756569] encoder.layers.7.self_attn.v_proj.bias: False
# [10:30:06.756679] encoder.layers.7.self_attn.v_proj.S_residual: True
# [10:30:06.756776] encoder.layers.7.self_attn.v_proj.U_residual: True
# [10:30:06.756874] encoder.layers.7.self_attn.v_proj.V_residual: True
# [10:30:06.756973] encoder.layers.7.self_attn.q_proj.weight_main: False
# [10:30:06.757070] encoder.layers.7.self_attn.q_proj.bias: False
# [10:30:06.757167] encoder.layers.7.self_attn.q_proj.S_residual: True
# [10:30:06.757357] encoder.layers.7.self_attn.q_proj.U_residual: True
# [10:30:06.757455] encoder.layers.7.self_attn.q_proj.V_residual: True
# [10:30:06.757561] encoder.layers.7.self_attn.out_proj.weight_main: False
# [10:30:06.757658] encoder.layers.7.self_attn.out_proj.bias: False
# [10:30:06.757757] encoder.layers.7.self_attn.out_proj.S_residual: True
# [10:30:06.757854] encoder.layers.7.self_attn.out_proj.U_residual: True
# [10:30:06.757975] encoder.layers.7.self_attn.out_proj.V_residual: True
# [10:30:06.758082] encoder.layers.7.layer_norm1.weight: False
# [10:30:06.758179] encoder.layers.7.layer_norm1.bias: False
# [10:30:06.758295] encoder.layers.7.mlp.fc1.weight: False
# [10:30:06.758389] encoder.layers.7.mlp.fc1.bias: False
# [10:30:06.758494] encoder.layers.7.mlp.fc2.weight: False
# [10:30:06.758588] encoder.layers.7.mlp.fc2.bias: False
# [10:30:06.758690] encoder.layers.7.layer_norm2.weight: False
# [10:30:06.758785] encoder.layers.7.layer_norm2.bias: False
# [10:30:06.758895] encoder.layers.8.self_attn.k_proj.weight_main: False
# [10:30:06.759014] encoder.layers.8.self_attn.k_proj.bias: False
# [10:30:06.759112] encoder.layers.8.self_attn.k_proj.S_residual: True
# [10:30:06.759213] encoder.layers.8.self_attn.k_proj.U_residual: True
# [10:30:06.759316] encoder.layers.8.self_attn.k_proj.V_residual: True
# [10:30:06.759417] encoder.layers.8.self_attn.v_proj.weight_main: False
# [10:30:06.759515] encoder.layers.8.self_attn.v_proj.bias: False
# [10:30:06.759614] encoder.layers.8.self_attn.v_proj.S_residual: True
# [10:30:06.759711] encoder.layers.8.self_attn.v_proj.U_residual: True
# [10:30:06.759808] encoder.layers.8.self_attn.v_proj.V_residual: True
# [10:30:06.759929] encoder.layers.8.self_attn.q_proj.weight_main: False
# [10:30:06.760029] encoder.layers.8.self_attn.q_proj.bias: False
# [10:30:06.760128] encoder.layers.8.self_attn.q_proj.S_residual: True
# [10:30:06.760239] encoder.layers.8.self_attn.q_proj.U_residual: True
# [10:30:06.760333] encoder.layers.8.self_attn.q_proj.V_residual: True
# [10:30:06.760435] encoder.layers.8.self_attn.out_proj.weight_main: False
# [10:30:06.760533] encoder.layers.8.self_attn.out_proj.bias: False
# [10:30:06.760632] encoder.layers.8.self_attn.out_proj.S_residual: True
# [10:30:06.760730] encoder.layers.8.self_attn.out_proj.U_residual: True
# [10:30:06.760828] encoder.layers.8.self_attn.out_proj.V_residual: True
# [10:30:06.760944] encoder.layers.8.layer_norm1.weight: False
# [10:30:06.761044] encoder.layers.8.layer_norm1.bias: False
# [10:30:06.761152] encoder.layers.8.mlp.fc1.weight: False
# [10:30:06.761253] encoder.layers.8.mlp.fc1.bias: False
# [10:30:06.761353] encoder.layers.8.mlp.fc2.weight: False
# [10:30:06.761450] encoder.layers.8.mlp.fc2.bias: False
# [10:30:06.761551] encoder.layers.8.layer_norm2.weight: False
# [10:30:06.761648] encoder.layers.8.layer_norm2.bias: False
# [10:30:06.761766] encoder.layers.9.self_attn.k_proj.weight_main: False
# [10:30:06.761859] encoder.layers.9.self_attn.k_proj.bias: False
# [10:30:06.761961] encoder.layers.9.self_attn.k_proj.S_residual: True
# [10:30:06.762059] encoder.layers.9.self_attn.k_proj.U_residual: True
# [10:30:06.762158] encoder.layers.9.self_attn.k_proj.V_residual: True
# [10:30:06.762267] encoder.layers.9.self_attn.v_proj.weight_main: False
# [10:30:06.762365] encoder.layers.9.self_attn.v_proj.bias: False
# [10:30:06.762463] encoder.layers.9.self_attn.v_proj.S_residual: True
# [10:30:06.762562] encoder.layers.9.self_attn.v_proj.U_residual: True
# [10:30:06.762659] encoder.layers.9.self_attn.v_proj.V_residual: True
# [10:30:06.762761] encoder.layers.9.self_attn.q_proj.weight_main: False
# [10:30:06.762858] encoder.layers.9.self_attn.q_proj.bias: False
# [10:30:06.762960] encoder.layers.9.self_attn.q_proj.S_residual: True
# [10:30:06.763062] encoder.layers.9.self_attn.q_proj.U_residual: True
# [10:30:06.763158] encoder.layers.9.self_attn.q_proj.V_residual: True
# [10:30:06.763266] encoder.layers.9.self_attn.out_proj.weight_main: False
# [10:30:06.763360] encoder.layers.9.self_attn.out_proj.bias: False
# [10:30:06.763459] encoder.layers.9.self_attn.out_proj.S_residual: True
# [10:30:06.763556] encoder.layers.9.self_attn.out_proj.U_residual: True
# [10:30:06.763654] encoder.layers.9.self_attn.out_proj.V_residual: True
# [10:30:06.763760] encoder.layers.9.layer_norm1.weight: False
# [10:30:06.763857] encoder.layers.9.layer_norm1.bias: False
# [10:30:06.763970] encoder.layers.9.mlp.fc1.weight: False
# [10:30:06.764065] encoder.layers.9.mlp.fc1.bias: False
# [10:30:06.764164] encoder.layers.9.mlp.fc2.weight: False
# [10:30:06.764265] encoder.layers.9.mlp.fc2.bias: False
# [10:30:06.764367] encoder.layers.9.layer_norm2.weight: False
# [10:30:06.764463] encoder.layers.9.layer_norm2.bias: False
# [10:30:06.764572] encoder.layers.10.self_attn.k_proj.weight_main: False
# [10:30:06.764667] encoder.layers.10.self_attn.k_proj.bias: False
# [10:30:06.764765] encoder.layers.10.self_attn.k_proj.S_residual: True
# [10:30:06.836007] encoder.layers.10.self_attn.k_proj.U_residual: True
# [10:30:06.836129] encoder.layers.10.self_attn.k_proj.V_residual: True
# [10:30:06.836253] encoder.layers.10.self_attn.v_proj.weight_main: False
# [10:30:06.836370] encoder.layers.10.self_attn.v_proj.bias: False
# [10:30:06.836479] encoder.layers.10.self_attn.v_proj.S_residual: True
# [10:30:06.836569] encoder.layers.10.self_attn.v_proj.U_residual: True
# [10:30:06.836649] encoder.layers.10.self_attn.v_proj.V_residual: True
# [10:30:06.836739] encoder.layers.10.self_attn.q_proj.weight_main: False
# [10:30:06.836853] encoder.layers.10.self_attn.q_proj.bias: False
# [10:30:06.836956] encoder.layers.10.self_attn.q_proj.S_residual: True
# [10:30:06.837046] encoder.layers.10.self_attn.q_proj.U_residual: True
# [10:30:06.837141] encoder.layers.10.self_attn.q_proj.V_residual: True
# [10:30:06.837251] encoder.layers.10.self_attn.out_proj.weight_main: False
# [10:30:06.837348] encoder.layers.10.self_attn.out_proj.bias: False
# [10:30:06.837447] encoder.layers.10.self_attn.out_proj.S_residual: True
# [10:30:06.837545] encoder.layers.10.self_attn.out_proj.U_residual: True
# [10:30:06.837645] encoder.layers.10.self_attn.out_proj.V_residual: True
# [10:30:06.837750] encoder.layers.10.layer_norm1.weight: False
# [10:30:06.837859] encoder.layers.10.layer_norm1.bias: False
# [10:30:06.837994] encoder.layers.10.mlp.fc1.weight: False
# [10:30:06.838090] encoder.layers.10.mlp.fc1.bias: False
# [10:30:06.838191] encoder.layers.10.mlp.fc2.weight: False
# [10:30:06.838291] encoder.layers.10.mlp.fc2.bias: False
# [10:30:06.838393] encoder.layers.10.layer_norm2.weight: False
# [10:30:06.838491] encoder.layers.10.layer_norm2.bias: False
# [10:30:06.838603] encoder.layers.11.self_attn.k_proj.weight_main: False
# [10:30:06.838697] encoder.layers.11.self_attn.k_proj.bias: False
# [10:30:06.838794] encoder.layers.11.self_attn.k_proj.S_residual: True
# [10:30:06.838893] encoder.layers.11.self_attn.k_proj.U_residual: True
# [10:30:06.839010] encoder.layers.11.self_attn.k_proj.V_residual: True
# [10:30:06.839111] encoder.layers.11.self_attn.v_proj.weight_main: False
# [10:30:06.839208] encoder.layers.11.self_attn.v_proj.bias: False
# [10:30:06.839310] encoder.layers.11.self_attn.v_proj.S_residual: True
# [10:30:06.839408] encoder.layers.11.self_attn.v_proj.U_residual: True
# [10:30:06.839510] encoder.layers.11.self_attn.v_proj.V_residual: True
# [10:30:06.839625] encoder.layers.11.self_attn.q_proj.weight_main: False
# [10:30:06.839724] encoder.layers.11.self_attn.q_proj.bias: False
# [10:30:06.839822] encoder.layers.11.self_attn.q_proj.S_residual: True
# [10:30:06.839930] encoder.layers.11.self_attn.q_proj.U_residual: True
# [10:30:06.840028] encoder.layers.11.self_attn.q_proj.V_residual: True
# [10:30:06.840132] encoder.layers.11.self_attn.out_proj.weight_main: False
# [10:30:06.840242] encoder.layers.11.self_attn.out_proj.bias: False
# [10:30:06.840337] encoder.layers.11.self_attn.out_proj.S_residual: True
# [10:30:06.840436] encoder.layers.11.self_attn.out_proj.U_residual: True
# [10:30:06.840535] encoder.layers.11.self_attn.out_proj.V_residual: True
# [10:30:06.840639] encoder.layers.11.layer_norm1.weight: False
# [10:30:06.840740] encoder.layers.11.layer_norm1.bias: False
# [10:30:06.840849] encoder.layers.11.mlp.fc1.weight: False
# [10:30:06.840965] encoder.layers.11.mlp.fc1.bias: False
# [10:30:06.841069] encoder.layers.11.mlp.fc2.weight: False
# [10:30:06.841167] encoder.layers.11.mlp.fc2.bias: False
# [10:30:06.841273] encoder.layers.11.layer_norm2.weight: False
# [10:30:06.841370] encoder.layers.11.layer_norm2.bias: False
# [10:30:06.841480] encoder.layers.12.self_attn.k_proj.weight_main: False
# [10:30:06.841576] encoder.layers.12.self_attn.k_proj.bias: False
# [10:30:06.841675] encoder.layers.12.self_attn.k_proj.S_residual: True
# [10:30:06.841774] encoder.layers.12.self_attn.k_proj.U_residual: True
# [10:30:06.841871] encoder.layers.12.self_attn.k_proj.V_residual: True
# [10:30:06.841972] encoder.layers.12.self_attn.v_proj.weight_main: False
# [10:30:06.842069] encoder.layers.12.self_attn.v_proj.bias: False
# [10:30:06.842168] encoder.layers.12.self_attn.v_proj.S_residual: True
# [10:30:06.842271] encoder.layers.12.self_attn.v_proj.U_residual: True
# [10:30:06.842369] encoder.layers.12.self_attn.v_proj.V_residual: True
# [10:30:06.842480] encoder.layers.12.self_attn.q_proj.weight_main: False
# [10:30:06.842578] encoder.layers.12.self_attn.q_proj.bias: False
# [10:30:06.842678] encoder.layers.12.self_attn.q_proj.S_residual: True
# [10:30:06.842781] encoder.layers.12.self_attn.q_proj.U_residual: True
# [10:30:06.842879] encoder.layers.12.self_attn.q_proj.V_residual: True
# [10:30:06.842980] encoder.layers.12.self_attn.out_proj.weight_main: False
# [10:30:06.843087] encoder.layers.12.self_attn.out_proj.bias: False
# [10:30:06.843184] encoder.layers.12.self_attn.out_proj.S_residual: True
# [10:30:06.843284] encoder.layers.12.self_attn.out_proj.U_residual: True
# [10:30:06.843391] encoder.layers.12.self_attn.out_proj.V_residual: True
# [10:30:06.843493] encoder.layers.12.layer_norm1.weight: False
# [10:30:06.843589] encoder.layers.12.layer_norm1.bias: False
# [10:30:06.843698] encoder.layers.12.mlp.fc1.weight: False
# [10:30:06.843794] encoder.layers.12.mlp.fc1.bias: False
# [10:30:06.843896] encoder.layers.12.mlp.fc2.weight: False
# [10:30:06.844012] encoder.layers.12.mlp.fc2.bias: False
# [10:30:06.844114] encoder.layers.12.layer_norm2.weight: False
# [10:30:06.844211] encoder.layers.12.layer_norm2.bias: False
# [10:30:06.844331] encoder.layers.13.self_attn.k_proj.weight_main: False
# [10:30:06.844426] encoder.layers.13.self_attn.k_proj.bias: False
# [10:30:06.844526] encoder.layers.13.self_attn.k_proj.S_residual: True
# [10:30:06.844624] encoder.layers.13.self_attn.k_proj.U_residual: True
# [10:30:06.844722] encoder.layers.13.self_attn.k_proj.V_residual: True
# [10:30:06.844825] encoder.layers.13.self_attn.v_proj.weight_main: False
# [10:30:06.844934] encoder.layers.13.self_attn.v_proj.bias: False
# [10:30:06.845030] encoder.layers.13.self_attn.v_proj.S_residual: True
# [10:30:06.845128] encoder.layers.13.self_attn.v_proj.U_residual: True
# [10:30:06.845230] encoder.layers.13.self_attn.v_proj.V_residual: True
# [10:30:06.845331] encoder.layers.13.self_attn.q_proj.weight_main: False
# [10:30:06.845429] encoder.layers.13.self_attn.q_proj.bias: False
# [10:30:06.845530] encoder.layers.13.self_attn.q_proj.S_residual: True
# [10:30:06.845628] encoder.layers.13.self_attn.q_proj.U_residual: True
# [10:30:06.845734] encoder.layers.13.self_attn.q_proj.V_residual: True
# [10:30:06.845836] encoder.layers.13.self_attn.out_proj.weight_main: False
# [10:30:06.845945] encoder.layers.13.self_attn.out_proj.bias: False
# [10:30:06.846044] encoder.layers.13.self_attn.out_proj.S_residual: True
# [10:30:06.846142] encoder.layers.13.self_attn.out_proj.U_residual: True
# [10:30:06.846246] encoder.layers.13.self_attn.out_proj.V_residual: True
# [10:30:06.846348] encoder.layers.13.layer_norm1.weight: False
# [10:30:06.846445] encoder.layers.13.layer_norm1.bias: False
# [10:30:06.846554] encoder.layers.13.mlp.fc1.weight: False
# [10:30:06.846651] encoder.layers.13.mlp.fc1.bias: False
# [10:30:06.846753] encoder.layers.13.mlp.fc2.weight: False
# [10:30:06.846850] encoder.layers.13.mlp.fc2.bias: False
# [10:30:06.846972] encoder.layers.13.layer_norm2.weight: False
# [10:30:06.847070] encoder.layers.13.layer_norm2.bias: False
# [10:30:06.847180] encoder.layers.14.self_attn.k_proj.weight_main: False
# [10:30:06.847281] encoder.layers.14.self_attn.k_proj.bias: False
# [10:30:06.847389] encoder.layers.14.self_attn.k_proj.S_residual: True
# [10:30:06.847486] encoder.layers.14.self_attn.k_proj.U_residual: True
# [10:30:06.847585] encoder.layers.14.self_attn.k_proj.V_residual: True
# [10:30:06.847688] encoder.layers.14.self_attn.v_proj.weight_main: False
# [10:30:06.847785] encoder.layers.14.self_attn.v_proj.bias: False
# [10:30:06.847883] encoder.layers.14.self_attn.v_proj.S_residual: True
# [10:30:06.847980] encoder.layers.14.self_attn.v_proj.U_residual: True
# [10:30:06.848078] encoder.layers.14.self_attn.v_proj.V_residual: True
# [10:30:06.848181] encoder.layers.14.self_attn.q_proj.weight_main: False
# [10:30:06.848294] encoder.layers.14.self_attn.q_proj.bias: False
# [10:30:06.848391] encoder.layers.14.self_attn.q_proj.S_residual: True
# [10:30:06.848490] encoder.layers.14.self_attn.q_proj.U_residual: True
# [10:30:06.848589] encoder.layers.14.self_attn.q_proj.V_residual: True
# [10:30:06.848691] encoder.layers.14.self_attn.out_proj.weight_main: False
# [10:30:06.848787] encoder.layers.14.self_attn.out_proj.bias: False
# [10:30:06.848885] encoder.layers.14.self_attn.out_proj.S_residual: True
# [10:30:06.848981] encoder.layers.14.self_attn.out_proj.U_residual: True
# [10:30:06.849079] encoder.layers.14.self_attn.out_proj.V_residual: True
# [10:30:06.849182] encoder.layers.14.layer_norm1.weight: False
# [10:30:06.849284] encoder.layers.14.layer_norm1.bias: False
# [10:30:06.849395] encoder.layers.14.mlp.fc1.weight: False
# [10:30:06.849490] encoder.layers.14.mlp.fc1.bias: False
# [10:30:06.849594] encoder.layers.14.mlp.fc2.weight: False
# [10:30:06.849691] encoder.layers.14.mlp.fc2.bias: False
# [10:30:06.849794] encoder.layers.14.layer_norm2.weight: False
# [10:30:06.849890] encoder.layers.14.layer_norm2.bias: False
# [10:30:06.850003] encoder.layers.15.self_attn.k_proj.weight_main: False
# [10:30:06.850102] encoder.layers.15.self_attn.k_proj.bias: False
# [10:30:06.850200] encoder.layers.15.self_attn.k_proj.S_residual: True
# [10:30:06.850288] encoder.layers.15.self_attn.k_proj.U_residual: True
# [10:30:06.850386] encoder.layers.15.self_attn.k_proj.V_residual: True
# [10:30:06.850489] encoder.layers.15.self_attn.v_proj.weight_main: False
# [10:30:06.850586] encoder.layers.15.self_attn.v_proj.bias: False
# [10:30:06.850684] encoder.layers.15.self_attn.v_proj.S_residual: True
# [10:30:06.850782] encoder.layers.15.self_attn.v_proj.U_residual: True
# [10:30:06.850879] encoder.layers.15.self_attn.v_proj.V_residual: True
# [10:30:06.850980] encoder.layers.15.self_attn.q_proj.weight_main: False
# [10:30:06.851082] encoder.layers.15.self_attn.q_proj.bias: False
# [10:30:06.851185] encoder.layers.15.self_attn.q_proj.S_residual: True
# [10:30:06.851288] encoder.layers.15.self_attn.q_proj.U_residual: True
# [10:30:06.851368] encoder.layers.15.self_attn.q_proj.V_residual: True
# [10:30:06.851466] encoder.layers.15.self_attn.out_proj.weight_main: False
# [10:30:06.851571] encoder.layers.15.self_attn.out_proj.bias: False
# [10:30:06.851674] encoder.layers.15.self_attn.out_proj.S_residual: True
# [10:30:06.851771] encoder.layers.15.self_attn.out_proj.U_residual: True
# [10:30:06.851870] encoder.layers.15.self_attn.out_proj.V_residual: True
# [10:30:06.851973] encoder.layers.15.layer_norm1.weight: False
# [10:30:06.852069] encoder.layers.15.layer_norm1.bias: False
# [10:30:06.852179] encoder.layers.15.mlp.fc1.weight: False
# [10:30:06.852281] encoder.layers.15.mlp.fc1.bias: False
# [10:30:06.852384] encoder.layers.15.mlp.fc2.weight: False
# [10:30:06.852480] encoder.layers.15.mlp.fc2.bias: False
# [10:30:06.852582] encoder.layers.15.layer_norm2.weight: False
# [10:30:06.852686] encoder.layers.15.layer_norm2.bias: False
# [10:30:06.852796] encoder.layers.16.self_attn.k_proj.weight_main: False
# [10:30:06.852889] encoder.layers.16.self_attn.k_proj.bias: False
# [10:30:06.852991] encoder.layers.16.self_attn.k_proj.S_residual: True
# [10:30:06.853094] encoder.layers.16.self_attn.k_proj.U_residual: True
# [10:30:06.853191] encoder.layers.16.self_attn.k_proj.V_residual: True
# [10:30:06.853298] encoder.layers.16.self_attn.v_proj.weight_main: False
# [10:30:06.853394] encoder.layers.16.self_attn.v_proj.bias: False
# [10:30:06.853493] encoder.layers.16.self_attn.v_proj.S_residual: True
# [10:30:06.853593] encoder.layers.16.self_attn.v_proj.U_residual: True
# [10:30:06.853690] encoder.layers.16.self_attn.v_proj.V_residual: True
# [10:30:06.853793] encoder.layers.16.self_attn.q_proj.weight_main: False
# [10:30:06.853889] encoder.layers.16.self_attn.q_proj.bias: False
# [10:30:06.853990] encoder.layers.16.self_attn.q_proj.S_residual: True
# [10:30:06.854094] encoder.layers.16.self_attn.q_proj.U_residual: True
# [10:30:06.854191] encoder.layers.16.self_attn.q_proj.V_residual: True
# [10:30:06.854297] encoder.layers.16.self_attn.out_proj.weight_main: False
# [10:30:06.854395] encoder.layers.16.self_attn.out_proj.bias: False
# [10:30:06.854492] encoder.layers.16.self_attn.out_proj.S_residual: True
# [10:30:06.854591] encoder.layers.16.self_attn.out_proj.U_residual: True
# [10:30:06.854688] encoder.layers.16.self_attn.out_proj.V_residual: True
# [10:30:06.854791] encoder.layers.16.layer_norm1.weight: False
# [10:30:06.854890] encoder.layers.16.layer_norm1.bias: False
# [10:30:06.855002] encoder.layers.16.mlp.fc1.weight: False
# [10:30:06.855102] encoder.layers.16.mlp.fc1.bias: False
# [10:30:06.855204] encoder.layers.16.mlp.fc2.weight: False
# [10:30:06.855304] encoder.layers.16.mlp.fc2.bias: False
# [10:30:06.855407] encoder.layers.16.layer_norm2.weight: False
# [10:30:06.855507] encoder.layers.16.layer_norm2.bias: False
# [10:30:06.855617] encoder.layers.17.self_attn.k_proj.weight_main: False
# [10:30:06.855711] encoder.layers.17.self_attn.k_proj.bias: False
# [10:30:06.855809] encoder.layers.17.self_attn.k_proj.S_residual: True
# [10:30:06.855937] encoder.layers.17.self_attn.k_proj.U_residual: True
# [10:30:06.856033] encoder.layers.17.self_attn.k_proj.V_residual: True
# [10:30:06.856137] encoder.layers.17.self_attn.v_proj.weight_main: False
# [10:30:06.856241] encoder.layers.17.self_attn.v_proj.bias: False
# [10:30:06.856336] encoder.layers.17.self_attn.v_proj.S_residual: True
# [10:30:06.856433] encoder.layers.17.self_attn.v_proj.U_residual: True
# [10:30:06.856533] encoder.layers.17.self_attn.v_proj.V_residual: True
# [10:30:06.856635] encoder.layers.17.self_attn.q_proj.weight_main: False
# [10:30:06.856731] encoder.layers.17.self_attn.q_proj.bias: False
# [10:30:06.856828] encoder.layers.17.self_attn.q_proj.S_residual: True
# [10:30:06.856938] encoder.layers.17.self_attn.q_proj.U_residual: True
# [10:30:06.857043] encoder.layers.17.self_attn.q_proj.V_residual: True
# [10:30:06.857147] encoder.layers.17.self_attn.out_proj.weight_main: False
# [10:30:06.857250] encoder.layers.17.self_attn.out_proj.bias: False
# [10:30:06.857347] encoder.layers.17.self_attn.out_proj.S_residual: True
# [10:30:06.857438] encoder.layers.17.self_attn.out_proj.U_residual: True
# [10:30:06.857540] encoder.layers.17.self_attn.out_proj.V_residual: True
# [10:30:06.857644] encoder.layers.17.layer_norm1.weight: False
# [10:30:06.857740] encoder.layers.17.layer_norm1.bias: False
# [10:30:06.857857] encoder.layers.17.mlp.fc1.weight: False
# [10:30:06.857979] encoder.layers.17.mlp.fc1.bias: False
# [10:30:06.858083] encoder.layers.17.mlp.fc2.weight: False
# [10:30:06.858179] encoder.layers.17.mlp.fc2.bias: False
# [10:30:06.858286] encoder.layers.17.layer_norm2.weight: False
# [10:30:06.858384] encoder.layers.17.layer_norm2.bias: False
# [10:30:06.858492] encoder.layers.18.self_attn.k_proj.weight_main: False
# [10:30:06.858589] encoder.layers.18.self_attn.k_proj.bias: False
# [10:30:06.858687] encoder.layers.18.self_attn.k_proj.S_residual: True
# [10:30:06.858785] encoder.layers.18.self_attn.k_proj.U_residual: True
# [10:30:06.858884] encoder.layers.18.self_attn.k_proj.V_residual: True
# [10:30:06.858986] encoder.layers.18.self_attn.v_proj.weight_main: False
# [10:30:06.859089] encoder.layers.18.self_attn.v_proj.bias: False
# [10:30:06.859185] encoder.layers.18.self_attn.v_proj.S_residual: True
# [10:30:06.859286] encoder.layers.18.self_attn.v_proj.U_residual: True
# [10:30:06.859384] encoder.layers.18.self_attn.v_proj.V_residual: True
# [10:30:06.859487] encoder.layers.18.self_attn.q_proj.weight_main: False
# [10:30:06.859584] encoder.layers.18.self_attn.q_proj.bias: False
# [10:30:06.859683] encoder.layers.18.self_attn.q_proj.S_residual: True
# [10:30:06.859780] encoder.layers.18.self_attn.q_proj.U_residual: True
# [10:30:06.859877] encoder.layers.18.self_attn.q_proj.V_residual: True
# [10:30:06.859980] encoder.layers.18.self_attn.out_proj.weight_main: False
# [10:30:06.860077] encoder.layers.18.self_attn.out_proj.bias: False
# [10:30:06.860174] encoder.layers.18.self_attn.out_proj.S_residual: True
# [10:30:06.860291] encoder.layers.18.self_attn.out_proj.U_residual: True
# [10:30:06.860389] encoder.layers.18.self_attn.out_proj.V_residual: True
# [10:30:06.860494] encoder.layers.18.layer_norm1.weight: False
# [10:30:06.860590] encoder.layers.18.layer_norm1.bias: False
# [10:30:06.860699] encoder.layers.18.mlp.fc1.weight: False
# [10:30:06.860794] encoder.layers.18.mlp.fc1.bias: False
# [10:30:06.860896] encoder.layers.18.mlp.fc2.weight: False
# [10:30:06.861014] encoder.layers.18.mlp.fc2.bias: False
# [10:30:06.861118] encoder.layers.18.layer_norm2.weight: False
# [10:30:06.861205] encoder.layers.18.layer_norm2.bias: False
# [10:30:06.861320] encoder.layers.19.self_attn.k_proj.weight_main: False
# [10:30:06.861416] encoder.layers.19.self_attn.k_proj.bias: False
# [10:30:06.861515] encoder.layers.19.self_attn.k_proj.S_residual: True
# [10:30:06.861613] encoder.layers.19.self_attn.k_proj.U_residual: True
# [10:30:06.861710] encoder.layers.19.self_attn.k_proj.V_residual: True
# [10:30:06.861812] encoder.layers.19.self_attn.v_proj.weight_main: False
# [10:30:06.861919] encoder.layers.19.self_attn.v_proj.bias: False
# [10:30:06.862022] encoder.layers.19.self_attn.v_proj.S_residual: True
# [10:30:06.862120] encoder.layers.19.self_attn.v_proj.U_residual: True
# [10:30:06.862218] encoder.layers.19.self_attn.v_proj.V_residual: True
# [10:30:06.862325] encoder.layers.19.self_attn.q_proj.weight_main: False
# [10:30:06.862423] encoder.layers.19.self_attn.q_proj.bias: False
# [10:30:06.862524] encoder.layers.19.self_attn.q_proj.S_residual: True
# [10:30:06.862622] encoder.layers.19.self_attn.q_proj.U_residual: True
# [10:30:06.862718] encoder.layers.19.self_attn.q_proj.V_residual: True
# [10:30:06.862820] encoder.layers.19.self_attn.out_proj.weight_main: False
# [10:30:06.862929] encoder.layers.19.self_attn.out_proj.bias: False
# [10:30:06.863028] encoder.layers.19.self_attn.out_proj.S_residual: True
# [10:30:06.863126] encoder.layers.19.self_attn.out_proj.U_residual: True
# [10:30:06.863228] encoder.layers.19.self_attn.out_proj.V_residual: True
# [10:30:06.863330] encoder.layers.19.layer_norm1.weight: False
# [10:30:06.863426] encoder.layers.19.layer_norm1.bias: False
# [10:30:06.863537] encoder.layers.19.mlp.fc1.weight: False
# [10:30:06.863632] encoder.layers.19.mlp.fc1.bias: False
# [10:30:06.863736] encoder.layers.19.mlp.fc2.weight: False
# [10:30:06.863833] encoder.layers.19.mlp.fc2.bias: False
# [10:30:06.863949] encoder.layers.19.layer_norm2.weight: False
# [10:30:06.864049] encoder.layers.19.layer_norm2.bias: False
# [10:30:06.864159] encoder.layers.20.self_attn.k_proj.weight_main: False
# [10:30:06.864260] encoder.layers.20.self_attn.k_proj.bias: False
# [10:30:06.864356] encoder.layers.20.self_attn.k_proj.S_residual: True
# [10:30:06.864454] encoder.layers.20.self_attn.k_proj.U_residual: True
# [10:30:06.864553] encoder.layers.20.self_attn.k_proj.V_residual: True
# [10:30:06.864655] encoder.layers.20.self_attn.v_proj.weight_main: False
# [10:30:06.864751] encoder.layers.20.self_attn.v_proj.bias: False
# [10:30:06.864850] encoder.layers.20.self_attn.v_proj.S_residual: True
# [10:30:06.864968] encoder.layers.20.self_attn.v_proj.U_residual: True
# [10:30:06.865066] encoder.layers.20.self_attn.v_proj.V_residual: True
# [10:30:06.865175] encoder.layers.20.self_attn.q_proj.weight_main: False
# [10:30:06.865282] encoder.layers.20.self_attn.q_proj.bias: False
# [10:30:06.865379] encoder.layers.20.self_attn.q_proj.S_residual: True
# [10:30:06.936753] encoder.layers.20.self_attn.q_proj.U_residual: True
# [10:30:06.936918] encoder.layers.20.self_attn.q_proj.V_residual: True
# [10:30:06.937039] encoder.layers.20.self_attn.out_proj.weight_main: False
# [10:30:06.937150] encoder.layers.20.self_attn.out_proj.bias: False
# [10:30:06.937273] encoder.layers.20.self_attn.out_proj.S_residual: True
# [10:30:06.937372] encoder.layers.20.self_attn.out_proj.U_residual: True
# [10:30:06.937455] encoder.layers.20.self_attn.out_proj.V_residual: True
# [10:30:06.937555] encoder.layers.20.layer_norm1.weight: False
# [10:30:06.937651] encoder.layers.20.layer_norm1.bias: False
# [10:30:06.937769] encoder.layers.20.mlp.fc1.weight: False
# [10:30:06.937863] encoder.layers.20.mlp.fc1.bias: False
# [10:30:06.937969] encoder.layers.20.mlp.fc2.weight: False
# [10:30:06.938056] encoder.layers.20.mlp.fc2.bias: False
# [10:30:06.938161] encoder.layers.20.layer_norm2.weight: False
# [10:30:06.938267] encoder.layers.20.layer_norm2.bias: False
# [10:30:06.938377] encoder.layers.21.self_attn.k_proj.weight_main: False
# [10:30:06.938473] encoder.layers.21.self_attn.k_proj.bias: False
# [10:30:06.938573] encoder.layers.21.self_attn.k_proj.S_residual: True
# [10:30:06.938673] encoder.layers.21.self_attn.k_proj.U_residual: True
# [10:30:06.938771] encoder.layers.21.self_attn.k_proj.V_residual: True
# [10:30:06.938873] encoder.layers.21.self_attn.v_proj.weight_main: False
# [10:30:06.938971] encoder.layers.21.self_attn.v_proj.bias: False
# [10:30:06.939069] encoder.layers.21.self_attn.v_proj.S_residual: True
# [10:30:06.939167] encoder.layers.21.self_attn.v_proj.U_residual: True
# [10:30:06.939270] encoder.layers.21.self_attn.v_proj.V_residual: True
# [10:30:06.939372] encoder.layers.21.self_attn.q_proj.weight_main: False
# [10:30:06.939470] encoder.layers.21.self_attn.q_proj.bias: False
# [10:30:06.939568] encoder.layers.21.self_attn.q_proj.S_residual: True
# [10:30:06.939666] encoder.layers.21.self_attn.q_proj.U_residual: True
# ...
# [10:55:02.742328] Best image-level F1 image-level AUC = 0.6236284905009799
# [10:55:10.628128] Auto Mixed Precision (AMP) is enabled.
# [10:55:10.628593] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [10:55:15.785681] Epoch: [12]  [ 0/31]  eta: 0:02:39  lr: 0.000044  overall: [local: 0.4330 | reduced: 0.4330]  real_loss: [local: 0.4331 | reduced: 0.4331]  fake_loss: [local: 0.4329 | reduced: 0.4329]  time: 5.1559  data: 0.8430  max mem: 9292
# [10:56:32.650832] Epoch: [12]  [20/31]  eta: 0:00:42  lr: 0.000039  overall: [local: 0.4473 | reduced: 0.4420]  real_loss: [local: 0.4602 | reduced: 0.4570]  fake_loss: [local: 0.4261 | reduced: 0.4309]  time: 3.8432  data: 0.0003  max mem: 9292
# [10:57:07.337276] Epoch: [12]  [30/31]  eta: 0:00:03  lr: 0.000037  overall: [local: 0.4256 | reduced: 0.4434]  real_loss: [local: 0.4120 | reduced: 0.4432]  fake_loss: [local: 0.4570 | reduced: 0.4494]  time: 3.5218  data: 0.0004  max mem: 9292
# [10:57:07.438403] Epoch: [12] Total time: 0:01:56 (3.7681 s / it)
# [10:57:08.204006] Averaged stats: lr: 0.000037  overall: [local: 0.4256 | reduced: 0.4434]  real_loss: [local: 0.4120 | reduced: 0.4432]  fake_loss: [local: 0.4570 | reduced: 0.4494]
# [10:57:08.249677] !!!Start Test: DiffusionForensics_val 6
# [10:57:10.063044] Test: [12]  [0/6]  eta: 0:00:10    time: 1.8001  data: 0.7543  max mem: 9292
# [10:57:14.990841] Test: [12]  [5/6]  eta: 0:00:01    time: 1.1200  data: 0.1278  max mem: 9292
# [10:57:15.084284] Test: [12] Total time: 0:00:06 (1.1382 s / it)
# [10:57:15.100876] ---syncronized---
# [10:57:15.101056] image-level F1 reduced_count 1
# [10:57:15.101189] image-level F1 reduced_sum 0.5833333730697632
# [10:57:15.101313] image-level AUC reduced_count 1
# [10:57:15.101435] image-level AUC reduced_sum 0.6435084672166741
# [10:57:15.101572] ---syncronized done ---
# [10:57:15.391981] Averaged stats: image-level F1: [local: 0.5833 | reduced: 0.5833]  image-level AUC: [local: 0.6435 | reduced: 0.6435]
# [10:57:15.540627] Average image-level F1 image-level AUC = 0.6134209201432186
# [10:57:15.634827] Auto Mixed Precision (AMP) is enabled.
# [10:57:15.635802] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [10:57:20.515356] Epoch: [13]  [ 0/31]  eta: 0:02:31  lr: 0.000037  overall: [local: 0.6052 | reduced: 0.6052]  real_loss: [local: 0.4679 | reduced: 0.4679]  fake_loss: [local: 0.7119 | reduced: 0.7119]  time: 4.8782  data: 0.6217  max mem: 9292
# [10:58:32.455125] Epoch: [13]  [20/31]  eta: 0:00:40  lr: 0.000033  overall: [local: 0.4278 | reduced: 0.4504]  real_loss: [local: 0.4212 | reduced: 0.4327]  fake_loss: [local: 0.4611 | reduced: 0.4694]  time: 3.5969  data: 0.0004  max mem: 9292
# [10:59:07.251590] Epoch: [13]  [30/31]  eta: 0:00:03  lr: 0.000031  overall: [local: 0.4360 | reduced: 0.4489]  real_loss: [local: 0.4290 | reduced: 0.4309]  fake_loss: [local: 0.4656 | reduced: 0.4676]  time: 3.5211  data: 0.0003  max mem: 9292
# [10:59:07.352128] Epoch: [13] Total time: 0:01:51 (3.6037 s / it)
# [10:59:08.089253] Averaged stats: lr: 0.000031  overall: [local: 0.4360 | reduced: 0.4489]  real_loss: [local: 0.4290 | reduced: 0.4309]  fake_loss: [local: 0.4656 | reduced: 0.4676]
# [10:59:08.402420] !!!Start Test: DiffusionForensics_val 6
# [10:59:09.710643] Test: [13]  [0/6]  eta: 0:00:07    time: 1.3034  data: 0.3416  max mem: 9292
# [10:59:14.574373] Test: [13]  [5/6]  eta: 0:00:01    time: 1.0276  data: 0.0571  max mem: 9292
# [10:59:14.690808] Test: [13] Total time: 0:00:06 (1.0474 s / it)
# [10:59:14.698157] ---syncronized---
# [10:59:14.698315] image-level F1 reduced_count 1
# [10:59:14.698458] image-level F1 reduced_sum 0.5833333730697632
# [10:59:14.698615] image-level AUC reduced_count 1
# [10:59:14.698754] image-level AUC reduced_sum 0.6430742509769867
# [10:59:14.698890] ---syncronized done ---
# [10:59:15.098975] Averaged stats: image-level F1: [local: 0.5833 | reduced: 0.5833]  image-level AUC: [local: 0.6431 | reduced: 0.6431]
# [10:59:15.099826] Average image-level F1 image-level AUC = 0.6132038120233749
# [10:59:15.516435] Auto Mixed Precision (AMP) is enabled.
# [10:59:15.517009] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [10:59:20.681259] Epoch: [14]  [ 0/31]  eta: 0:02:40  lr: 0.000030  overall: [local: 0.3986 | reduced: 0.3986]  real_loss: [local: 0.3567 | reduced: 0.3567]  fake_loss: [local: 0.4460 | reduced: 0.4460]  time: 5.1628  data: 0.7581  max mem: 9292
# [11:00:32.190081] Epoch: [14]  [20/31]  eta: 0:00:40  lr: 0.000027  overall: [local: 0.4249 | reduced: 0.4351]  real_loss: [local: 0.3866 | reduced: 0.4123]  fake_loss: [local: 0.4365 | reduced: 0.4621]  time: 3.5754  data: 0.0002  max mem: 9292
# [11:01:06.657413] Epoch: [14]  [30/31]  eta: 0:00:03  lr: 0.000025  overall: [local: 0.4370 | reduced: 0.4349]  real_loss: [local: 0.4061 | reduced: 0.4326]  fake_loss: [local: 0.4102 | reduced: 0.4386]  time: 3.5118  data: 0.0003  max mem: 9292
# [11:01:06.767369] Epoch: [14] Total time: 0:01:51 (3.5887 s / it)
# [11:01:07.528474] Averaged stats: lr: 0.000025  overall: [local: 0.4370 | reduced: 0.4349]  real_loss: [local: 0.4061 | reduced: 0.4326]  fake_loss: [local: 0.4102 | reduced: 0.4386]
# [11:01:07.895407] !!!Start Test: DiffusionForensics_val 6
# [11:01:09.188741] Test: [14]  [0/6]  eta: 0:00:07    time: 1.2884  data: 0.3326  max mem: 9292
# [11:01:14.062664] Test: [14]  [5/6]  eta: 0:00:01    time: 1.0268  data: 0.0556  max mem: 9292
# [11:01:14.150242] Test: [14] Total time: 0:00:06 (1.0418 s / it)
# [11:01:14.157138] ---syncronized---
# [11:01:14.157280] image-level F1 reduced_count 1
# [11:01:14.157383] image-level F1 reduced_sum 0.6052631735801697
# [11:01:14.157488] image-level AUC reduced_count 1
# [11:01:14.157589] image-level AUC reduced_sum 0.6762152777777778
# [11:01:14.157701] ---syncronized done ---
# [11:01:14.441988] Averaged stats: image-level F1: [local: 0.6053 | reduced: 0.6053]  image-level AUC: [local: 0.6762 | reduced: 0.6762]
# [11:01:14.539740] Best image-level F1 image-level AUC = 0.6407392256789737
# [11:01:21.969570] Auto Mixed Precision (AMP) is enabled.
# [11:01:21.970027] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [11:01:26.959683] Epoch: [15]  [ 0/31]  eta: 0:02:34  lr: 0.000025  overall: [local: 0.2932 | reduced: 0.2932]  real_loss: [local: 0.3594 | reduced: 0.3594]  fake_loss: [local: 0.2269 | reduced: 0.2269]  time: 4.9880  data: 0.6451  max mem: 9292
# [11:02:43.717150] Epoch: [15]  [20/31]  eta: 0:00:42  lr: 0.000021  overall: [local: 0.4259 | reduced: 0.4357]  real_loss: [local: 0.4218 | reduced: 0.4476]  fake_loss: [local: 0.4294 | reduced: 0.4209]  time: 3.8378  data: 0.0003  max mem: 9292
# [11:03:18.491437] Epoch: [15]  [30/31]  eta: 0:00:03  lr: 0.000020  overall: [local: 0.4235 | reduced: 0.4365]  real_loss: [local: 0.4133 | reduced: 0.4505]  fake_loss: [local: 0.4246 | reduced: 0.4240]  time: 3.5443  data: 0.0003  max mem: 9292
# [11:03:18.635747] Epoch: [15] Total time: 0:01:56 (3.7634 s / it)
# [11:03:19.412699] Averaged stats: lr: 0.000020  overall: [local: 0.4235 | reduced: 0.4365]  real_loss: [local: 0.4133 | reduced: 0.4505]  fake_loss: [local: 0.4246 | reduced: 0.4240]
# [11:03:19.695914] !!!Start Test: DiffusionForensics_val 6
# [11:03:21.013870] Test: [15]  [0/6]  eta: 0:00:07    time: 1.3115  data: 0.3454  max mem: 9292
# [11:03:25.888820] Test: [15]  [5/6]  eta: 0:00:01    time: 1.0307  data: 0.0578  max mem: 9292
# [11:03:25.989788] Test: [15] Total time: 0:00:06 (1.0483 s / it)
# [11:03:26.026424] ---syncronized---
# [11:03:26.026604] image-level F1 reduced_count 1
# [11:03:26.026749] image-level F1 reduced_sum 0.6052631735801697
# [11:03:26.026920] image-level AUC reduced_count 1
# [11:03:26.027102] image-level AUC reduced_sum 0.6617391304347826
# [11:03:26.027271] ---syncronized done ---
# [11:03:26.431989] Averaged stats: image-level F1: [local: 0.6053 | reduced: 0.6053]  image-level AUC: [local: 0.6617 | reduced: 0.6617]
# [11:03:26.432928] Average image-level F1 image-level AUC = 0.6335011520074761
# [11:03:26.732560] Auto Mixed Precision (AMP) is enabled.
# [11:03:26.733111] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [11:03:31.535869] Epoch: [16]  [ 0/31]  eta: 0:02:28  lr: 0.000019  overall: [local: 0.3169 | reduced: 0.3169]  real_loss: [local: 0.5080 | reduced: 0.5080]  fake_loss: [local: 0.2169 | reduced: 0.2169]  time: 4.8013  data: 0.5885  max mem: 9292
# [11:04:43.113550] Epoch: [16]  [20/31]  eta: 0:00:40  lr: 0.000017  overall: [local: 0.4528 | reduced: 0.4382]  real_loss: [local: 0.4468 | reduced: 0.4461]  fake_loss: [local: 0.4595 | reduced: 0.4324]  time: 3.5788  data: 0.0004  max mem: 9292
# [11:05:17.769615] Epoch: [16]  [30/31]  eta: 0:00:03  lr: 0.000016  overall: [local: 0.4190 | reduced: 0.4386]  real_loss: [local: 0.4252 | reduced: 0.4416]  fake_loss: [local: 0.4165 | reduced: 0.4371]  time: 3.5077  data: 0.0004  max mem: 9292
# [11:05:17.845270] Epoch: [16] Total time: 0:01:51 (3.5843 s / it)
# [11:05:18.617395] Averaged stats: lr: 0.000016  overall: [local: 0.4190 | reduced: 0.4386]  real_loss: [local: 0.4252 | reduced: 0.4416]  fake_loss: [local: 0.4165 | reduced: 0.4371]
# [11:05:18.910599] !!!Start Test: DiffusionForensics_val 6
# [11:05:20.190781] Test: [16]  [0/6]  eta: 0:00:07    time: 1.2750  data: 0.3207  max mem: 9292
# [11:05:25.044587] Test: [16]  [5/6]  eta: 0:00:01    time: 1.0213  data: 0.0537  max mem: 9292
# [11:05:25.109158] Test: [16] Total time: 0:00:06 (1.0324 s / it)
# [11:05:25.115797] ---syncronized---
# [11:05:25.115967] image-level F1 reduced_count 1
# [11:05:25.116087] image-level F1 reduced_sum 0.5833333134651184
# [11:05:25.116218] image-level AUC reduced_count 1
# [11:05:25.116335] image-level AUC reduced_sum 0.6549479166666666
# [11:05:25.116456] ---syncronized done ---
# [11:05:25.405604] Averaged stats: image-level F1: [local: 0.5833 | reduced: 0.5833]  image-level AUC: [local: 0.6549 | reduced: 0.6549]
# [11:05:25.478675] Average image-level F1 image-level AUC = 0.6191406150658925
# [11:05:25.641645] Auto Mixed Precision (AMP) is enabled.
# [11:05:25.642151] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [11:05:30.408665] Epoch: [17]  [ 0/31]  eta: 0:02:27  lr: 0.000015  overall: [local: 0.3804 | reduced: 0.3804]  real_loss: [local: 0.3959 | reduced: 0.3959]  fake_loss: [local: 0.3699 | reduced: 0.3699]  time: 4.7650  data: 0.5970  max mem: 9292
# [11:06:41.573432] Epoch: [17]  [20/31]  eta: 0:00:39  lr: 0.000013  overall: [local: 0.4227 | reduced: 0.4271]  real_loss: [local: 0.3746 | reduced: 0.4238]  fake_loss: [local: 0.4243 | reduced: 0.4332]  time: 3.5582  data: 0.0004  max mem: 9292
# [11:07:16.026198] Epoch: [17]  [30/31]  eta: 0:00:03  lr: 0.000013  overall: [local: 0.4227 | reduced: 0.4357]  real_loss: [local: 0.3900 | reduced: 0.4260]  fake_loss: [local: 0.4334 | reduced: 0.4411]  time: 3.4912  data: 0.0003  max mem: 9292
# [11:07:16.100457] Epoch: [17] Total time: 0:01:50 (3.5632 s / it)
# [11:07:16.860065] Averaged stats: lr: 0.000013  overall: [local: 0.4227 | reduced: 0.4357]  real_loss: [local: 0.3900 | reduced: 0.4260]  fake_loss: [local: 0.4334 | reduced: 0.4411]
# [11:07:17.159939] !!!Start Test: DiffusionForensics_val 6
# [11:07:18.442061] Test: [17]  [0/6]  eta: 0:00:07    time: 1.2765  data: 0.3244  max mem: 9292
# [11:07:23.303063] Test: [17]  [5/6]  eta: 0:00:01    time: 1.0227  data: 0.0543  max mem: 9292
# [11:07:23.368381] Test: [17] Total time: 0:00:06 (1.0341 s / it)
# [11:07:23.375253] ---syncronized---
# [11:07:23.375387] image-level F1 reduced_count 1
# [11:07:23.375507] image-level F1 reduced_sum 0.6216216087341309
# [11:07:23.375624] image-level AUC reduced_count 1
# [11:07:23.375740] image-level AUC reduced_sum 0.6778115501519757
# [11:07:23.375857] ---syncronized done ---
# [11:07:23.741469] Averaged stats: image-level F1: [local: 0.6216 | reduced: 0.6216]  image-level AUC: [local: 0.6778 | reduced: 0.6778]
# [11:07:23.897165] Best image-level F1 image-level AUC = 0.6497165794430533
# [11:07:32.611884] Auto Mixed Precision (AMP) is enabled.
# [11:07:32.612387] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [11:07:38.348172] Epoch: [18]  [ 0/31]  eta: 0:02:57  lr: 0.000012  overall: [local: 0.3650 | reduced: 0.3650]  real_loss: [local: 0.3028 | reduced: 0.3028]  fake_loss: [local: 0.4356 | reduced: 0.4356]  time: 5.7344  data: 1.0642  max mem: 9292
# [11:08:54.123735] Epoch: [18]  [20/31]  eta: 0:00:42  lr: 0.000011  overall: [local: 0.4394 | reduced: 0.4271]  real_loss: [local: 0.4206 | reduced: 0.4095]  fake_loss: [local: 0.4585 | reduced: 0.4467]  time: 3.7887  data: 0.0003  max mem: 9292
# [11:09:28.743208] Epoch: [18]  [30/31]  eta: 0:00:03  lr: 0.000011  overall: [local: 0.4394 | reduced: 0.4336]  real_loss: [local: 0.3726 | reduced: 0.4116]  fake_loss: [local: 0.4788 | reduced: 0.4624]  time: 3.5006  data: 0.0002  max mem: 9292
# [11:09:28.816154] Epoch: [18] Total time: 0:01:56 (3.7485 s / it)
# [11:09:29.631992] Averaged stats: lr: 0.000011  overall: [local: 0.4394 | reduced: 0.4336]  real_loss: [local: 0.3726 | reduced: 0.4116]  fake_loss: [local: 0.4788 | reduced: 0.4624]
# [11:09:29.930705] !!!Start Test: DiffusionForensics_val 6
# [11:09:31.235582] Test: [18]  [0/6]  eta: 0:00:07    time: 1.2999  data: 0.3326  max mem: 9292
# [11:09:36.212119] Test: [18]  [5/6]  eta: 0:00:01    time: 1.0459  data: 0.0556  max mem: 9292
# [11:09:36.276292] Test: [18] Total time: 0:00:06 (1.0569 s / it)
# [11:09:36.283175] ---syncronized---
# [11:09:36.283311] image-level F1 reduced_count 1
# [11:09:36.283431] image-level F1 reduced_sum 0.5945945382118225
# [11:09:36.283551] image-level AUC reduced_count 1
# [11:09:36.283665] image-level AUC reduced_sum 0.6569691706469822
# [11:09:36.283779] ---syncronized done ---
# [11:09:36.554563] Averaged stats: image-level F1: [local: 0.5946 | reduced: 0.5946]  image-level AUC: [local: 0.6570 | reduced: 0.6570]
# [11:09:36.688078] Average image-level F1 image-level AUC = 0.6257818544294024
# [11:09:36.791889] Auto Mixed Precision (AMP) is enabled.
# [11:09:36.793510] log_dir: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train
# [11:09:41.573611] Epoch: [19]  [ 0/31]  eta: 0:02:28  lr: 0.000011  overall: [local: 0.3407 | reduced: 0.3407]  real_loss: [local: 0.2876 | reduced: 0.2876]  fake_loss: [local: 0.3820 | reduced: 0.3820]  time: 4.7783  data: 0.5907  max mem: 9292
# [11:10:53.435820] Epoch: [19]  [20/31]  eta: 0:00:40  lr: 0.000010  overall: [local: 0.4433 | reduced: 0.4398]  real_loss: [local: 0.4244 | reduced: 0.4196]  fake_loss: [local: 0.4511 | reduced: 0.4571]  time: 3.5930  data: 0.0003  max mem: 9292
# [11:11:28.082600] Epoch: [19]  [30/31]  eta: 0:00:03  lr: 0.000010  overall: [local: 0.4012 | reduced: 0.4361]  real_loss: [local: 0.3889 | reduced: 0.4069]  fake_loss: [local: 0.4511 | reduced: 0.4601]  time: 3.5368  data: 0.0003  max mem: 9292
# [11:11:28.158358] Epoch: [19] Total time: 0:01:51 (3.5924 s / it)
# [11:11:28.915664] Averaged stats: lr: 0.000010  overall: [local: 0.4012 | reduced: 0.4361]  real_loss: [local: 0.3889 | reduced: 0.4069]  fake_loss: [local: 0.4511 | reduced: 0.4601]
# [11:11:35.814325] !!!Start Test: DiffusionForensics_val 6
# [11:11:37.137474] Test: [19]  [0/6]  eta: 0:00:07    time: 1.3181  data: 0.3379  max mem: 9292
# [11:11:41.959172] Test: [19]  [5/6]  eta: 0:00:01    time: 1.0231  data: 0.0565  max mem: 9292
# [11:11:42.022777] Test: [19] Total time: 0:00:06 (1.0341 s / it)
# [11:11:42.045356] ---syncronized---
# [11:11:42.045510] image-level F1 reduced_count 1
# [11:11:42.045613] image-level F1 reduced_sum 0.611111044883728
# [11:11:42.045718] image-level AUC reduced_count 1
# [11:11:42.045819] image-level AUC reduced_sum 0.657837603126357
# [11:11:42.045949] ---syncronized done ---
# [11:11:42.346286] Averaged stats: image-level F1: [local: 0.6111 | reduced: 0.6111]  image-level AUC: [local: 0.6578 | reduced: 0.6578]
# [11:11:42.471442] Average image-level F1 image-level AUC = 0.6344743240050426
# [11:11:42.623884] Training time 0:41:35

# %%
# %matplotlib inline
import os, json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from IPython.display import Image, display

LOG_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train/log.txt"


def parse_forensichub_json_log(path):
    all_entries = []

    with open(path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            try:
                entry = json.loads(line)
            except json.JSONDecodeError:
                continue

            if "epoch" in entry:
                all_entries.append(entry)

    if not all_entries:
        raise RuntimeError(f"No JSON epoch entries found in {path}")

    # Use only the last run if the log contains restarted runs
    runs = []
    current_run = []
    prev_epoch = -1

    for entry in all_entries:
        ep = int(entry.get("epoch", 0))

        if ep <= prev_epoch and current_run:
            runs.append(current_run)
            current_run = []

        current_run.append(entry)
        prev_epoch = ep

    if current_run:
        runs.append(current_run)

    entries = runs[-1]

    # Display epochs as 1-based
    epochs = [int(e["epoch"]) + 1 for e in entries]

    train_losses = [
        float(e.get("train_overall", e.get("train_combined_loss", np.nan)))
        for e in entries
    ]

    real_losses = [
        float(e.get("train_real_loss", np.nan))
        for e in entries
    ]

    fake_losses = [
        float(e.get("train_fake_loss", np.nan))
        for e in entries
    ]

    lrs = [
        float(e.get("train_lr", np.nan))
        for e in entries
    ]

    test_aucs = [
        float(e.get("test_image-level AUC", np.nan))
        for e in entries
    ]

    test_f1s = [
        float(e.get("test_image-level F1", np.nan))
        for e in entries
    ]

    return epochs, train_losses, real_losses, fake_losses, lrs, test_aucs, test_f1s, len(runs)


def plot_training(path):
    epochs, losses, real_losses, fake_losses, lrs, aucs, f1s, n_runs = parse_forensichub_json_log(path)

    aucs_np = np.array(aucs, dtype=float)
    f1s_np = np.array(f1s, dtype=float)

    best_auc_idx = int(np.nanargmax(aucs_np))

    best_auc_epoch = epochs[best_auc_idx]
    best_auc = aucs[best_auc_idx]
    f1_at_best_auc = f1s[best_auc_idx]

    print(f"Best AUC: {best_auc:.4f} at epoch {best_auc_epoch}")
    print(f"F1 at best AUC epoch: {f1_at_best_auc:.4f} at epoch {best_auc_epoch}")

    fig, axes = plt.subplots(1, 4, figsize=(22, 4.8))
    fig.patch.set_facecolor("#FAFAFA")

    for ax in axes:
        ax.set_facecolor("#F4F4F4")
        ax.spines[["top", "right"]].set_visible(False)
        ax.spines[["left", "bottom"]].set_color("#CCCCCC")
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # 1. Training losses
    ax = axes[0]
    ax.plot(epochs, losses, marker="o", linewidth=2, markersize=5, label="Overall loss")
    ax.set_title("Training losses", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend(fontsize=9, framealpha=0.5)

    # 2. Validation AUC
    ax = axes[1]
    ax.plot(epochs, aucs, marker="D", linewidth=2, markersize=5, label="Val AUC")
    ax.fill_between(epochs, 0.5, aucs, alpha=0.15)
    ax.scatter(best_auc_epoch, best_auc, s=90, zorder=5, label="Best AUC")
    ax.annotate(
        f"Best AUC: {best_auc:.4f}",
        xy=(best_auc_epoch, best_auc),
        xytext=(best_auc_epoch - max(epochs) * 0.12, best_auc + 0.08),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0.4, 1.05)
    ax.set_title("Validation AUC", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("AUC")
    ax.legend(fontsize=9, framealpha=0.5)

    # 3. Validation F1 at best-AUC epoch
    ax = axes[2]
    ax.plot(epochs, f1s, marker="s", linewidth=2, markersize=5, label="Val F1")
    ax.scatter(best_auc_epoch, f1_at_best_auc, s=90, zorder=5, label="F1 at best-AUC epoch")
    ax.annotate(
        f"F1 @ best AUC: {f1_at_best_auc:.4f}",
        xy=(best_auc_epoch, f1_at_best_auc),
        xytext=(best_auc_epoch + max(epochs) * 0.12, f1_at_best_auc + 0.10),
        fontsize=9,
        ha="center",
        arrowprops=dict(arrowstyle="->", lw=1),
    )
    ax.axhline(0.5, linestyle=":", linewidth=1, alpha=0.6)
    ax.set_ylim(0, 1.05)
    ax.set_title("Validation F1", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("F1")
    ax.legend(fontsize=9, framealpha=0.5)

    # 4. Learning rate
    ax = axes[3]
    ax.plot(epochs, lrs, marker="o", linewidth=2, markersize=5, label="Learning rate")
    ax.set_title("Learning rate schedule", fontsize=13, pad=10)
    ax.set_xlabel("Epoch")
    ax.set_ylabel("LR")
    ax.ticklabel_format(style="sci", axis="y", scilimits=(0, 0))
    ax.legend(fontsize=9, framealpha=0.5)

    plt.suptitle(
        f"ForensicHub · Effort on DiffusionForensics ({len(epochs)} epochs)",
        fontsize=14,
        y=1.03,
    )
    plt.tight_layout()

    out_path = "forensichub_effort_training_curves.jpg"
    plt.savefig(out_path, dpi=100, bbox_inches="tight", facecolor=fig.get_facecolor())
    plt.close(fig)

    display(Image(out_path))


plot_training(LOG_PATH)
# Out:
# Best AUC: 0.6778 at epoch 18
# F1 at best AUC epoch: 0.6216 at epoch 18

# %%
# Validation inference — Effort

import os
import json
import torch
from PIL import Image
from torchvision import transforms
import sys

BASE = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks"

sys.path.insert(0, BASE)
sys.path.insert(0, os.path.join(BASE, "ForensicHub"))
sys.path.insert(0, os.path.join(BASE, "DeepfakeBench"))
sys.path.insert(0, os.path.join(BASE, "IMDLBenCo"))

import ForensicHub.tasks.deepfake
from ForensicHub.registry import MODELS, build_from_registry

# ── Paths / constants ─────────────────────────────────────────────────────────
CHECKPOINT_DIR = f"{BASE}/ForensicHub/log/crossdataset_image_new/diffusionforensics_effort_train"
VAL_JSON = "/content/DiffusionForensics_Recons/val.json"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
THRESHOLD = 0.5

# ── Step 1: find best epoch automatically from the log ────────────────────────
LOG_PATH = os.path.join(CHECKPOINT_DIR, "log.txt")

all_entries = []
with open(LOG_PATH) as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        try:
            entry = json.loads(line)
        except json.JSONDecodeError:
            continue

        if "epoch" in entry:
            all_entries.append(entry)

runs = []
current_run = []
prev_epoch = -1

for entry in all_entries:
    ep = int(entry.get("epoch", 0))

    if ep <= prev_epoch and current_run:
        runs.append(current_run)
        current_run = []

    current_run.append(entry)
    prev_epoch = ep

if current_run:
    runs.append(current_run)

if not runs:
    raise RuntimeError(f"No valid log runs found in {LOG_PATH}")

last_run = runs[-1]

# Choose best checkpoint by validation AUC
valid_auc_entries = [
    e for e in last_run
    if "test_image-level AUC" in e and e["test_image-level AUC"] is not None
]

if not valid_auc_entries:
    raise RuntimeError(f"No validation AUC entries found in last run of {LOG_PATH}")

best_entry = max(valid_auc_entries, key=lambda e: float(e["test_image-level AUC"]))

best_epoch = int(best_entry["epoch"])
best_auc = float(best_entry["test_image-level AUC"])
best_f1 = float(best_entry.get("test_image-level F1", float("nan")))

print(f"Best epoch from log by AUC: {best_epoch}")
print(f"Best val AUC: {best_auc:.6f}")
print(f"Val F1 at best-AUC epoch: {best_f1:.6f}")

# ── Step 2: select checkpoint ─────────────────────────────────────────────────
best_ckpt = os.path.join(CHECKPOINT_DIR, f"checkpoint-{best_epoch}.pth")

if not os.path.exists(best_ckpt):
    available = sorted(
        [
            f for f in os.listdir(CHECKPOINT_DIR)
            if f.startswith("checkpoint-") and f.endswith(".pth")
        ],
        key=lambda f: int(f.replace("checkpoint-", "").replace(".pth", ""))
    )

    if not available:
        raise FileNotFoundError(f"No checkpoint files found in {CHECKPOINT_DIR}")

    candidates = [
        f for f in available
        if int(f.replace("checkpoint-", "").replace(".pth", "")) <= best_epoch
    ]

    best_ckpt = os.path.join(
        CHECKPOINT_DIR,
        candidates[-1] if candidates else available[-1]
    )

print("Using checkpoint:")
print(best_ckpt)

# ── Step 3: build exact Effort model from ForensicHub registry ────────────────
model_args = {
    "name": "EffortDetector",
    "init_config": {
        "yaml_config_path": f"{BASE}/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml"
    }
}

model = build_from_registry(MODELS, model_args)

checkpoint = torch.load(best_ckpt, map_location=DEVICE, weights_only=False)
state_dict = checkpoint["model"] if "model" in checkpoint else checkpoint

missing, unexpected = model.load_state_dict(state_dict, strict=False)

print(f"Missing keys: {len(missing)}")
print(f"Unexpected keys: {len(unexpected)}")

if len(missing) > 0:
    print("First missing keys:", missing[:10])

if len(unexpected) > 0:
    print("First unexpected keys:", unexpected[:10])

model.to(DEVICE)
model.eval()

# ── Step 4: validation transform ──────────────────────────────────────────────
# Effort preprocessing:
# image_size: 224
# norm_type: CLIP

IMAGE_SIZE = 224

val_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.48145466, 0.4578275, 0.40821073],
        std=[0.26862954, 0.26130258, 0.27577711],
    ),
])

# ── Step 5: load validation items and run inference ───────────────────────────
with open(VAL_JSON) as f:
    val_items = json.load(f)

results = []
skipped = []

with torch.no_grad():
    for item in val_items:
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=DEVICE),
            }

            out_dict = model(**input_dict)

            prob = float(out_dict["pred_label"].view(-1)[0].item())
            pred = 1 if prob >= THRESHOLD else 0

            results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": prob,
                "correct": bool(pred == label),
                "checkpoint_epoch": best_epoch,
                "checkpoint_val_auc": best_auc,
                "checkpoint_val_f1": best_f1,
            })

        except Exception as e:
            skipped.append({
                "path": path,
                "error": str(e),
            })

if len(results) == 0:
    raise RuntimeError("No validation images were processed successfully.")

print(f"Processed: {len(results)}")
print(f"Skipped: {len(skipped)}")
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2.10.0+cu128
# Current Torch version: 2.10
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# ['in_channels', 'out_channels', 'kernel_size', 'stride', 'padding', 'dilation', 'groups', 'bias', 'padding_mode', 'device', 'dtype']
# spatial_count=0 keep_stride_count=0
# Best epoch from log by AUC: 17
# Best val AUC: 0.677812
# Val F1 at best-AUC epoch: 0.621622
# Using checkpoint:
# /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/effort_train/checkpoint-17.pth
# [lazy import] Loading 'EffortDetector' from 'DeepfakeBench.training.detectors.effort_detector'
# [build_from_registry] Creating model 'EffortDetector' with args: {'yaml_config_path': '/content/drive/MyDrive/Capstone_Hripsime/Frameworks/DeepfakeBench/DeepfakeBench/training/config/config/detector/effort.yaml'}
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/590 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# text_model.embeddings.position_ids   | UNEXPECTED |  |
# vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# embeddings.class_embedding: False
# embeddings.patch_embedding.weight: False
# embeddings.position_embedding.weight: False
# pre_layrnorm.weight: False
# pre_layrnorm.bias: False
# encoder.layers.0.self_attn.k_proj.weight_main: False
# encoder.layers.0.self_attn.k_proj.bias: False
# encoder.layers.0.self_attn.k_proj.S_residual: True
# encoder.layers.0.self_attn.k_proj.U_residual: True
# encoder.layers.0.self_attn.k_proj.V_residual: True
# encoder.layers.0.self_attn.v_proj.weight_main: False
# encoder.layers.0.self_attn.v_proj.bias: False
# encoder.layers.0.self_attn.v_proj.S_residual: True
# encoder.layers.0.self_attn.v_proj.U_residual: True
# encoder.layers.0.self_attn.v_proj.V_residual: True
# encoder.layers.0.self_attn.q_proj.weight_main: False
# encoder.layers.0.self_attn.q_proj.bias: False
# encoder.layers.0.self_attn.q_proj.S_residual: True
# encoder.layers.0.self_attn.q_proj.U_residual: True
# encoder.layers.0.self_attn.q_proj.V_residual: True
# encoder.layers.0.self_attn.out_proj.weight_main: False
# encoder.layers.0.self_attn.out_proj.bias: False
# encoder.layers.0.self_attn.out_proj.S_residual: True
# encoder.layers.0.self_attn.out_proj.U_residual: True
# encoder.layers.0.self_attn.out_proj.V_residual: True
# encoder.layers.0.layer_norm1.weight: False
# encoder.layers.0.layer_norm1.bias: False
# encoder.layers.0.mlp.fc1.weight: False
# encoder.layers.0.mlp.fc1.bias: False
# encoder.layers.0.mlp.fc2.weight: False
# encoder.layers.0.mlp.fc2.bias: False
# encoder.layers.0.layer_norm2.weight: False
# encoder.layers.0.layer_norm2.bias: False
# encoder.layers.1.self_attn.k_proj.weight_main: False
# encoder.layers.1.self_attn.k_proj.bias: False
# encoder.layers.1.self_attn.k_proj.S_residual: True
# encoder.layers.1.self_attn.k_proj.U_residual: True
# encoder.layers.1.self_attn.k_proj.V_residual: True
# encoder.layers.1.self_attn.v_proj.weight_main: False
# encoder.layers.1.self_attn.v_proj.bias: False
# encoder.layers.1.self_attn.v_proj.S_residual: True
# encoder.layers.1.self_attn.v_proj.U_residual: True
# encoder.layers.1.self_attn.v_proj.V_residual: True
# encoder.layers.1.self_attn.q_proj.weight_main: False
# encoder.layers.1.self_attn.q_proj.bias: False
# encoder.layers.1.self_attn.q_proj.S_residual: True
# encoder.layers.1.self_attn.q_proj.U_residual: True
# encoder.layers.1.self_attn.q_proj.V_residual: True
# encoder.layers.1.self_attn.out_proj.weight_main: False
# encoder.layers.1.self_attn.out_proj.bias: False
# encoder.layers.1.self_attn.out_proj.S_residual: True
# encoder.layers.1.self_attn.out_proj.U_residual: True
# encoder.layers.1.self_attn.out_proj.V_residual: True
# encoder.layers.1.layer_norm1.weight: False
# encoder.layers.1.layer_norm1.bias: False
# encoder.layers.1.mlp.fc1.weight: False
# encoder.layers.1.mlp.fc1.bias: False
# encoder.layers.1.mlp.fc2.weight: False
# encoder.layers.1.mlp.fc2.bias: False
# encoder.layers.1.layer_norm2.weight: False
# encoder.layers.1.layer_norm2.bias: False
# encoder.layers.2.self_attn.k_proj.weight_main: False
# encoder.layers.2.self_attn.k_proj.bias: False
# encoder.layers.2.self_attn.k_proj.S_residual: True
# encoder.layers.2.self_attn.k_proj.U_residual: True
# encoder.layers.2.self_attn.k_proj.V_residual: True
# encoder.layers.2.self_attn.v_proj.weight_main: False
# encoder.layers.2.self_attn.v_proj.bias: False
# encoder.layers.2.self_attn.v_proj.S_residual: True
# encoder.layers.2.self_attn.v_proj.U_residual: True
# encoder.layers.2.self_attn.v_proj.V_residual: True
# encoder.layers.2.self_attn.q_proj.weight_main: False
# encoder.layers.2.self_attn.q_proj.bias: False
# encoder.layers.2.self_attn.q_proj.S_residual: True
# encoder.layers.2.self_attn.q_proj.U_residual: True
# encoder.layers.2.self_attn.q_proj.V_residual: True
# encoder.layers.2.self_attn.out_proj.weight_main: False
# encoder.layers.2.self_attn.out_proj.bias: False
# encoder.layers.2.self_attn.out_proj.S_residual: True
# encoder.layers.2.self_attn.out_proj.U_residual: True
# encoder.layers.2.self_attn.out_proj.V_residual: True
# encoder.layers.2.layer_norm1.weight: False
# encoder.layers.2.layer_norm1.bias: False
# encoder.layers.2.mlp.fc1.weight: False
# encoder.layers.2.mlp.fc1.bias: False
# encoder.layers.2.mlp.fc2.weight: False
# encoder.layers.2.mlp.fc2.bias: False
# encoder.layers.2.layer_norm2.weight: False
# encoder.layers.2.layer_norm2.bias: False
# encoder.layers.3.self_attn.k_proj.weight_main: False
# encoder.layers.3.self_attn.k_proj.bias: False
# encoder.layers.3.self_attn.k_proj.S_residual: True
# encoder.layers.3.self_attn.k_proj.U_residual: True
# encoder.layers.3.self_attn.k_proj.V_residual: True
# encoder.layers.3.self_attn.v_proj.weight_main: False
# encoder.layers.3.self_attn.v_proj.bias: False
# encoder.layers.3.self_attn.v_proj.S_residual: True
# encoder.layers.3.self_attn.v_proj.U_residual: True
# encoder.layers.3.self_attn.v_proj.V_residual: True
# encoder.layers.3.self_attn.q_proj.weight_main: False
# encoder.layers.3.self_attn.q_proj.bias: False
# encoder.layers.3.self_attn.q_proj.S_residual: True
# encoder.layers.3.self_attn.q_proj.U_residual: True
# encoder.layers.3.self_attn.q_proj.V_residual: True
# encoder.layers.3.self_attn.out_proj.weight_main: False
# encoder.layers.3.self_attn.out_proj.bias: False
# encoder.layers.3.self_attn.out_proj.S_residual: True
# encoder.layers.3.self_attn.out_proj.U_residual: True
# encoder.layers.3.self_attn.out_proj.V_residual: True
# encoder.layers.3.layer_norm1.weight: False
# encoder.layers.3.layer_norm1.bias: False
# encoder.layers.3.mlp.fc1.weight: False
# encoder.layers.3.mlp.fc1.bias: False
# encoder.layers.3.mlp.fc2.weight: False
# encoder.layers.3.mlp.fc2.bias: False
# encoder.layers.3.layer_norm2.weight: False
# encoder.layers.3.layer_norm2.bias: False
# encoder.layers.4.self_attn.k_proj.weight_main: False
# encoder.layers.4.self_attn.k_proj.bias: False
# encoder.layers.4.self_attn.k_proj.S_residual: True
# encoder.layers.4.self_attn.k_proj.U_residual: True
# encoder.layers.4.self_attn.k_proj.V_residual: True
# encoder.layers.4.self_attn.v_proj.weight_main: False
# encoder.layers.4.self_attn.v_proj.bias: False
# encoder.layers.4.self_attn.v_proj.S_residual: True
# encoder.layers.4.self_attn.v_proj.U_residual: True
# encoder.layers.4.self_attn.v_proj.V_residual: True
# encoder.layers.4.self_attn.q_proj.weight_main: False
# encoder.layers.4.self_attn.q_proj.bias: False
# encoder.layers.4.self_attn.q_proj.S_residual: True
# encoder.layers.4.self_attn.q_proj.U_residual: True
# encoder.layers.4.self_attn.q_proj.V_residual: True
# encoder.layers.4.self_attn.out_proj.weight_main: False
# encoder.layers.4.self_attn.out_proj.bias: False
# encoder.layers.4.self_attn.out_proj.S_residual: True
# encoder.layers.4.self_attn.out_proj.U_residual: True
# encoder.layers.4.self_attn.out_proj.V_residual: True
# encoder.layers.4.layer_norm1.weight: False
# encoder.layers.4.layer_norm1.bias: False
# encoder.layers.4.mlp.fc1.weight: False
# encoder.layers.4.mlp.fc1.bias: False
# encoder.layers.4.mlp.fc2.weight: False
# encoder.layers.4.mlp.fc2.bias: False
# encoder.layers.4.layer_norm2.weight: False
# encoder.layers.4.layer_norm2.bias: False
# encoder.layers.5.self_attn.k_proj.weight_main: False
# encoder.layers.5.self_attn.k_proj.bias: False
# encoder.layers.5.self_attn.k_proj.S_residual: True
# encoder.layers.5.self_attn.k_proj.U_residual: True
# encoder.layers.5.self_attn.k_proj.V_residual: True
# encoder.layers.5.self_attn.v_proj.weight_main: False
# encoder.layers.5.self_attn.v_proj.bias: False
# encoder.layers.5.self_attn.v_proj.S_residual: True
# encoder.layers.5.self_attn.v_proj.U_residual: True
# encoder.layers.5.self_attn.v_proj.V_residual: True
# encoder.layers.5.self_attn.q_proj.weight_main: False
# encoder.layers.5.self_attn.q_proj.bias: False
# encoder.layers.5.self_attn.q_proj.S_residual: True
# encoder.layers.5.self_attn.q_proj.U_residual: True
# encoder.layers.5.self_attn.q_proj.V_residual: True
# encoder.layers.5.self_attn.out_proj.weight_main: False
# encoder.layers.5.self_attn.out_proj.bias: False
# encoder.layers.5.self_attn.out_proj.S_residual: True
# encoder.layers.5.self_attn.out_proj.U_residual: True
# encoder.layers.5.self_attn.out_proj.V_residual: True
# encoder.layers.5.layer_norm1.weight: False
# encoder.layers.5.layer_norm1.bias: False
# encoder.layers.5.mlp.fc1.weight: False
# encoder.layers.5.mlp.fc1.bias: False
# encoder.layers.5.mlp.fc2.weight: False
# encoder.layers.5.mlp.fc2.bias: False
# encoder.layers.5.layer_norm2.weight: False
# encoder.layers.5.layer_norm2.bias: False
# encoder.layers.6.self_attn.k_proj.weight_main: False
# encoder.layers.6.self_attn.k_proj.bias: False
# encoder.layers.6.self_attn.k_proj.S_residual: True
# encoder.layers.6.self_attn.k_proj.U_residual: True
# encoder.layers.6.self_attn.k_proj.V_residual: True
# encoder.layers.6.self_attn.v_proj.weight_main: False
# encoder.layers.6.self_attn.v_proj.bias: False
# encoder.layers.6.self_attn.v_proj.S_residual: True
# encoder.layers.6.self_attn.v_proj.U_residual: True
# encoder.layers.6.self_attn.v_proj.V_residual: True
# encoder.layers.6.self_attn.q_proj.weight_main: False
# encoder.layers.6.self_attn.q_proj.bias: False
# encoder.layers.6.self_attn.q_proj.S_residual: True
# encoder.layers.6.self_attn.q_proj.U_residual: True
# encoder.layers.6.self_attn.q_proj.V_residual: True
# encoder.layers.6.self_attn.out_proj.weight_main: False
# encoder.layers.6.self_attn.out_proj.bias: False
# encoder.layers.6.self_attn.out_proj.S_residual: True
# encoder.layers.6.self_attn.out_proj.U_residual: True
# encoder.layers.6.self_attn.out_proj.V_residual: True
# encoder.layers.6.layer_norm1.weight: False
# encoder.layers.6.layer_norm1.bias: False
# encoder.layers.6.mlp.fc1.weight: False
# encoder.layers.6.mlp.fc1.bias: False
# encoder.layers.6.mlp.fc2.weight: False
# encoder.layers.6.mlp.fc2.bias: False
# encoder.layers.6.layer_norm2.weight: False
# encoder.layers.6.layer_norm2.bias: False
# encoder.layers.7.self_attn.k_proj.weight_main: False
# encoder.layers.7.self_attn.k_proj.bias: False
# encoder.layers.7.self_attn.k_proj.S_residual: True
# encoder.layers.7.self_attn.k_proj.U_residual: True
# encoder.layers.7.self_attn.k_proj.V_residual: True
# encoder.layers.7.self_attn.v_proj.weight_main: False
# encoder.layers.7.self_attn.v_proj.bias: False
# encoder.layers.7.self_attn.v_proj.S_residual: True
# encoder.layers.7.self_attn.v_proj.U_residual: True
# encoder.layers.7.self_attn.v_proj.V_residual: True
# encoder.layers.7.self_attn.q_proj.weight_main: False
# encoder.layers.7.self_attn.q_proj.bias: False
# encoder.layers.7.self_attn.q_proj.S_residual: True
# encoder.layers.7.self_attn.q_proj.U_residual: True
# encoder.layers.7.self_attn.q_proj.V_residual: True
# encoder.layers.7.self_attn.out_proj.weight_main: False
# encoder.layers.7.self_attn.out_proj.bias: False
# encoder.layers.7.self_attn.out_proj.S_residual: True
# encoder.layers.7.self_attn.out_proj.U_residual: True
# encoder.layers.7.self_attn.out_proj.V_residual: True
# encoder.layers.7.layer_norm1.weight: False
# encoder.layers.7.layer_norm1.bias: False
# encoder.layers.7.mlp.fc1.weight: False
# encoder.layers.7.mlp.fc1.bias: False
# encoder.layers.7.mlp.fc2.weight: False
# encoder.layers.7.mlp.fc2.bias: False
# encoder.layers.7.layer_norm2.weight: False
# encoder.layers.7.layer_norm2.bias: False
# encoder.layers.8.self_attn.k_proj.weight_main: False
# encoder.layers.8.self_attn.k_proj.bias: False
# encoder.layers.8.self_attn.k_proj.S_residual: True
# encoder.layers.8.self_attn.k_proj.U_residual: True
# encoder.layers.8.self_attn.k_proj.V_residual: True
# encoder.layers.8.self_attn.v_proj.weight_main: False
# encoder.layers.8.self_attn.v_proj.bias: False
# encoder.layers.8.self_attn.v_proj.S_residual: True
# encoder.layers.8.self_attn.v_proj.U_residual: True
# encoder.layers.8.self_attn.v_proj.V_residual: True
# encoder.layers.8.self_attn.q_proj.weight_main: False
# encoder.layers.8.self_attn.q_proj.bias: False
# encoder.layers.8.self_attn.q_proj.S_residual: True
# encoder.layers.8.self_attn.q_proj.U_residual: True
# encoder.layers.8.self_attn.q_proj.V_residual: True
# encoder.layers.8.self_attn.out_proj.weight_main: False
# encoder.layers.8.self_attn.out_proj.bias: False
# encoder.layers.8.self_attn.out_proj.S_residual: True
# encoder.layers.8.self_attn.out_proj.U_residual: True
# encoder.layers.8.self_attn.out_proj.V_residual: True
# encoder.layers.8.layer_norm1.weight: False
# encoder.layers.8.layer_norm1.bias: False
# encoder.layers.8.mlp.fc1.weight: False
# encoder.layers.8.mlp.fc1.bias: False
# encoder.layers.8.mlp.fc2.weight: False
# encoder.layers.8.mlp.fc2.bias: False
# encoder.layers.8.layer_norm2.weight: False
# encoder.layers.8.layer_norm2.bias: False
# encoder.layers.9.self_attn.k_proj.weight_main: False
# encoder.layers.9.self_attn.k_proj.bias: False
# encoder.layers.9.self_attn.k_proj.S_residual: True
# encoder.layers.9.self_attn.k_proj.U_residual: True
# encoder.layers.9.self_attn.k_proj.V_residual: True
# encoder.layers.9.self_attn.v_proj.weight_main: False
# encoder.layers.9.self_attn.v_proj.bias: False
# encoder.layers.9.self_attn.v_proj.S_residual: True
# encoder.layers.9.self_attn.v_proj.U_residual: True
# encoder.layers.9.self_attn.v_proj.V_residual: True
# encoder.layers.9.self_attn.q_proj.weight_main: False
# encoder.layers.9.self_attn.q_proj.bias: False
# encoder.layers.9.self_attn.q_proj.S_residual: True
# encoder.layers.9.self_attn.q_proj.U_residual: True
# encoder.layers.9.self_attn.q_proj.V_residual: True
# encoder.layers.9.self_attn.out_proj.weight_main: False
# encoder.layers.9.self_attn.out_proj.bias: False
# encoder.layers.9.self_attn.out_proj.S_residual: True
# encoder.layers.9.self_attn.out_proj.U_residual: True
# encoder.layers.9.self_attn.out_proj.V_residual: True
# encoder.layers.9.layer_norm1.weight: False
# encoder.layers.9.layer_norm1.bias: False
# encoder.layers.9.mlp.fc1.weight: False
# encoder.layers.9.mlp.fc1.bias: False
# encoder.layers.9.mlp.fc2.weight: False
# encoder.layers.9.mlp.fc2.bias: False
# encoder.layers.9.layer_norm2.weight: False
# encoder.layers.9.layer_norm2.bias: False
# encoder.layers.10.self_attn.k_proj.weight_main: False
# encoder.layers.10.self_attn.k_proj.bias: False
# encoder.layers.10.self_attn.k_proj.S_residual: True
# encoder.layers.10.self_attn.k_proj.U_residual: True
# encoder.layers.10.self_attn.k_proj.V_residual: True
# encoder.layers.10.self_attn.v_proj.weight_main: False
# encoder.layers.10.self_attn.v_proj.bias: False
# encoder.layers.10.self_attn.v_proj.S_residual: True
# encoder.layers.10.self_attn.v_proj.U_residual: True
# encoder.layers.10.self_attn.v_proj.V_residual: True
# encoder.layers.10.self_attn.q_proj.weight_main: False
# encoder.layers.10.self_attn.q_proj.bias: False
# encoder.layers.10.self_attn.q_proj.S_residual: True
# encoder.layers.10.self_attn.q_proj.U_residual: True
# encoder.layers.10.self_attn.q_proj.V_residual: True
# encoder.layers.10.self_attn.out_proj.weight_main: False
# encoder.layers.10.self_attn.out_proj.bias: False
# encoder.layers.10.self_attn.out_proj.S_residual: True
# encoder.layers.10.self_attn.out_proj.U_residual: True
# encoder.layers.10.self_attn.out_proj.V_residual: True
# encoder.layers.10.layer_norm1.weight: False
# encoder.layers.10.layer_norm1.bias: False
# encoder.layers.10.mlp.fc1.weight: False
# encoder.layers.10.mlp.fc1.bias: False
# encoder.layers.10.mlp.fc2.weight: False
# encoder.layers.10.mlp.fc2.bias: False
# encoder.layers.10.layer_norm2.weight: False
# encoder.layers.10.layer_norm2.bias: False
# encoder.layers.11.self_attn.k_proj.weight_main: False
# encoder.layers.11.self_attn.k_proj.bias: False
# encoder.layers.11.self_attn.k_proj.S_residual: True
# encoder.layers.11.self_attn.k_proj.U_residual: True
# encoder.layers.11.self_attn.k_proj.V_residual: True
# encoder.layers.11.self_attn.v_proj.weight_main: False
# encoder.layers.11.self_attn.v_proj.bias: False
# encoder.layers.11.self_attn.v_proj.S_residual: True
# encoder.layers.11.self_attn.v_proj.U_residual: True
# encoder.layers.11.self_attn.v_proj.V_residual: True
# encoder.layers.11.self_attn.q_proj.weight_main: False
# encoder.layers.11.self_attn.q_proj.bias: False
# encoder.layers.11.self_attn.q_proj.S_residual: True
# encoder.layers.11.self_attn.q_proj.U_residual: True
# encoder.layers.11.self_attn.q_proj.V_residual: True
# encoder.layers.11.self_attn.out_proj.weight_main: False
# encoder.layers.11.self_attn.out_proj.bias: False
# encoder.layers.11.self_attn.out_proj.S_residual: True
# encoder.layers.11.self_attn.out_proj.U_residual: True
# encoder.layers.11.self_attn.out_proj.V_residual: True
# encoder.layers.11.layer_norm1.weight: False
# encoder.layers.11.layer_norm1.bias: False
# encoder.layers.11.mlp.fc1.weight: False
# encoder.layers.11.mlp.fc1.bias: False
# encoder.layers.11.mlp.fc2.weight: False
# encoder.layers.11.mlp.fc2.bias: False
# encoder.layers.11.layer_norm2.weight: False
# encoder.layers.11.layer_norm2.bias: False
# encoder.layers.12.self_attn.k_proj.weight_main: False
# encoder.layers.12.self_attn.k_proj.bias: False
# encoder.layers.12.self_attn.k_proj.S_residual: True
# encoder.layers.12.self_attn.k_proj.U_residual: True
# encoder.layers.12.self_attn.k_proj.V_residual: True
# encoder.layers.12.self_attn.v_proj.weight_main: False
# encoder.layers.12.self_attn.v_proj.bias: False
# encoder.layers.12.self_attn.v_proj.S_residual: True
# encoder.layers.12.self_attn.v_proj.U_residual: True
# encoder.layers.12.self_attn.v_proj.V_residual: True
# encoder.layers.12.self_attn.q_proj.weight_main: False
# encoder.layers.12.self_attn.q_proj.bias: False
# encoder.layers.12.self_attn.q_proj.S_residual: True
# encoder.layers.12.self_attn.q_proj.U_residual: True
# encoder.layers.12.self_attn.q_proj.V_residual: True
# encoder.layers.12.self_attn.out_proj.weight_main: False
# encoder.layers.12.self_attn.out_proj.bias: False
# encoder.layers.12.self_attn.out_proj.S_residual: True
# encoder.layers.12.self_attn.out_proj.U_residual: True
# encoder.layers.12.self_attn.out_proj.V_residual: True
# encoder.layers.12.layer_norm1.weight: False
# encoder.layers.12.layer_norm1.bias: False
# encoder.layers.12.mlp.fc1.weight: False
# encoder.layers.12.mlp.fc1.bias: False
# encoder.layers.12.mlp.fc2.weight: False
# encoder.layers.12.mlp.fc2.bias: False
# encoder.layers.12.layer_norm2.weight: False
# encoder.layers.12.layer_norm2.bias: False
# encoder.layers.13.self_attn.k_proj.weight_main: False
# encoder.layers.13.self_attn.k_proj.bias: False
# encoder.layers.13.self_attn.k_proj.S_residual: True
# encoder.layers.13.self_attn.k_proj.U_residual: True
# encoder.layers.13.self_attn.k_proj.V_residual: True
# encoder.layers.13.self_attn.v_proj.weight_main: False
# encoder.layers.13.self_attn.v_proj.bias: False
# encoder.layers.13.self_attn.v_proj.S_residual: True
# encoder.layers.13.self_attn.v_proj.U_residual: True
# encoder.layers.13.self_attn.v_proj.V_residual: True
# encoder.layers.13.self_attn.q_proj.weight_main: False
# encoder.layers.13.self_attn.q_proj.bias: False
# encoder.layers.13.self_attn.q_proj.S_residual: True
# encoder.layers.13.self_attn.q_proj.U_residual: True
# encoder.layers.13.self_attn.q_proj.V_residual: True
# encoder.layers.13.self_attn.out_proj.weight_main: False
# encoder.layers.13.self_attn.out_proj.bias: False
# encoder.layers.13.self_attn.out_proj.S_residual: True
# encoder.layers.13.self_attn.out_proj.U_residual: True
# encoder.layers.13.self_attn.out_proj.V_residual: True
# encoder.layers.13.layer_norm1.weight: False
# encoder.layers.13.layer_norm1.bias: False
# encoder.layers.13.mlp.fc1.weight: False
# encoder.layers.13.mlp.fc1.bias: False
# encoder.layers.13.mlp.fc2.weight: False
# encoder.layers.13.mlp.fc2.bias: False
# encoder.layers.13.layer_norm2.weight: False
# encoder.layers.13.layer_norm2.bias: False
# encoder.layers.14.self_attn.k_proj.weight_main: False
# encoder.layers.14.self_attn.k_proj.bias: False
# encoder.layers.14.self_attn.k_proj.S_residual: True
# encoder.layers.14.self_attn.k_proj.U_residual: True
# encoder.layers.14.self_attn.k_proj.V_residual: True
# encoder.layers.14.self_attn.v_proj.weight_main: False
# encoder.layers.14.self_attn.v_proj.bias: False
# encoder.layers.14.self_attn.v_proj.S_residual: True
# encoder.layers.14.self_attn.v_proj.U_residual: True
# encoder.layers.14.self_attn.v_proj.V_residual: True
# encoder.layers.14.self_attn.q_proj.weight_main: False
# encoder.layers.14.self_attn.q_proj.bias: False
# encoder.layers.14.self_attn.q_proj.S_residual: True
# encoder.layers.14.self_attn.q_proj.U_residual: True
# encoder.layers.14.self_attn.q_proj.V_residual: True
# encoder.layers.14.self_attn.out_proj.weight_main: False
# encoder.layers.14.self_attn.out_proj.bias: False
# encoder.layers.14.self_attn.out_proj.S_residual: True
# encoder.layers.14.self_attn.out_proj.U_residual: True
# encoder.layers.14.self_attn.out_proj.V_residual: True
# encoder.layers.14.layer_norm1.weight: False
# encoder.layers.14.layer_norm1.bias: False
# encoder.layers.14.mlp.fc1.weight: False
# encoder.layers.14.mlp.fc1.bias: False
# encoder.layers.14.mlp.fc2.weight: False
# encoder.layers.14.mlp.fc2.bias: False
# encoder.layers.14.layer_norm2.weight: False
# encoder.layers.14.layer_norm2.bias: False
# encoder.layers.15.self_attn.k_proj.weight_main: False
# encoder.layers.15.self_attn.k_proj.bias: False
# encoder.layers.15.self_attn.k_proj.S_residual: True
# encoder.layers.15.self_attn.k_proj.U_residual: True
# encoder.layers.15.self_attn.k_proj.V_residual: True
# encoder.layers.15.self_attn.v_proj.weight_main: False
# encoder.layers.15.self_attn.v_proj.bias: False
# encoder.layers.15.self_attn.v_proj.S_residual: True
# encoder.layers.15.self_attn.v_proj.U_residual: True
# encoder.layers.15.self_attn.v_proj.V_residual: True
# encoder.layers.15.self_attn.q_proj.weight_main: False
# encoder.layers.15.self_attn.q_proj.bias: False
# encoder.layers.15.self_attn.q_proj.S_residual: True
# encoder.layers.15.self_attn.q_proj.U_residual: True
# encoder.layers.15.self_attn.q_proj.V_residual: True
# encoder.layers.15.self_attn.out_proj.weight_main: False
# encoder.layers.15.self_attn.out_proj.bias: False
# encoder.layers.15.self_attn.out_proj.S_residual: True
# encoder.layers.15.self_attn.out_proj.U_residual: True
# encoder.layers.15.self_attn.out_proj.V_residual: True
# encoder.layers.15.layer_norm1.weight: False
# encoder.layers.15.layer_norm1.bias: False
# encoder.layers.15.mlp.fc1.weight: False
# encoder.layers.15.mlp.fc1.bias: False
# encoder.layers.15.mlp.fc2.weight: False
# encoder.layers.15.mlp.fc2.bias: False
# encoder.layers.15.layer_norm2.weight: False
# encoder.layers.15.layer_norm2.bias: False
# encoder.layers.16.self_attn.k_proj.weight_main: False
# encoder.layers.16.self_attn.k_proj.bias: False
# encoder.layers.16.self_attn.k_proj.S_residual: True
# encoder.layers.16.self_attn.k_proj.U_residual: True
# encoder.layers.16.self_attn.k_proj.V_residual: True
# encoder.layers.16.self_attn.v_proj.weight_main: False
# encoder.layers.16.self_attn.v_proj.bias: False
# encoder.layers.16.self_attn.v_proj.S_residual: True
# encoder.layers.16.self_attn.v_proj.U_residual: True
# encoder.layers.16.self_attn.v_proj.V_residual: True
# encoder.layers.16.self_attn.q_proj.weight_main: False
# encoder.layers.16.self_attn.q_proj.bias: False
# encoder.layers.16.self_attn.q_proj.S_residual: True
# encoder.layers.16.self_attn.q_proj.U_residual: True
# encoder.layers.16.self_attn.q_proj.V_residual: True
# encoder.layers.16.self_attn.out_proj.weight_main: False
# encoder.layers.16.self_attn.out_proj.bias: False
# encoder.layers.16.self_attn.out_proj.S_residual: True
# encoder.layers.16.self_attn.out_proj.U_residual: True
# encoder.layers.16.self_attn.out_proj.V_residual: True
# encoder.layers.16.layer_norm1.weight: False
# encoder.layers.16.layer_norm1.bias: False
# encoder.layers.16.mlp.fc1.weight: False
# encoder.layers.16.mlp.fc1.bias: False
# encoder.layers.16.mlp.fc2.weight: False
# encoder.layers.16.mlp.fc2.bias: False
# encoder.layers.16.layer_norm2.weight: False
# encoder.layers.16.layer_norm2.bias: False
# encoder.layers.17.self_attn.k_proj.weight_main: False
# encoder.layers.17.self_attn.k_proj.bias: False
# encoder.layers.17.self_attn.k_proj.S_residual: True
# encoder.layers.17.self_attn.k_proj.U_residual: True
# encoder.layers.17.self_attn.k_proj.V_residual: True
# encoder.layers.17.self_attn.v_proj.weight_main: False
# encoder.layers.17.self_attn.v_proj.bias: False
# encoder.layers.17.self_attn.v_proj.S_residual: True
# encoder.layers.17.self_attn.v_proj.U_residual: True
# encoder.layers.17.self_attn.v_proj.V_residual: True
# encoder.layers.17.self_attn.q_proj.weight_main: False
# encoder.layers.17.self_attn.q_proj.bias: False
# encoder.layers.17.self_attn.q_proj.S_residual: True
# encoder.layers.17.self_attn.q_proj.U_residual: True
# encoder.layers.17.self_attn.q_proj.V_residual: True
# encoder.layers.17.self_attn.out_proj.weight_main: False
# encoder.layers.17.self_attn.out_proj.bias: False
# encoder.layers.17.self_attn.out_proj.S_residual: True
# encoder.layers.17.self_attn.out_proj.U_residual: True
# encoder.layers.17.self_attn.out_proj.V_residual: True
# encoder.layers.17.layer_norm1.weight: False
# encoder.layers.17.layer_norm1.bias: False
# encoder.layers.17.mlp.fc1.weight: False
# encoder.layers.17.mlp.fc1.bias: False
# encoder.layers.17.mlp.fc2.weight: False
# encoder.layers.17.mlp.fc2.bias: False
# encoder.layers.17.layer_norm2.weight: False
# encoder.layers.17.layer_norm2.bias: False
# encoder.layers.18.self_attn.k_proj.weight_main: False
# encoder.layers.18.self_attn.k_proj.bias: False
# encoder.layers.18.self_attn.k_proj.S_residual: True
# encoder.layers.18.self_attn.k_proj.U_residual: True
# encoder.layers.18.self_attn.k_proj.V_residual: True
# encoder.layers.18.self_attn.v_proj.weight_main: False
# encoder.layers.18.self_attn.v_proj.bias: False
# encoder.layers.18.self_attn.v_proj.S_residual: True
# encoder.layers.18.self_attn.v_proj.U_residual: True
# encoder.layers.18.self_attn.v_proj.V_residual: True
# encoder.layers.18.self_attn.q_proj.weight_main: False
# encoder.layers.18.self_attn.q_proj.bias: False
# encoder.layers.18.self_attn.q_proj.S_residual: True
# encoder.layers.18.self_attn.q_proj.U_residual: True
# encoder.layers.18.self_attn.q_proj.V_residual: True
# encoder.layers.18.self_attn.out_proj.weight_main: False
# encoder.layers.18.self_attn.out_proj.bias: False
# encoder.layers.18.self_attn.out_proj.S_residual: True
# encoder.layers.18.self_attn.out_proj.U_residual: True
# encoder.layers.18.self_attn.out_proj.V_residual: True
# encoder.layers.18.layer_norm1.weight: False
# encoder.layers.18.layer_norm1.bias: False
# encoder.layers.18.mlp.fc1.weight: False
# encoder.layers.18.mlp.fc1.bias: False
# encoder.layers.18.mlp.fc2.weight: False
# encoder.layers.18.mlp.fc2.bias: False
# encoder.layers.18.layer_norm2.weight: False
# encoder.layers.18.layer_norm2.bias: False
# encoder.layers.19.self_attn.k_proj.weight_main: False
# encoder.layers.19.self_attn.k_proj.bias: False
# encoder.layers.19.self_attn.k_proj.S_residual: True
# encoder.layers.19.self_attn.k_proj.U_residual: True
# encoder.layers.19.self_attn.k_proj.V_residual: True
# encoder.layers.19.self_attn.v_proj.weight_main: False
# encoder.layers.19.self_attn.v_proj.bias: False
# encoder.layers.19.self_attn.v_proj.S_residual: True
# encoder.layers.19.self_attn.v_proj.U_residual: True
# encoder.layers.19.self_attn.v_proj.V_residual: True
# encoder.layers.19.self_attn.q_proj.weight_main: False
# encoder.layers.19.self_attn.q_proj.bias: False
# encoder.layers.19.self_attn.q_proj.S_residual: True
# encoder.layers.19.self_attn.q_proj.U_residual: True
# encoder.layers.19.self_attn.q_proj.V_residual: True
# encoder.layers.19.self_attn.out_proj.weight_main: False
# encoder.layers.19.self_attn.out_proj.bias: False
# encoder.layers.19.self_attn.out_proj.S_residual: True
# encoder.layers.19.self_attn.out_proj.U_residual: True
# encoder.layers.19.self_attn.out_proj.V_residual: True
# encoder.layers.19.layer_norm1.weight: False
# encoder.layers.19.layer_norm1.bias: False
# encoder.layers.19.mlp.fc1.weight: False
# encoder.layers.19.mlp.fc1.bias: False
# encoder.layers.19.mlp.fc2.weight: False
# encoder.layers.19.mlp.fc2.bias: False
# encoder.layers.19.layer_norm2.weight: False
# encoder.layers.19.layer_norm2.bias: False
# encoder.layers.20.self_attn.k_proj.weight_main: False
# encoder.layers.20.self_attn.k_proj.bias: False
# encoder.layers.20.self_attn.k_proj.S_residual: True
# encoder.layers.20.self_attn.k_proj.U_residual: True
# encoder.layers.20.self_attn.k_proj.V_residual: True
# encoder.layers.20.self_attn.v_proj.weight_main: False
# encoder.layers.20.self_attn.v_proj.bias: False
# encoder.layers.20.self_attn.v_proj.S_residual: True
# encoder.layers.20.self_attn.v_proj.U_residual: True
# encoder.layers.20.self_attn.v_proj.V_residual: True
# encoder.layers.20.self_attn.q_proj.weight_main: False
# encoder.layers.20.self_attn.q_proj.bias: False
# encoder.layers.20.self_attn.q_proj.S_residual: True
# encoder.layers.20.self_attn.q_proj.U_residual: True
# encoder.layers.20.self_attn.q_proj.V_residual: True
# encoder.layers.20.self_attn.out_proj.weight_main: False
# encoder.layers.20.self_attn.out_proj.bias: False
# encoder.layers.20.self_attn.out_proj.S_residual: True
# encoder.layers.20.self_attn.out_proj.U_residual: True
# encoder.layers.20.self_attn.out_proj.V_residual: True
# encoder.layers.20.layer_norm1.weight: False
# encoder.layers.20.layer_norm1.bias: False
# encoder.layers.20.mlp.fc1.weight: False
# encoder.layers.20.mlp.fc1.bias: False
# encoder.layers.20.mlp.fc2.weight: False
# encoder.layers.20.mlp.fc2.bias: False
# encoder.layers.20.layer_norm2.weight: False
# encoder.layers.20.layer_norm2.bias: False
# encoder.layers.21.self_attn.k_proj.weight_main: False
# encoder.layers.21.self_attn.k_proj.bias: False
# encoder.layers.21.self_attn.k_proj.S_residual: True
# encoder.layers.21.self_attn.k_proj.U_residual: True
# encoder.layers.21.self_attn.k_proj.V_residual: True
# encoder.layers.21.self_attn.v_proj.weight_main: False
# encoder.layers.21.self_attn.v_proj.bias: False
# encoder.layers.21.self_attn.v_proj.S_residual: True
# encoder.layers.21.self_attn.v_proj.U_residual: True
# encoder.layers.21.self_attn.v_proj.V_residual: True
# encoder.layers.21.self_attn.q_proj.weight_main: False
# encoder.layers.21.self_attn.q_proj.bias: False
# encoder.layers.21.self_attn.q_proj.S_residual: True
# encoder.layers.21.self_attn.q_proj.U_residual: True
# encoder.layers.21.self_attn.q_proj.V_residual: True
# encoder.layers.21.self_attn.out_proj.weight_main: False
# encoder.layers.21.self_attn.out_proj.bias: False
# encoder.layers.21.self_attn.out_proj.S_residual: True
# encoder.layers.21.self_attn.out_proj.U_residual: True
# encoder.layers.21.self_attn.out_proj.V_residual: True
# encoder.layers.21.layer_norm1.weight: False
# encoder.layers.21.layer_norm1.bias: False
# encoder.layers.21.mlp.fc1.weight: False
# encoder.layers.21.mlp.fc1.bias: False
# encoder.layers.21.mlp.fc2.weight: False
# encoder.layers.21.mlp.fc2.bias: False
# encoder.layers.21.layer_norm2.weight: False
# encoder.layers.21.layer_norm2.bias: False
# encoder.layers.22.self_attn.k_proj.weight_main: False
# encoder.layers.22.self_attn.k_proj.bias: False
# encoder.layers.22.self_attn.k_proj.S_residual: True
# encoder.layers.22.self_attn.k_proj.U_residual: True
# encoder.layers.22.self_attn.k_proj.V_residual: True
# encoder.layers.22.self_attn.v_proj.weight_main: False
# encoder.layers.22.self_attn.v_proj.bias: False
# encoder.layers.22.self_attn.v_proj.S_residual: True
# encoder.layers.22.self_attn.v_proj.U_residual: True
# encoder.layers.22.self_attn.v_proj.V_residual: True
# encoder.layers.22.self_attn.q_proj.weight_main: False
# encoder.layers.22.self_attn.q_proj.bias: False
# encoder.layers.22.self_attn.q_proj.S_residual: True
# encoder.layers.22.self_attn.q_proj.U_residual: True
# encoder.layers.22.self_attn.q_proj.V_residual: True
# encoder.layers.22.self_attn.out_proj.weight_main: False
# encoder.layers.22.self_attn.out_proj.bias: False
# encoder.layers.22.self_attn.out_proj.S_residual: True
# encoder.layers.22.self_attn.out_proj.U_residual: True
# encoder.layers.22.self_attn.out_proj.V_residual: True
# encoder.layers.22.layer_norm1.weight: False
# encoder.layers.22.layer_norm1.bias: False
# encoder.layers.22.mlp.fc1.weight: False
# encoder.layers.22.mlp.fc1.bias: False
# encoder.layers.22.mlp.fc2.weight: False
# encoder.layers.22.mlp.fc2.bias: False
# encoder.layers.22.layer_norm2.weight: False
# encoder.layers.22.layer_norm2.bias: False
# encoder.layers.23.self_attn.k_proj.weight_main: False
# encoder.layers.23.self_attn.k_proj.bias: False
# encoder.layers.23.self_attn.k_proj.S_residual: True
# encoder.layers.23.self_attn.k_proj.U_residual: True
# encoder.layers.23.self_attn.k_proj.V_residual: True
# encoder.layers.23.self_attn.v_proj.weight_main: False
# encoder.layers.23.self_attn.v_proj.bias: False
# encoder.layers.23.self_attn.v_proj.S_residual: True
# encoder.layers.23.self_attn.v_proj.U_residual: True
# encoder.layers.23.self_attn.v_proj.V_residual: True
# encoder.layers.23.self_attn.q_proj.weight_main: False
# encoder.layers.23.self_attn.q_proj.bias: False
# encoder.layers.23.self_attn.q_proj.S_residual: True
# encoder.layers.23.self_attn.q_proj.U_residual: True
# encoder.layers.23.self_attn.q_proj.V_residual: True
# encoder.layers.23.self_attn.out_proj.weight_main: False
# encoder.layers.23.self_attn.out_proj.bias: False
# encoder.layers.23.self_attn.out_proj.S_residual: True
# encoder.layers.23.self_attn.out_proj.U_residual: True
# encoder.layers.23.self_attn.out_proj.V_residual: True
# encoder.layers.23.layer_norm1.weight: False
# encoder.layers.23.layer_norm1.bias: False
# encoder.layers.23.mlp.fc1.weight: False
# encoder.layers.23.mlp.fc1.bias: False
# encoder.layers.23.mlp.fc2.weight: False
# encoder.layers.23.mlp.fc2.bias: False
# encoder.layers.23.layer_norm2.weight: False
# encoder.layers.23.layer_norm2.bias: False
# post_layernorm.weight: False
# post_layernorm.bias: False
# Number of total parameters: 303376480, tunable parameters: 196704
# Missing keys: 0
# Unexpected keys: 0
# Processed: 100
# Skipped: 0

# %%
# ── Inference on TRAINING set, Effort model already loaded ──

import json
import torch
from PIL import Image
import numpy as np
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score

TRAIN_JSON = "/content/DiffusionForensics_Recons/train.json"
IMAGE_SIZE = 224

with open(TRAIN_JSON) as f:
    train_items = json.load(f)

print(f"Running inference on {len(train_items)} training images...")

train_results = []
train_skipped = []

with torch.no_grad():
    for i, item in enumerate(train_items):
        path = item["path"]
        label = int(item["label"])

        try:
            image_tensor = val_transform(
                Image.open(path).convert("RGB")
            ).unsqueeze(0).to(DEVICE)

            input_dict = {
                "image": image_tensor,
                "label": torch.tensor([label], dtype=torch.long).to(DEVICE),
                "mask": torch.ones(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=DEVICE),
            }

            out_dict = model(**input_dict)

            prob = float(out_dict["pred_label"].view(-1)[0].item())
            pred = 1 if prob >= THRESHOLD else 0

            train_results.append({
                "path": path,
                "true_label": label,
                "pred": int(pred),
                "confidence": prob,
                "correct": bool(pred == label),
            })

        except Exception as e:
            train_skipped.append({
                "path": path,
                "error": str(e),
            })

        if (i + 1) % 500 == 0:
            print(
                f"  {i+1}/{len(train_items)} processed | "
                f"ok={len(train_results)} | skipped={len(train_skipped)}"
            )

if len(train_results) == 0:
    raise RuntimeError("No training images were processed successfully.")

train_labels = np.array([r["true_label"] for r in train_results])
train_scores = np.array([r["confidence"] for r in train_results])
train_preds = np.array([r["pred"] for r in train_results])

train_acc = accuracy_score(train_labels, train_preds)
train_f1 = f1_score(train_labels, train_preds)
train_auc = roc_auc_score(train_labels, train_scores)

print("\n=== Train set results ===")
print(f"Processed: {len(train_results)}")
print(f"Skipped:   {len(train_skipped)}")
print(f"Train accuracy: {train_acc * 100:.2f}%")
print(f"Train F1:       {train_f1:.4f}")
print(f"Train AUC:      {train_auc:.4f}")

if len(train_skipped) > 0:
    print("\nFirst skipped examples:")
    for s in train_skipped[:5]:
        print(s)
# Out:
# Running inference on 1000 training images...
#   500/1000 processed | ok=500 | skipped=0
#   1000/1000 processed | ok=1000 | skipped=0
#
# === Train set results ===
# Processed: 1000
# Skipped:   0
# Train accuracy: 85.00%
# Train F1:       0.8421
# Train AUC:      0.9258

# %%
# ── ROC Curve: Validation only ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from IPython.display import Image, display

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

# ── Validation ROC ──
y_true = np.array([r["true_label"] for r in results])
y_score = np.array([r["confidence"] for r in results])

fpr, tpr, thresh = roc_curve(y_true, y_score)
auc_val = auc(fpr, tpr)

# ── Plot ──
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor('#FAFAFA')

ax.set_facecolor('#F4F4F4')
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_color('#CCCCCC')
ax.set_aspect('equal')

ax.plot(fpr, tpr, color='#7B4FB5', linewidth=2.5, label='ROC curve')
ax.fill_between(fpr, tpr, alpha=0.25, color='#9B7FD4')

ax.text(0.55, 0.35, f'AUC = {auc_val:.2f}', fontsize=20,
        fontweight='bold', color='#5A3A8A',
        ha='center', va='center')

# Random baseline
ax.plot([0, 1], [0, 1], color='#888', linestyle='--', linewidth=1,
        label='Random (0.50)')

# Best threshold (Youden)
opt_idx = np.argmax(tpr - fpr)
ax.scatter(fpr[opt_idx], tpr[opt_idx], color='#7B4FB5',
           s=100, zorder=5, edgecolors='white', linewidths=2)

ax.annotate(f'Best: {thresh[opt_idx]:.3f}\n'
            f'TPR={tpr[opt_idx]:.2f}, FPR={fpr[opt_idx]:.2f}',
            xy=(fpr[opt_idx], tpr[opt_idx]),
            xytext=(fpr[opt_idx] + 0.15, tpr[opt_idx] - 0.12),
            fontsize=9, color='#5A3A8A',
            arrowprops=dict(arrowstyle='->', color='#7B4FB5', lw=1.5))

ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_xlabel('FPR', fontsize=12)
ax.set_ylabel('TPR', fontsize=12)
ax.set_title('ROC — Validation Set (Effort FHub)', fontsize=14, pad=12)

ax.legend(fontsize=10, loc='lower right', framealpha=0.5)

plt.tight_layout()
plt.savefig('roc_val.jpg', dpi=80, bbox_inches='tight',
            facecolor=fig.get_facecolor())
plt.close(fig)

display(Image('roc_val.jpg'))

print(f"\nValidation AUC: {auc_val:.4f}")
print(f"Best threshold: {thresh[opt_idx]:.4f}")
# Out:
# Validation AUC: 0.6672
# Best threshold: 0.4954

# %%
# ── Confusion Matrix: Validation only, Effort — best-AUC checkpoint results ──
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    f1_score,
    accuracy_score,
    precision_score,
    recall_score,
)
from IPython.display import Image, display

MODEL_NAME = "Effort FHub"

def compute_metrics(res):
    y_true = np.array([int(r["true_label"]) for r in res])
    y_pred = np.array([int(r["pred"]) for r in res])

    # Some cells use "confidence", others use "score"
    if "confidence" in res[0]:
        y_score = np.array([float(r["confidence"]) for r in res])
    elif "score" in res[0]:
        y_score = np.array([float(r["score"]) for r in res])
    else:
        raise KeyError("results must contain either 'confidence' or 'score'.")

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    TN, FP, FN, TP = cm.ravel()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    auc_direct = roc_auc_score(y_true, y_score)
    auc_inverted = roc_auc_score(y_true, 1.0 - y_score)

    # Use the direction that gives correct fake-probability ranking
    if auc_inverted > auc_direct:
        auc_val = auc_inverted
        score_mode = "1 - score"
    else:
        auc_val = auc_direct
        score_mode = "score"

    return TN, FP, FN, TP, accuracy, precision, recall, f1, auc_val, score_mode

def draw_cm(ax, TN, FP, FN, TP, title):
    cell_labels = [["TN", "FP"], ["FN", "TP"]]
    cell_values = [[TN, FP], [FN, TP]]
    cell_colors = [["#d4edda", "#f8d7da"],
                   ["#f8d7da", "#d4edda"]]

    for i in range(2):
        for j in range(2):
            ax.add_patch(
                plt.Rectangle(
                    (j, 1 - i), 1, 1,
                    facecolor=cell_colors[i][j],
                    edgecolor="black",
                    linewidth=1.5,
                )
            )
            ax.text(
                j + 0.5,
                1 - i + 0.5,
                f"{cell_labels[i][j]}\n{cell_values[i][j]}",
                ha="center",
                va="center",
                fontsize=18,
                fontweight="bold",
                color="black",
            )

    ax.set_xlim(0, 2)
    ax.set_ylim(0, 2)
    ax.set_xticks([0.5, 1.5])
    ax.set_yticks([1.5, 0.5])

    ax.set_xticklabels(["Predicted REAL", "Predicted FAKE"], fontsize=10)
    ax.set_yticklabels(["REAL (0)", "FAKE (1)"], fontsize=10)

    ax.set_xlabel("Predicted label", fontsize=11, labelpad=8)
    ax.set_ylabel("True label", fontsize=11, labelpad=8)

    ax.tick_params(length=0)
    for spine in ax.spines.values():
        spine.set_visible(False)

    ax.set_title(title, fontsize=10, pad=14)

# Safety check
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

TN, FP, FN, TP, acc, prec, rec, f1, auc_val, score_mode = compute_metrics(results)

# Optional: pull checkpoint metadata if your results include it
ckpt_epoch = results[0].get("checkpoint_epoch", None)
ckpt_val_auc = results[0].get("checkpoint_val_auc", None)
ckpt_val_f1 = results[0].get("checkpoint_val_f1", None)

print(f"{'═' * 60}")
print(f"  Validation Metrics — {MODEL_NAME}")
print(f"{'═' * 60}")

if ckpt_epoch is not None:
    print(f"  Selected checkpoint epoch: {ckpt_epoch}")
if ckpt_val_auc is not None:
    print(f"  AUC Best Epoch:     {float(ckpt_val_auc):.4f}")
if ckpt_val_f1 is not None:
    print(f"  F1 Best-AUC epoch:  {float(ckpt_val_f1):.4f}")

print(f"  Accuracy:           {acc:.4f}")
print(f"{'─' * 60}")
print(f"  TP (correct fake):         {TP}")
print(f"  TN (correct real):         {TN}")
print(f"  FP (false alarm):          {FP}")
print(f"  FN (missed fake):          {FN}")
print(f"{'═' * 60}")

fig, ax = plt.subplots(figsize=(6, 5))
fig.patch.set_facecolor("white")

draw_cm(
    ax,
    TN, FP, FN, TP,
    f"Val · AUC {auc_val:.3f} · Acc {acc * 100:.1f}% · F1 {f1 * 100:.1f}%"
)

plt.suptitle(f"Confusion Matrix — Validation ({MODEL_NAME})", fontsize=14, y=1.02)
plt.tight_layout()

out_path = "confusion_matrix_val_effort.jpg"
plt.savefig(out_path, dpi=80, bbox_inches="tight", facecolor=fig.get_facecolor())
plt.close(fig)

display(Image(out_path))
# Out:
# ════════════════════════════════════════════════════════════
#   Validation Metrics — Effort FHub
# ════════════════════════════════════════════════════════════
#   Selected checkpoint epoch: 17
#   AUC Best Epoch:     0.6778
#   F1 Best-AUC epoch:  0.6216
#   Accuracy:           0.6800
# ────────────────────────────────────────────────────────────
#   TP (correct fake):         22
#   TN (correct real):         46
#   FP (false alarm):          4
#   FN (missed fake):          28
# ════════════════════════════════════════════════════════════

# %%
# # ── Save per-image results to Drive ──────────────────────────────────────
# import os, json

# DRIVE_OUT = "/content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/test_outputs/effort_val_fh"
# os.makedirs(DRIVE_OUT, exist_ok=True)

# with open(f"{DRIVE_OUT}/results.json", "w") as f:
#     json.dump(results, f, indent=2)

# print(f"\n✓ Saved {len(results)} per-image results to: {DRIVE_OUT}/results.json")
# print(f"   wrong: {sum(1 for r in results if not r.get('correct', r['pred']==r['true_label']))}")
# Out:
# ✓ Saved 100 per-image results to: /content/drive/MyDrive/Capstone_Hripsime/Frameworks/ForensicHub/log/test_outputs/effort_val_fh/results.json
#    wrong: 32

# %%
# Badly / Well Detected dataset — VALIDATION

# %matplotlib inline

import os
import re
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Image, display

# ── Rebuild all summary information from `results` ────────────────────────────
if len(results) == 0:
    raise RuntimeError("Validation results is empty.")

total = len(results)
n_correct = sum(r["correct"] for r in results)
accuracy = 100 * n_correct / total

probs = [r["confidence"] for r in results]

well  = [r for r in results if r["correct"]]
badly = [r for r in results if not r["correct"]]

well_sorted  = sorted(well,  key=lambda x: abs(x["confidence"] - 0.5), reverse=True)
badly_sorted = sorted(badly, key=lambda x: abs(x["confidence"] - 0.5), reverse=True)

well_sample  = well_sorted[:100]
badly_sample = badly_sorted[:100]

n_real = sum(r["true_label"] == 0 for r in results)
n_fake = sum(r["true_label"] == 1 for r in results)

tp = sum((r["true_label"] == 1 and r["pred"] == 1) for r in results)
tn = sum((r["true_label"] == 0 and r["pred"] == 0) for r in results)
fp = sum((r["true_label"] == 0 and r["pred"] == 1) for r in results)
fn = sum((r["true_label"] == 1 and r["pred"] == 0) for r in results)

real_acc = 100 * tn / max(1, n_real)
fake_acc = 100 * tp / max(1, n_fake)
precision_fake = tp / max(1, tp + fp)
recall_fake = tp / max(1, tp + fn)
f1_fake = 2 * precision_fake * recall_fake / max(1e-12, precision_fake + recall_fake)

# ── Print validation info ─────────────────────────────────────────────────────
print(f"Validation inference: {total} images\n")
print(f"Done: {n_correct}/{total} correct ({accuracy:.1f}% accuracy)")
print(f"Min prob: {min(probs):.4f}  Max: {max(probs):.4f}  Mean: {sum(probs)/len(probs):.4f}")
print(f"Well detected:  {len(well)}")
print(f"Badly detected: {len(badly)}")
print(f"TP={tp}, TN={tn}, FP={fp}, FN={fn}")
print(f"Real accuracy: {real_acc:.1f}%")
print(f"Fake accuracy: {fake_acc:.1f}%")
print(f"Fake precision: {precision_fake:.4f}")
print(f"Fake recall:    {recall_fake:.4f}")
print(f"Fake F1:        {f1_fake:.4f}")

if "skipped" in globals() and len(skipped) > 0:
    print(f"\nSkipped images: {len(skipped)}")
    for s in skipped[:10]:
        print(f"  {os.path.basename(s['path'])}: {s['error']}")

# ── Helpers ───────────────────────────────────────────────────────────────────
def label_str(l):
    return "REAL" if int(l) == 0 else "FAKE"

def get_image_number(path):
    """
    Extracts image number from filename.
    Examples:
      /.../0005.png -> 0005
      /.../fake_0005_img.png -> 0005
    """
    fname = os.path.basename(path)
    stem = os.path.splitext(fname)[0]

    if stem.isdigit():
        return stem

    m = re.search(r"\d+", stem)
    return m.group(0) if m else "unknown"

def load_thumb(path, size=128):
    img = PILImage.open(path).convert("RGB")
    w, h = img.size
    side = min(w, h)
    img = img.crop((
        (w - side) // 2,
        (h - side) // 2,
        (w + side) // 2,
        (h + side) // 2
    ))
    return img.resize((size, size), PILImage.LANCZOS)

def make_grid(samples, title, filename, max_rows=10, cols=10):
    n = len(samples)
    if n == 0:
        print(f"No samples to plot for {filename}")
        return

    rows = min(max_rows, (n + cols - 1) // cols)
    show = min(n, rows * cols)

    fig, axes = plt.subplots(rows, cols, figsize=(22, rows * 2.9))
    fig.patch.set_facecolor("#1a1a1a")
    fig.suptitle(title, fontsize=15, color="white", y=0.995, fontweight="medium")

    # Make axes iterable for both 1-row and multi-row cases
    if rows == 1:
        flat_axes = axes.flatten() if hasattr(axes, "flatten") else [axes]
    else:
        flat_axes = axes.flatten()

    for idx, ax in enumerate(flat_axes):
        if idx >= show:
            ax.axis("off")
            continue

        r = samples[idx]

        try:
            ax.imshow(load_thumb(r["path"]))
        except Exception:
            ax.set_facecolor("#333")
            ax.text(
                0.5, 0.5, "error",
                ha="center", va="center",
                color="white", fontsize=7,
                transform=ax.transAxes
            )

        true_color = "#2ecc71" if int(r["true_label"]) == 0 else "#e74c3c"
        for spine in ax.spines.values():
            spine.set_edgecolor(true_color)
            spine.set_linewidth(3)

        ax.set_xticks([])
        ax.set_yticks([])

        img_num = get_image_number(r["path"])

        ax.set_title(
            f"Image #{img_num}\n"
            f"True: {label_str(r['true_label'])} → Pred: {label_str(r['pred'])}\n"
            f"conf: {r['confidence']:.3f}",
            fontsize=7,
            color="white",
            pad=4
        )

    for ax in flat_axes[show:]:
        ax.axis("off")

    real_p = mpatches.Patch(color="#2ecc71", label="True label: REAL")
    fake_p = mpatches.Patch(color="#e74c3c", label="True label: FAKE")
    fig.legend(
        handles=[real_p, fake_p],
        loc="lower center",
        ncol=2,
        fontsize=10,
        framealpha=0.3,
        facecolor="#333",
        labelcolor="white",
        bbox_to_anchor=(0.5, 0.01)
    )

    plt.subplots_adjust(hspace=0.75, wspace=0.08, top=0.92, bottom=0.06)
    plt.savefig(
        filename,
        dpi=80,
        bbox_inches="tight",
        facecolor=fig.get_facecolor()
    )
    plt.close(fig)
    display(Image(filename))

# ── Plots ─────────────────────────────────────────────────────────────────────
make_grid(
    well_sample,
    title=f"{len(well_sample)} most confidently CORRECT predictions (Validation)\n"
          "Border = true label",
    filename="well_detected_val.jpg"
)

make_grid(
    badly_sample,
    title=f"{len(badly_sample)} most confidently WRONG predictions (Validation)\n"
          "Border = true label",
    filename="badly_detected_val.jpg"
)
# Out:
# Validation inference: 100 images
#
# Done: 68/100 correct (68.0% accuracy)
# Min prob: 0.0330  Max: 0.9870  Mean: 0.3492
# Well detected:  68
# Badly detected: 32
# TP=22, TN=46, FP=4, FN=28
# Real accuracy: 92.0%
# Fake accuracy: 44.0%
# Fake precision: 0.8462
# Fake recall:    0.4400
# Fake F1:        0.5789

# %%
import nbformat
NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort Train.ipynb"

nb = nbformat.read(NOTEBOOK_PATH, as_version=4)

if "widgets" in nb.metadata:
    del nb.metadata["widgets"]

nbformat.write(nb, NOTEBOOK_PATH)

# %%
# !pip install nbconvert -q

NOTEBOOK_PATH = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort Train.ipynb"
OUTPUT_DIR    = "/content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks"

# !jupyter nbconvert \
    --to html \
    --embed-images \
    --output-dir "{OUTPUT_DIR}" \
    "{NOTEBOOK_PATH}"

print("Done — check your Drive for the .html file")
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/Effort Train.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 692597 bytes to /content/drive/MyDrive/Capstone_Hripsime/Code Notebooks/HTML Notebooks/Effort Train.html
# Done — check your Drive for the .html file
